# %%
import pandas as pd
import re
import csv
from nltk import word_tokenize,pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords 
from nltk import stem
from nltk import sent_tokenize


import stanza
stanza.download('en') # download English model
nlp = stanza.Pipeline('en') # initialize English neural pipeline
doc = nlp("Barack Obama was born in Hawaii.") # run annotation over a sentence
from sklearn.model_selection import train_test_split
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-09-28 21:12:25 INFO: Downloaded file to /Users/gbaldonado/stanza_resources/resources.json
# 2024-09-28 21:12:25 INFO: Downloading default packages for language: en (English) ...
# 2024-09-28 21:12:26 INFO: File exists: /Users/gbaldonado/stanza_resources/en/default.zip
# 2024-09-28 21:12:29 INFO: Finished downloading models and saved to /Users/gbaldonado/stanza_resources
# 2024-09-28 21:12:29 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-09-28 21:12:29 INFO: Downloaded file to /Users/gbaldonado/stanza_resources/resources.json
# 2024-09-28 21:12:30 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-09-28 21:12:30 INFO: Using device: cpu
# 2024-09-28 21:12:30 INFO: Loading: tokenize
# 2024-09-28 21:12:30 INFO: Loading: mwt
# 2024-09-28 21:12:30 INFO: Loading: pos
# 2024-09-28 21:12:30 INFO: Loading: lemma
# 2024-09-28 21:12:30 INFO: Loading: constituency
# 2024-09-28 21:12:31 INFO: Loading: depparse
# 2024-09-28 21:12:31 INFO: Loading: sentiment
# 2024-09-28 21:12:31 INFO: Loading: ner
# 2024-09-28 21:12:31 INFO: Done loading processors!

# %% [markdown]
# ##### Stanford Core NLP
# * We need to download the [Stanford core nlp](https://stanfordnlp.github.io/CoreNLP/download.html) package before we can start with the dataset creation process.
# ``
# cd /Users/krishns18/SFSU/Modeling_ALMA/corenlp/stanford-corenlp-4.0.0
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer
# ``
# * The server will start and the command prompt will display like below
# ``
# (base) Shaileshs-MBP:stanford-corenlp-4.0.0 krishns18$ java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer
# [main] INFO CoreNLP - --- StanfordCoreNLPServer#main() called ---
# [main] INFO CoreNLP - Warning: cannot find edu/stanford/nlp/models/srparser/englishSR.ser.gz
# [main] INFO CoreNLP - Setting default constituency parser to PCFG parser: edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz
# [main] INFO CoreNLP - To use shift reduce parser download English models jar from:
# [main] INFO CoreNLP - https://stanfordnlp.github.io/CoreNLP/download.html
# [main] INFO CoreNLP -     Threads: 16
# [main] INFO CoreNLP - Starting server...
# [main] INFO CoreNLP - StanfordCoreNLPServer listening at /0:0:0:0:0:0:0:0:9000
# ``

# %%
import sys

# Add the 'utils' directory to the system path
utils_path = '/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/utils'
sys.path.insert(0, utils_path)

from text_cleaner import clean_text

# %%
# nlp = StanfordCoreNLP('http://localhost:9000')

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ## 1.) Load tacited dataset

# %%
# Load the Excel workbook
themes = ["Aspirational Plus", "Familial Plus", "Navigational Plus", "Social Plus", "Resistance Plus"]
base_df = pd.read_excel("../../../data/for_training/batch_2_concatenated/batch_2_tacited_Aspirational Plus_to_be_processed_for_sentence_level.xlsx", usecols=["Essay ID", "Annotated Essays"])

for i in themes:
    published_tacited_dataset_path = f'/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/for_training/batch_2_concatenated/batch_2_tacited_{i}_to_be_processed_for_sentence_level.xlsx'
    df = pd.read_excel(published_tacited_dataset_path, usecols=[i])

    base_df[i] = df[i]

base_df
# Out:
#                     Essay ID  \
# 0    F20.PHYS0102.02.000.001
# 1    F20.PHYS0102.02.001.002
# 2    F20.PHYS0102.02.002.003
# 3    F20.PHYS0102.02.003.004
# 4    F20.PHYS0102.02.004.005
# ..                       ...
# 993  S20.PHYS0112.01.019.312
# 994  S20.PHYS0112.01.020.313
# 995  S20.PHYS0112.01.021.054
# 996  S20.PHYS0112.01.022.314
# 997  S20.PHYS0112.01.023.315
#
#                                       Annotated Essays  \
# 0    Reflection #1: Why Am I Here?   “Why am I here...
# 1    I am here because my future goal is to heal pe...
# 2    Reflection: At the moment I am feeling very st...
# 3    Holly Enrile PHYSICS LAB Reﬂection#1 Sept. 10,...
# 4    Karla Martinez  Why I am here?  One of the mai...
# ..                                                 ...
# 993  I am here to learn how physics works, how moti...
# 994  I am here because there are so many things to ...
# 995  I am taking physics and physics lab because I ...
# 996  Sometimes when things in life don't go as plan...
# 997  I am currently taking Physics 112 for many rea...
#
#                                      Aspirational Plus  \
# 0    More specifically, my goal is to become a spor...
# 1    I am here because my future goal is to heal pe...
# 2                                                    0
# 3                                                    0
# 4    I am also here because I want to be a nurse. I...
# ..                                                 ...
# 993  I am here to learn how physics works, how moti...
# 994  I am here to be the best or at least a better ...
# 995  I am taking physics and physics lab because I ...
# 996                                                  0
# 997  After receiving my bachelor’s degree I hope to...
#
#                                          Familial Plus  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3     In general, I’m in school because I want to m...
# 4    One of the main reasons why I am here is becau...
# ..                                                 ...
# 993                                                  0
# 994                                                  0
# 995                                                  0
# 996                                                  0
# 997                                                  0
#
#                                      Navigational Plus  \
# 0    For me personally, I am taking   physics 101 a...
# 1     I am taking this course as a prereq for the  ...
# 2                                                    0
# 3     I am here because it is a requirement for my ...
# 4                                                    0
# ..                                                 ...
# 993  I'm Taking this class for my biology major, so...
# 994   I am in this class because it is a requiremen...
# 995                                                  0
# 996                                                  0
# 997   My main reason for taking this class is to pr...
#
#                                            Social Plus  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4    I always wanted to study medicine and help peo...
# ..                                                 ...
# 993                                                  0
# 994                                                  0
# 995                                                  0
# 996   It then narrows down to the things that I fin...
# 997                                                  0
#
#                                        Resistance Plus
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3     In general, I’m in school because I want to m...
# 4     Become a nurse has always been my dream job a...
# ..                                                 ...
# 993                                                  0
# 994                                                  0
# 995                                                  0
# 996                                                  0
# 997                                                  0
#
# [998 rows x 7 columns]

# %%
base_df.to_excel("/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/for_training/batch_2_concatenated/batch_2_dataset_all_merged_capitals.xlsx", index=False)

# %% [markdown]
# ## 2. Create theme datasets

# %%
def create_theme_datasets(df, themes, sentence_level=True):
    """
    Creates separate datasets for each theme and returns them as a dictionary.

    :param df: The original DataFrame.
    :param themes: List of theme columns to create separate datasets for.
    :return: A dictionary with theme names as keys and DataFrames as values.
    """
    base_columns = ['Essay ID', 'Annotated Essays']
    theme_datasets = {}

    for theme in themes:
        # Select the columns for the theme dataset
        theme_df = df[base_columns + [theme]]

        if sentence_level:
        # Filter out rows where the theme value is 0
            theme_df = theme_df[theme_df[theme] != 0]
            theme_df = theme_df[theme_df[theme] != "0"]
        
        # Add the DataFrame to the dictionary
        theme_datasets[theme] = theme_df

        theme_df.rename(columns={"Essay ID": "Alma ID", "Annotated Essays": "Essay: Why I am here?"}, inplace=True)

    return theme_datasets

theme_names = themes

# Create the theme datasets
sentence_level_theme_datasets = create_theme_datasets(base_df, theme_names, True)
essay_level_theme_datasets = create_theme_datasets(base_df, theme_names, False)
# Out:
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_4274/2584496348.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theme_df.rename(columns={"Essay ID": "Alma ID", "Annotated Essays": "Essay: Why I am here?"}, inplace=True)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_4274/2584496348.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theme_df.rename(columns={"Essay ID": "Alma ID", "Annotated Essays": "Essay: Why I am here?"}, inplace=True)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_4274/2584496348.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theme_df.rename(columns={"Essay ID": "Alma ID", "Annotated Essays": "Essay: Why I am here?"}, inplace=True)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_4274/2584496348.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theme_df.rename(columns={"Essay ID": "Alma ID", "Annotated Essays": "Essay: Why I am here?"}, inplace=True)
# /var/folders/cz/vjt5grr94cn0qr63v4qx4qth0000gn/T/ipykernel_4274/2584496348.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theme_df.rename(columns={"Essay ID": "Alma ID", "Annotated Essays": "Essay: Why I am here?"}, inplace=True)

# %%
sentence_level_theme_datasets["Resistance Plus"]
# Out:
#                      Alma ID  \
# 3    F20.PHYS0102.02.003.004
# 4    F20.PHYS0102.02.004.005
# 44   F20.PHYS0242.04.008.206
# 60   F20.PHYS0242.04.024.222
# 66   F20.ASTR0116.02.004.226
# ..                       ...
# 937  S20.PHYS0112.03.002.107
# 938  S20.PHYS0112.03.003.345
# 947  S20.PHYS0112.03.012.352
# 948  S20.PHYS0112.03.013.353
# 954  S20.PHYS0112.03.019.359
#
#                                  Essay: Why I am here?  \
# 3    Holly Enrile PHYSICS LAB Reﬂection#1 Sept. 10,...
# 4    Karla Martinez  Why I am here?  One of the mai...
# 44   The reason why I want to go into the STEM fiel...
# 60   After reading the question prompt, two respons...
# 66   Roxana Garcia Rojas   Ricardo Flores   ASTR 11...
# ..                                                 ...
# 937  Why am I here? I'm here cause my parents broug...
# 938  Why am I here? Reflecting back its crazy to th...
# 947  The reason I am here is because I want to be a...
# 948  I am here for my third time and am motivated a...
# 954  Reflective Journal #1 "Why am I here?"        ...
#
#                                        Resistance Plus
# 3     In general, I’m in school because I want to m...
# 4     Become a nurse has always been my dream job a...
# 44   It's also something very motivating for me to ...
# 60   The short version of that story is that I grew...
# 66    Life is hard, and the   institutional oppress...
# ..                                                 ...
# 937  School has always been hard for me but i'm det...
# 938   I am here to also show to my family, friends,...
# 947   Only five percent of doctors are Hispanic and...
# 948   I am motivated to becoming a physical therapi...
# 954  They taught me the value of hard work and pers...
#
# [128 rows x 3 columns]

# %%
essay_level_theme_datasets["Navigational"]
# Out:
#                      Alma ID  \
# 0           S18.W2.111.01.01
# 1           S18.W2.111.01.02
# 2           S18.W2.111.01.03
# 3           S18.W2.111.01.04
# 4           S18.W2.111.01.05
# ..                       ...
# 584  F19.PHYS242.02.004.1216
# 585  F19.PHYS242.02.005.1213
# 586  F19.PHYS242.02.006.1217
# 587  F19.PHYS242.02.007.1211
# 588  F19.PHYS242.02.008.1214
#
#                                  Essay: Why I am here?  \
# 0    Why am I here? Well why does anyone pursue a h...
# 1    I'm here because my parents came here during t...
# 2    I am here because I want to better myself & my...
# 3    I am here at SFSU because I am a first generat...
# 4     I am here to help myself grow.\n- Learn and a...
# ..                                                 ...
# 584  My family has valued hard work. Growing up I w...
# 585  I have lived in the Bay Area my whole life and...
# 586  The values of my community have made a deep an...
# 587  Well one thing my mom has taught me is to not ...
# 588  Since I am the first one go to college in my f...
#
#                                           Navigational
# 0                                                    0
# 1                                                    0
# 2    Being in this instituion will pave a way for m...
# 3                                                    0
# 4    - Learn and apply my skills to progress toward...
# ..                                                 ...
# 584                                                  0
# 585                                                  0
# 586                                                  0
# 587                                                  0
# 588                                                  0
#
# [589 rows x 3 columns]

# %%
essay_level_theme_datasets["Navigational"]
# Out:
#                      Alma ID  \
# 0           S18.W2.111.01.01
# 1           S18.W2.111.01.02
# 2           S18.W2.111.01.03
# 3           S18.W2.111.01.04
# 4           S18.W2.111.01.05
# ..                       ...
# 584  F19.PHYS242.02.004.1216
# 585  F19.PHYS242.02.005.1213
# 586  F19.PHYS242.02.006.1217
# 587  F19.PHYS242.02.007.1211
# 588  F19.PHYS242.02.008.1214
#
#                                  Essay: Why I am here?  \
# 0    Why am I here? Well why does anyone pursue a h...
# 1    I'm here because my parents came here during t...
# 2    I am here because I want to better myself & my...
# 3    I am here at SFSU because I am a first generat...
# 4     I am here to help myself grow.\n- Learn and a...
# ..                                                 ...
# 584  My family has valued hard work. Growing up I w...
# 585  I have lived in the Bay Area my whole life and...
# 586  The values of my community have made a deep an...
# 587  Well one thing my mom has taught me is to not ...
# 588  Since I am the first one go to college in my f...
#
#                                           Navigational
# 0                                                    0
# 1                                                    0
# 2    Being in this instituion will pave a way for m...
# 3                                                    0
# 4    - Learn and apply my skills to progress toward...
# ..                                                 ...
# 584                                                  0
# 585                                                  0
# 586                                                  0
# 587                                                  0
# 588                                                  0
#
# [589 rows x 3 columns]

# %%
navigational_sentence_df = sentence_level_theme_datasets["Navigational"]

# %% [markdown]
# **Data Preparation**
# 1. Get noun and adjective

# %%
def get_noun_adj(phrase):
    noun_adj = []
    for tag in pos_tag(phrase.split()):
        if tag[1] in ['NN','NNP','NNS', 'NNPS','JJ', 'JJR', 'JJS']:
            noun_adj.append(tag[0])
    return  noun_adj

# %%
## to replace get_ner??
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import jaccard_score

def jaccard_similarity(str1, str2):
    vect = CountVectorizer().fit_transform([str1, str2])
    vectors = vect.toarray()
    return jaccard_score(vectors[0], vectors[1], average='weighted')

# %% [markdown]
# 3. Get sentence label
#     1. Look for exact match
#     2. Check for NER in phrase (title/profession/scientific fields) and check if those exist in the sentence
#     3. Get the nouns and adjectives and check if those exist in the sentence

# %%
text = "I‚Äôm here because I want to become a dentist. How about you? Let's do this!"
cleaned_text = clean_text(text)
cleaned_text
# Out:
# "Im here because I want to become a dentist. How about you? Let's do this!"

# %%
## updated with jaccard sim and removed get_ner

def get_sentence_label(essay_sentence, phrase): 
    # Escape special regex characters in the phrase but keep / and - unescaped
    escaped_phrase = re.escape(phrase).replace(r'\/', '/').replace(r'\-', '-')
    # Create a regex pattern to find the phrase within the essay sentence
    match = re.search(r'.*%s.*' % escaped_phrase, essay_sentence, re.IGNORECASE)
    if match:
        return 1
    else:        
        similarity = jaccard_similarity(essay_sentence, phrase)
        # print(similarity)
        if similarity > 0.5:  # Adjust the threshold as needed
            return 1
        else:
            # 3. Else get the nouns and adjectives and check if those present in the sentence
            noun_adj_phrase = get_noun_adj(phrase)
            all_pos_found = None
            for pos in noun_adj_phrase:
                if pos not in essay_sentence:
                    all_pos_found = 0
                    break
                else:
                    all_pos_found = 1
            if all_pos_found == 1:
                return 1
            else:
                return 0

# %%
get_sentence_label("a one hour airplane trip back home, 7 hour drive",'I am in college specifically to pursue my one and only career which is to be a veterinarian')
# Out:
# 0

# %%
from custom_tokenizer import custom_sent_tokenizer

# %%
text = "Dr. Smith is a veterinarian. P.A. Jones assists him."
sentences = custom_sent_tokenizer(text)
print(sentences)
# Out:
# ['Dr. Smith is a veterinarian.', 'P.A. Jones assists him.']

# %%
sent = "‚Ä†i am at san francisco state university to get a bachelors degree in civil engineering "
sentences = clean_text(sent)
sentences = custom_sent_tokenizer(sentences)

print(sentences)
# Out:
# ['i am at san francisco state university to get a bachelors degree in civil engineering']

# %%
clean_text(sent)
# Out:
# 'i am at san francisco state university to get a bachelors degree in civil engineering'

# %% [markdown]
# ## Looking at example 1, index 0

# %% [markdown]
# ## 3. Creating sentence level phrases

# %% [markdown]
# 'I decided to enroll into the physics supplemental course because I’ve had a history of struggling in my math classes. Since physics is basically another math class, I knew I would need to take extra steps to ensure my success. In the past I’ve had a packed schedule with classes and work, but this semester I allowed myself more room for school by cutting back my work hours. I originally planned on letting myself have time to attend office hours, but I realized that wouldn’t be enough.\nWhen I heard the option to enroll in a supplemental course for physics, I knew I had to enroll for the extra help. Not only would I have more practice with physics problems, but I would be able to connect more with my fellow classmates. I figured that if I felt like I created a little community with the supplemental course, I would feel more comfortable with physics problems. With a community I would feel comfortable enough to ask questions without having to worry about sounding unintelligent.\nAnother big reason for enrolling was when I heard I wouldn’t have homework. I will have the opportunity to have the extra practice with physics problems without the stress of having to worry about my grade. I will be able to do the problems at my own pace and truly understand the steps to get the solution'

# %%
ex = 'I decided to enroll into the physics supplemental course because I’ve had a history of struggling in my math classes. Since physics is basically another math class, I knew I would need to take extra steps to ensure my success. In the past I’ve had a packed schedule with classes and work, but this semester I allowed myself more room for school by cutting back my work hours. I originally planned on letting myself have time to attend office hours, but I realized that wouldn’t be enough.\nWhen I heard the option to enroll in a supplemental course for physics, I knew I had to enroll for the extra help. Not only would I have more practice with physics problems, but I would be able to connect more with my fellow classmates. I figured that if I felt like I created a little community with the supplemental course, I would feel more comfortable with physics problems. With a community I would feel comfortable enough to ask questions without having to worry about sounding unintelligent.\nAnother big reason for enrolling was when I heard I wouldn’t have homework. I will have the opportunity to have the extra practice with physics problems without the stress of having to worry about my grade. I will be able to do the problems at my own pace and truly understand the steps to get the solution'
annotation = ' I’ve had a history of struggling in my math classes. Since physics is basically another math class /%/ I knew I would need to take extra steps to ensure my success. /-/ When I heard the option to enroll in a supplemental course for physics. /-/ I knew I had to enroll for the extra help.'

annotation_list = re.split(r'/%/', annotation)
annotation_list = [clean_text(text) for text in annotation_list]
annotation_list
# Out:
# ['Ive had a history of struggling in my math classes. Since physics is basically another math class',
#  'I knew I would need to take extra steps to ensure my success. When I heard the option to enroll in a supplemental course for physics. I knew I had to enroll for the extra help.']

# %%
annotation = "- I am here to help myself grow. /%/  - Understand my purpose. /%/  Improve /%/ - Learn and apply my skills to progress towards my career goal."

annotation_list = re.split(r'/%/', annotation)
annotation_list = [clean_text(text) for text in annotation_list]
annotation_list
# Out:
# ['I am here to help myself grow.',
#  'Understand my purpose.',
#  'Improve',
#  'Learn and apply my skills to progress towards my career goal.']

# %%
def process_sentences_for_theme(theme_df, theme_column):
    theme_sentence_df = pd.DataFrame(columns=['sentence', 'label', 'phrase'])
    
    for index, val in theme_df.iterrows():
        text = val['Essay: Why I am here?'].rstrip('\n\r')
        
        # Split the paragraphs into sentences using sent_tokenize from nltk
        temp_text = custom_sent_tokenizer(text)
        
        # Annotation
        annotation = str(val[theme_column])
         
        # Annotation list
        annotation_list = re.split(r'/%/', annotation)
        annotation_strip = [clean_text(annotation) for annotation in annotation_list]
        essay_strip = [x for x in temp_text if x != '']
        essay_strip = [clean_text(essay) for essay in essay_strip]
        
        # Remove extra spaces before the sentences
        annotation_strip = [y.lstrip(" ") for y in annotation_strip]
        essay_strip = [x.lstrip(" ") for x in essay_strip]
        
        # Annotate the essay on sentence level
        for sentence in essay_strip:
            sentence = clean_text(sentence)
            if not re.search(r'\w', sentence):
                continue
            if len(sentence.split(' ')) < 3:
                continue
            
            label = 0
            for annotation_phrase in annotation_strip:
                if len(annotation_phrase.split()) > 2:
                    label = get_sentence_label(sentence, annotation_phrase)
                    if label == 1:
                        break
            
            # Create a new DataFrame with the row you want to add
            new_row = pd.DataFrame([{'sentence': sentence.lower(), 'label': label, 'phrase': annotation_strip}])
            
            # Concatenate the new row to the existing DataFrame
            theme_sentence_df = pd.concat([theme_sentence_df, new_row], ignore_index=True)
    
    return theme_sentence_df

# %%
sentence_level_theme_datasets["Navigational Plus"]

for index, val in sentence_level_theme_datasets["Navigational Plus"].iterrows():
   
    text = val['Essay: Why I am here?'].rstrip('\n\r')
    print(text)
    # Split the paragraphs into sentences using sent_tokenize from nltk
    temp_text = custom_sent_tokenizer(text)

    print(temp_text)
# Out:
# Reflection #1: Why Am I Here?   “Why am I here?” is quite a general question that can be taken in many directions, but I assume   that it is intended for us to make our connections to this class. For me personally, I am taking   physics 101 and 102, because as a kinesiology major it is something that we need to know in our   field of study. More specifically, my goal is to become a sports physical therapist and work to   rehabilitate athletes, so dealing with physics and its relationship with the human body is going to   be a big component of my job. Sports have always been a big part of my life ever since I was in   elementary school and I have played in a couple basketball leagues growing up. This fascination   with sports turned into an interest in health and fitness as well, which led me down the path of   kinesiology. Particularly, it was all the injuries that I have been through over the years that really   made me want to become a physical therapist and help others who may be going through any   injuries they may experience in their lifetime.
# ['Reflection #1: Why Am I Here?', '  “Why am I here?” is quite a general question that can be taken in many directions, but I assume   that it is intended for us to make our connections to this class.', 'For me personally, I am taking   physics 101 and 102, because as a kinesiology major it is something that we need to know in our   field of study.', 'More specifically, my goal is to become a sports physical therapist and work to   rehabilitate athletes, so dealing with physics and its relationship with the human body is going to   be a big component of my job.', 'Sports have always been a big part of my life ever since I was in   elementary school and I have played in a couple basketball leagues growing up.', 'This fascination   with sports turned into an interest in health and fitness as well, which led me down the path of   kinesiology.', 'Particularly, it was all the injuries that I have been through over the years that really   made me want to become a physical therapist and help others who may be going through any   injuries they may experience in their lifetime.']
# I am here because my future goal is to heal people. I am taking this course as a prereq for the   Kin major. I would like to become a physical therapist, specifically for athletes. I am very   passionate about sports and being in that atmosphere will keep me motivated and able to   understand the physical and mental struggles that athletes go through.
# ['I am here because my future goal is to heal people.', 'I am taking this course as a prereq for the   Kin major.', 'I would like to become a physical therapist, specifically for athletes.', 'I am very   passionate about sports and being in that atmosphere will keep me motivated and able to   understand the physical and mental struggles that athletes go through.']
# Holly Enrile PHYSICS LAB Reﬂection#1 Sept. 10, 2020 I am here because it is a requirement for my major and I think Physics is a really cool subject to learn. To have knowledge about the way things work and relate to each other is a powerful skill.  In general, I’m in school because I want to make my parents proud and break the generational cycle. I will be ﬁrst generation university graduate. I am also a mother of 2 who I want to set a good example for and that hard work does and will pay oﬀ. There will be many obstacles, especially during this time with all the stuﬀ going in the world today but with grit and growth mindsets, we all can persevere and get through it.
# ['Holly Enrile PHYSICS LAB Reﬂection#1 Sept.', '10, 2020 I am here because it is a requirement for my major and I think Physics is a really cool subject to learn.', 'To have knowledge about the way things work and relate to each other is a powerful skill.', ' In general, I’m in school because I want to make my parents proud and break the generational cycle.', 'I will be ﬁrst generation university graduate.', 'I am also a mother of 2 who I want to set a good example for and that hard work does and will pay oﬀ.', 'There will be many obstacles, especially during this time with all the stuﬀ going in the world today but with grit and growth mindsets, we all can persevere and get through it.']
# Why am I here? I am here in this lab because, honestly, there wasn’t any other lab that was available for me to take. But also because science has always been my favorite subject and so taking a physics lab interested me a lot more than other labs that were available. I am here at college because the career choices I want to take, require me to to get a degree in Biology and also, more importantly, because my parents have sacrificed a lot to make it in this country as far as they could have and they would want me to be better off than they are. And to be honest, I am here because there is nothing else for me to do besides work, especially because of the whole pandemic situation that is going on, this helps to further progress my study, as well as help occupy my time.
# ['Why am I here?', 'I am here in this lab because, honestly, there wasn’t any other lab that was available for me to take.', 'But also because science has always been my favorite subject and so taking a physics lab interested me a lot more than other labs that were available.', 'I am here at college because the career choices I want to take, require me to to get a degree in Biology and also, more importantly, because my parents have sacrificed a lot to make it in this country as far as they could have and they would want me to be better off than they are.', 'And to be honest, I am here because there is nothing else for me to do besides work, especially because of the whole pandemic situation that is going on, this helps to further progress my study, as well as help occupy my time.']
# Jose Castillo       Reflection     Honestly I’m only here because is part of my requirement for my major. Also part of it is   for my mom I’m only here because i’m just trying to make her proud and also make myself   proud that I can get a degree. Not going to lie sometimes I don’t feel like I can just because most   of the classes are hard and especially doing every class online makes it harder for me. Honestly   don’t even know how long i’m going to be here it really depends how much effort in time I   actually put in all my classes. Hopefully i’m able to graduated in 4 years just because I do want   to work for my master degree in the future I feel like it’s going to benefit me and especially for   my mom and family. Overall taking this class and so many other labs it’s not bad I mean i don’t   usually do good but it does help you learned new things that you haven’t before and that’s   something i’m trying to expend my mindset and what I can get out of in order to help me in the   long run.
# ['Jose Castillo       Reflection     Honestly I’m only here because is part of my requirement for my major.', 'Also part of it is   for my mom I’m only here because i’m just trying to make her proud and also make myself   proud that I can get a degree.', 'Not going to lie sometimes I don’t feel like I can just because most   of the classes are hard and especially doing every class online makes it harder for me.', 'Honestly   don’t even know how long i’m going to be here it really depends how much effort in time I   actually put in all my classes.', 'Hopefully i’m able to graduated in 4 years just because I do want   to work for my master degree in the future I feel like it’s going to benefit me and especially for   my mom and family.', 'Overall taking this class and so many other labs it’s not bad I mean i don’t   usually do good but it does help you learned new things that you haven’t before and that’s   something i’m trying to expend my mindset and what I can get out of in order to help me in the   long run.']
# I am here because I am a pre-kinesiology major and it is a prerequisite for my major.  I am a pre-kinesiology major hopefully a kinesiology major next fall because I hope to be a physical therapist in the near future. I am taking this class because I am also in physics lecture and intriguing and it seemed interesting. I hope to get knowledge from this class that will better prepare myself for the kinesiology courses I will be needing to take next school year. I am trying to get all my general education courses as well as a few pre-requisite courses because I am also interested in getting a business minor, so I need to try to get everything out of the way as soon as possible to be able to graduate on time and hopefully get into a graduate physical therapy school.
# ['I am here because I am a pre-kinesiology major and it is a prerequisite for my major.', ' I am a pre-kinesiology major hopefully a kinesiology major next fall because I hope to be a physical therapist in the near future.', 'I am taking this class because I am also in physics lecture and intriguing and it seemed interesting.', 'I hope to get knowledge from this class that will better prepare myself for the kinesiology courses I will be needing to take next school year.', 'I am trying to get all my general education courses as well as a few pre-requisite courses because I am also interested in getting a business minor, so I need to try to get everything out of the way as soon as possible to be able to graduate on time and hopefully get into a graduate physical therapy school.']
# Estefan Dinarte   9/10/2020   PHYS 102     “Why Am I Here”     I am  here because I would like to fu rther my knowledge and education. My major is Kinesiology  and Physics is a pre -requisite  for m y end goal of be coming  a Physical Therapist.  I also enjoy the  team - work an d bondi ng aspect s of lab because it is a great way to make new friends an d connections. Physics  will teach me interesting and useful knowledge like motion and behavior through space and time , and  the related entities of energy and force.  Being here is also important for my growth and development.  Without educati on and a diploma to show for it,  it is difficult to find a stable job and have that financial  freedom.  All in all, I am here because it is a pre -requisite but I also enjo y the ext ra knowledge to further  enhance my brain.
# ['Estefan Dinarte   9/10/2020   PHYS 102     “Why Am I Here”     I am  here because I would like to fu rther my knowledge and education.', 'My major is Kinesiology  and Physics is a pre -requisite  for m y end goal of be coming  a Physical Therapist.', ' I also enjoy the  team - work an d bondi ng aspect s of lab because it is a great way to make new friends an d connections.', 'Physics  will teach me interesting and useful knowledge like motion and behavior through space and time , and  the related entities of energy and force.', ' Being here is also important for my growth and development.', ' Without educati on and a diploma to show for it,  it is difficult to find a stable job and have that financial  freedom.', ' All in all, I am here because it is a pre -requisite but I also enjo y the ext ra knowledge to further  enhance my brain.']
# I think the reason that I am here is to complete my physics classes. I took the lecture last   semester and I did just fine in that class, although it sucked that I had to finish that class online.   That is what screwed my grade up last minute. Other than that I don’t know why I am here other   than that. I do like physics, at least basic physics, and if I were to pursue a higher level of   physics with trigonometry and things like that, my brain would honestly explode. But taking this   level of physics isn’t too bad. I’m excited to see what is in store for this lab. I should be able to   apply what I learned from last semester into this class and maybe help some people out if they   are stuck. 5 minutes to talk about why I think I am here.. Uhh, OH I would like to be able to   apply the labs into real life especially because I think this lab would help me in my major which   is Kinesiology. I think being able to apply that into the field of Kinesiology would be huge   because we study range of motion and the movements of the body.
# ['I think the reason that I am here is to complete my physics classes.', 'I took the lecture last   semester and I did just fine in that class, although it sucked that I had to finish that class online.', '  That is what screwed my grade up last minute.', 'Other than that I don’t know why I am here other   than that.', 'I do like physics, at least basic physics, and if I were to pursue a higher level of   physics with trigonometry and things like that, my brain would honestly explode.', 'But taking this   level of physics isn’t too bad.', 'I’m excited to see what is in store for this lab.', 'I should be able to   apply what I learned from last semester into this class and maybe help some people out if they   are stuck.', '5 minutes to talk about why I think I am here..', 'Uhh, OH I would like to be able to   apply the labs into real life especially because I think this lab would help me in my major which   is Kinesiology.', 'I think being able to apply that into the field of Kinesiology would be huge   because we study range of motion and the movements of the body.']
# Why am I here? I am here in this class because it is a pre requisite for my major. I guess in the grand scheme of things I am just here on this by chance. I think I am just the sum of all these random chances and probabilities. I also think I am here based on my past experiences. If I hadn’t taken one speciﬁc class in high school by chance then I would not be pursuing the career I am right now. I also think I would not be here at this school to even be taking this class in the ﬁrst place. I think I am here from a combination of chances and choices.
# ['Why am I here?', 'I am here in this class because it is a pre requisite for my major.', 'I guess in the grand scheme of things I am just here on this by chance.', 'I think I am just the sum of all these random chances and probabilities.', 'I also think I am here based on my past experiences.', 'If I hadn’t taken one speciﬁc class in high school by chance then I would not be pursuing the career I am right now.', 'I also think I would not be here at this school to even be taking this class in the ﬁrst place.', 'I think I am here from a combination of chances and choices.']
# Milka Abdosh         Why am I here?     I believe that I am here because I want to be successful. I want to be able to support my parents   and have a career. Most people won’t want to take care of their parents but I believe I owe it to   them to be as money motivated and goal striving as possible. Taking this physics class is the   building block for my success because I need this class to graduate. I have been in school for a   while and I am looking forward to be able to start my career and travel the world (once the   pandemic is over).
# ['Milka Abdosh         Why am I here?', '    I believe that I am here because I want to be successful.', 'I want to be able to support my parents   and have a career.', 'Most people won’t want to take care of their parents but I believe I owe it to   them to be as money motivated and goal striving as possible.', 'Taking this physics class is the   building block for my success because I need this class to graduate.', 'I have been in school for a   while and I am looking forward to be able to start my career and travel the world (once the   pandemic is over).']
# Why am I here?   I am where I am due making tons of different decisions that all made sense at the time. Feeding   bad habits starting in middle school through high school, deciding to postpone getting a degree   after highschool since I didn’t have real academic interests, choosing to start in community   college to do general education classes. I used to think that there wasn’t a real place for me in   school and barely skated by in it, and now I’m making up for where I was before. At this   moment I’ve found things that interest me. Through learning about the body and how to get   stronger I’ve also found reasons to be more connected to this world and other people. By   listening to myself more I’ve been able to find a path to move forward on.
# ['Why am I here?', '  I am where I am due making tons of different decisions that all made sense at the time.', 'Feeding   bad habits starting in middle school through high school, deciding to postpone getting a degree   after highschool since I didn’t have real academic interests, choosing to start in community   college to do general education classes.', 'I used to think that there wasn’t a real place for me in   school and barely skated by in it, and now I’m making up for where I was before.', 'At this   moment I’ve found things that interest me.', 'Through learning about the body and how to get   stronger I’ve also found reasons to be more connected to this world and other people.', 'By   listening to myself more I’ve been able to find a path to move forward on.']
# Week 3 Reflection:   Why am I here?     College is a place where you can further your knowledge and learn new skills. I’m here because I   want to become either a physical therapist or an occupational therapist. In order to get there, I   need to graduate from college with a bachelor’s degree. As a kinesiology major, I need to fulfill   many prerequisites and physics is just one of them. Physics is one of the basic sciences I need to   learn about since it is useful in understanding how much force a patient is able to exert or in   measuring a range of motion.
# ['Week 3 Reflection:   Why am I here?', '    College is a place where you can further your knowledge and learn new skills.', 'I’m here because I   want to become either a physical therapist or an occupational therapist.', 'In order to get there, I   need to graduate from college with a bachelor’s degree.', 'As a kinesiology major, I need to fulfill   many prerequisites and physics is just one of them.', 'Physics is one of the basic sciences I need to   learn about since it is useful in understanding how much force a patient is able to exert or in   measuring a range of motion.']
# Patrick Bialy  Reflection #1  Why am I here?  	I am in this physics because it is a class I have to take to satisfy my major requirements. I am currently a Kinesiology major that recently switched from pre-nursing. I am pursuing this major because I have had a lot of experience with the healthcare industry, my mom being a nurse and my sister a doctor. During my countless hours volunteering at hospitals to the countless hours being admitted, I feel like I would be comfortable to pursue a career. I is a hard goal to achieve but hopefully my passion can drive me to my destination. I am currently at Sf State, in the beautiful city of San Francisco. I chose this school because of the city and the constant chilly weather. On my free time, I am a pretty avid photographer and the city is perfect for just that. This is why I am here.
# ['Patrick Bialy  Reflection #1  Why am I here?', ' \tI am in this physics because it is a class I have to take to satisfy my major requirements.', 'I am currently a Kinesiology major that recently switched from pre-nursing.', 'I am pursuing this major because I have had a lot of experience with the healthcare industry, my mom being a nurse and my sister a doctor.', 'During my countless hours volunteering at hospitals to the countless hours being admitted, I feel like I would be comfortable to pursue a career.', 'I is a hard goal to achieve but hopefully my passion can drive me to my destination.', 'I am currently at Sf State, in the beautiful city of San Francisco.', 'I chose this school because of the city and the constant chilly weather.', 'On my free time, I am a pretty avid photographer and the city is perfect for just that.', 'This is why I am here.']
# Why am I here? I'm currently enrolled in both physics lecture and lab. I'm here in physics lab because I need to take this lab for my requirement for Kinesiology . Since this is a broad paper about why we are here, I'm not sure if we’re supposed to be talking about here as in physics lab or here as in what our purpose in this world is. But since I'm not sure, I’ll talk about both. As I mentioned earlier I’m here because I need to take physics in as a course for my Kinesiology degree. Now talking about in general, I feel like my purpose in this world is to make a positive impact on people’ s lives. One of the reasons why I feel like I’m here in this world is to spread love and positivity . I feel like I’m here to make the people I love and the people around me live their life to the fullest. Another reason why I feel like I’m here is to further my education and career . To keep striving at being a better person each and every day . Overall, I feel like I have many reasons and ways to answer “why am I here” but those are just a few to mention.
# ['Why am I here?', "I'm currently enrolled in both physics lecture and lab.", "I'm here in physics lab because I need to take this lab for my requirement for Kinesiology .", "Since this is a broad paper about why we are here, I'm not sure if we’re supposed to be talking about here as in physics lab or here as in what our purpose in this world is.", "But since I'm not sure, I’ll talk about both.", 'As I mentioned earlier I’m here because I need to take physics in as a course for my Kinesiology degree.', 'Now talking about in general, I feel like my purpose in this world is to make a positive impact on people’ s lives.', 'One of the reasons why I feel like I’m here in this world is to spread love and positivity .', 'I feel like I’m here to make the people I love and the people around me live their life to the fullest.', 'Another reason why I feel like I’m here is to further my education and career .', 'To keep striving at being a better person each and every day .', 'Overall, I feel like I have many reasons and ways to answer “why am I here” but those are just a few to mention.']
# Austin Noriega   9/10/2020   Phys 102   Reflection #1: Why am I here?   I am here for a multitude of reasons. I think firstly that I had a good time learning   physics in high school, so I already had an interest in this so I can also complete my   requirements to graduate. But for San Francisco State as a whole, the reason that I   applied to attend was that I needed something different from the consistencies and the   same things that I had left in San Jose. Dorming at San Francisco gave me an   opportunity to explore more of the things around me, and myself. I went to college so I   get an education about the things that I will need for my future careers inside of the   business field. As a first generation college student, my passing through college is not   only for me, but for my family as well. I am here for my growth and learning so I can be   better than I was before this class.
# ['Austin Noriega   9/10/2020   Phys 102   Reflection #1: Why am I here?', '  I am here for a multitude of reasons.', 'I think firstly that I had a good time learning   physics in high school, so I already had an interest in this so I can also complete my   requirements to graduate.', 'But for San Francisco State as a whole, the reason that I   applied to attend was that I needed something different from the consistencies and the   same things that I had left in San Jose.', 'Dorming at San Francisco gave me an   opportunity to explore more of the things around me, and myself.', 'I went to college so I   get an education about the things that I will need for my future careers inside of the   business field.', 'As a first generation college student, my passing through college is not   only for me, but for my family as well.', 'I am here for my growth and learning so I can be   better than I was before this class.']
# Reflection  #1  “Why Am I Here? ” N. Velez      I’m quite literally here in this class because I took physic s before but  didn’t  pass with a  grade I wante d. The physic s class I previousl y took was Phys 111, and our tea cher was not great.  To put it simply, she could not teac h if her life depended on it. She had a very thick accent,  which made it very hard to understand her, b ut she was also very unor ganized , writing randomly  on the b oard and jumping around with her topics. I can go on for a while  abou t her sub -par  teaching ; to put it in perspective, the class st arted with about 50 students, and event ually it  trickled down to  about 15 by the 2nd half of the seme ster. I somehow still passed the class with a  D even aft er I didn’t show up for th e last three week s of class or the final , which tells me the  school threw a massive curve for the students . I’m not  happy with the D grade and think it was  unfair th at I got such a bad learning exper ience, so here I am taking Phys 101 /102 to replace it.
# ['Reflection  #1  “Why Am I Here?', '” N. Velez      I’m quite literally here in this class because I took physic s before but  didn’t  pass with a  grade I wante d.', 'The physic s class I previousl y took was Phys 111, and our tea cher was not great.', ' To put it simply, she could not teac h if her life depended on it.', 'She had a very thick accent,  which made it very hard to understand her, b ut she was also very unor ganized , writing randomly  on the b oard and jumping around with her topics.', 'I can go on for a while  abou t her sub -par  teaching ; to put it in perspective, the class st arted with about 50 students, and event ually it  trickled down to  about 15 by the 2nd half of the seme ster.', 'I somehow still passed the class with a  D even aft er I didn’t show up for th e last three week s of class or the final , which tells me the  school threw a massive curve for the students .', 'I’m not  happy with the D grade and think it was  unfair th at I got such a bad learning exper ience, so here I am taking Phys 101 /102 to replace it.']
# Elena Mena  “Why am I here”   I am here because this is a required class for my major. I am a kinesiology major and physics is one of the required classes to take. To be frank, I am not very interested in physics but I hope that changes by the end of the semester. I have heard that physics is not as hard as some of the previous science classes I have had to take for my major. In that case, I am very relieved. My intentions with this class is to actually learn and pass with an A. I am very dedicated to my studies. I always do the best of my capabilities yet I do allow myself to take a breath, when needed. I am passionate about my end goal with my degree but I do not think I am specifically passionate about physics. I have a general idea of the concept of physics but I am sure throughout this class, that will change.
# ['Elena Mena  “Why am I here”   I am here because this is a required class for my major.', 'I am a kinesiology major and physics is one of the required classes to take.', 'To be frank, I am not very interested in physics but I hope that changes by the end of the semester.', 'I have heard that physics is not as hard as some of the previous science classes I have had to take for my major.', 'In that case, I am very relieved.', 'My intentions with this class is to actually learn and pass with an A. I am very dedicated to my studies.', 'I always do the best of my capabilities yet I do allow myself to take a breath, when needed.', 'I am passionate about my end goal with my degree but I do not think I am specifically passionate about physics.', 'I have a general idea of the concept of physics but I am sure throughout this class, that will change.']
# Jordaan Render Phys 102 Reflection 1 Why am I here?  I am here because I want to receive a quality education around a new group of people and further my academic career as well as personal character development. I chose SFSU because it is a new school in a new city and I thoroughly enjoy meeting new people. I was born in Germany and grew up across the United States on different military bases. Moving around a lot made it easier for me to become an adaptable person and see the culture differences within our own country. I would like to use my background in a way that allows me to me travel and connect with many different people from differing cultures and really gain a broader view on life. I started my college career as a political science major because I used to aspire to be a politician, but later decided that was not the path for me. I subsequently chose computer science because the sciences have always been fascinating to me and I love building and overclocking computers, but after studying CS for a year and turning one of my favorite hobbies into something I have to work hard at, my passion started to die for that field. Luckily, I was able to easily switch to health sciences and I have been pretty content with where I am at so far. My current path is to become a Physical Therapist because I enjoy communicating with and helping people and as a PT, I will have many opportunities to travel for work. In conclusion, I would say I am here for a quality education and to meet new people from different backgrounds.
# ['Jordaan Render Phys 102 Reflection 1 Why am I here?', ' I am here because I want to receive a quality education around a new group of people and further my academic career as well as personal character development.', 'I chose SFSU because it is a new school in a new city and I thoroughly enjoy meeting new people.', 'I was born in Germany and grew up across the United States on different military bases.', 'Moving around a lot made it easier for me to become an adaptable person and see the culture differences within our own country.', 'I would like to use my background in a way that allows me to me travel and connect with many different people from differing cultures and really gain a broader view on life.', 'I started my college career as a political science major because I used to aspire to be a politician, but later decided that was not the path for me.', 'I subsequently chose computer science because the sciences have always been fascinating to me and I love building and overclocking computers, but after studying CS for a year and turning one of my favorite hobbies into something I have to work hard at, my passion started to die for that field.', 'Luckily, I was able to easily switch to health sciences and I have been pretty content with where I am at so far.', 'My current path is to become a Physical Therapist because I enjoy communicating with and helping people and as a PT, I will have many opportunities to travel for work.', 'In conclusion, I would say I am here for a quality education and to meet new people from different backgrounds.']
# Why am I here?     I believe that I am here to help others since I have always grown up taking care of my   grandparents and siblings. I always knew that I had a strong passion for inspiring and motivating   others to do their best, but I never truly had an idea of what career path I wanted to take. After   taking different classes in community college, I found myself very interested in the Kinesiology   field and I remember watching a short clip in class about the different career paths. When the   video showed what a day would look like as an occupational therapist, I was truly inspired by   her work and how much her patients meant to her. Right away, I did more research on what an   OT does and ever since, I continued taking more classes and hope to attend OT grad school   after I graduate with a BS in Kinesiology. I believe that I am here to also make my parents proud   and most importantly, to make myself proud. I also want to have a family in the future and be   able to take care and provide for them, so I want to have a good job that will help me become   financially stable in the near future.
# ['Why am I here?', '    I believe that I am here to help others since I have always grown up taking care of my   grandparents and siblings.', 'I always knew that I had a strong passion for inspiring and motivating   others to do their best, but I never truly had an idea of what career path I wanted to take.', 'After   taking different classes in community college, I found myself very interested in the Kinesiology   field and I remember watching a short clip in class about the different career paths.', 'When the   video showed what a day would look like as an occupational therapist, I was truly inspired by   her work and how much her patients meant to her.', 'Right away, I did more research on what an   OT does and ever since, I continued taking more classes and hope to attend OT grad school   after I graduate with a BS in Kinesiology.', 'I believe that I am here to also make my parents proud   and most importantly, to make myself proud.', 'I also want to have a family in the future and be   able to take care and provide for them, so I want to have a good job that will help me become   financially stable in the near future.']
# Why am I here? I am here in Physics 102 to complete as one of my requirements towards my major. Even though Physics isn’t particularly my favorite go to subject, I am finding it more and more interesting as we move forward. I am here to accomplish the classes I need in order to be successful in my career which will be Kinesiology. I am here to learn about the body and movements in order to help others become healthier and stronger. I am here at this university to help me further my education and to be able to have bachelor’s degree to hold a successful job. Those are some of the reasons on why I am here and why I am enrolled in taking the Physics 102 lab.   -Rebekah Schroeder
# ['Why am I here?', 'I am here in Physics 102 to complete as one of my requirements towards my major.', 'Even though Physics isn’t particularly my favorite go to subject, I am finding it more and more interesting as we move forward.', 'I am here to accomplish the classes I need in order to be successful in my career which will be Kinesiology.', 'I am here to learn about the body and movements in order to help others become healthier and stronger.', 'I am here at this university to help me further my education and to be able to have bachelor’s degree to hold a successful job.', 'Those are some of the reasons on why I am here and why I am enrolled in taking the Physics 102 lab.', '  -Rebekah Schroeder']
# The reason why I’m in this Physics lab is because I need the lab part of this course. Hopefully I’ll   learn something useful that I can use later in the future or present. I think labs are about looking   in depth after having a result or data in order to prove your answer, so by taking this lab I can   learn to elaborate more and expand my thoughts. It's also a new learning experience since it's   an online lab course where we get to use different methods.
# ['The reason why I’m in this Physics lab is because I need the lab part of this course.', 'Hopefully I’ll   learn something useful that I can use later in the future or present.', 'I think labs are about looking   in depth after having a result or data in order to prove your answer, so by taking this lab I can   learn to elaborate more and expand my thoughts.', "It's also a new learning experience since it's   an online lab course where we get to use different methods."]
# I am here because this class is a prerequisite for my Kinesiology major. I don’t really know much   about physics and the last physics class I took was in middle school. I’m here because I want to   have an education and build my career/ find my passion. I’m here because I have to be. I’m   actually not sure why I’m here. I’m here because many people my age are in college working   towards their dream jobs but I feel like I’m just here. Sometimes, I have a quarter-life crisis and   I’m not even 25 years old yet. I’ve been having a quarter-life crisis since I was in high school.   People tell me that I’m still young and that I’ll figure things out soon but I don’t like not   knowing what’s going to happen in my future. I don’t even know what my passion is. I enjoy   going to the gym which is why I’m a Kinesiology major. I also don’t find other majors   interesting. I think I want to go into occupational therapy but I don’t know if I’m even able to be   accepted by a graduate school. I can’t see myself as anything and I’m just stuck or I’m actually   just not sure where I’m going or if I’m going down the right path. I’m kind of confused. I’m here   because my sisters are also here and they mean a lot to me.
# ['I am here because this class is a prerequisite for my Kinesiology major.', 'I don’t really know much   about physics and the last physics class I took was in middle school.', 'I’m here because I want to   have an education and build my career/ find my passion.', 'I’m here because I have to be.', 'I’m   actually not sure why I’m here.', 'I’m here because many people my age are in college working   towards their dream jobs but I feel like I’m just here.', 'Sometimes, I have a quarter-life crisis and   I’m not even 25 years old yet.', 'I’ve been having a quarter-life crisis since I was in high school.', '  People tell me that I’m still young and that I’ll figure things out soon but I don’t like not   knowing what’s going to happen in my future.', 'I don’t even know what my passion is.', 'I enjoy   going to the gym which is why I’m a Kinesiology major.', 'I also don’t find other majors   interesting.', 'I think I want to go into occupational therapy but I don’t know if I’m even able to be   accepted by a graduate school.', 'I can’t see myself as anything and I’m just stuck or I’m actually   just not sure where I’m going or if I’m going down the right path.', 'I’m kind of confused.', 'I’m here   because my sisters are also here and they mean a lot to me.']
# Why am I here?     I am here at school because I want to become a nurse, and that requires a license and degree. I   am currently a kinesiology major so I can transfer into the nursing program either here or at   another school. I feel passionate about helping others that if I could, I would want to be a doctor.   I love the excitement, the knowledge, and the help I would put towards others as a nurse.   The general reason towards why I’m here is because of my parents. They put me in this world   even though my mom always said she could have dropped me off at the fire department. She was   kidding. I love my family and my life, and I don’t regret being where I am at. I always wanted to   die doing something heroic and making my last words something a long the lines of “I got this”.
# ['Why am I here?', '    I am here at school because I want to become a nurse, and that requires a license and degree.', 'I   am currently a kinesiology major so I can transfer into the nursing program either here or at   another school.', 'I feel passionate about helping others that if I could, I would want to be a doctor.', '  I love the excitement, the knowledge, and the help I would put towards others as a nurse.', '  The general reason towards why I’m here is because of my parents.', 'They put me in this world   even though my mom always said she could have dropped me off at the fire department.', 'She was   kidding.', 'I love my family and my life, and I don’t regret being where I am at.', 'I always wanted to   die doing something heroic and making my last words something a long the lines of “I got this”.']
# Ahries Julian                                           Physics 102 reflection 1     Why am I here? I am here attending SFSU to achieve higher education but also to hopefully find   a career. One reason that I am taking physics is because I need to for my major courses to   graduate and achieve my bachelor of science degree in exercise science and movement   science. After getting my bachelor of science degree in kinesiology, I plan to hopefully apply for   physical therapy school or occupational therapy school. My mind has not been made up yet if I   wanted to go to medical school etc. Since I am a personal trainer and have been coaching   clients in different populations for about 4 ½ years, I feel this is my passion and my calling.   Anything can happen though till I graduate so I do have time to reflect and process everything in   my mind to make the best decision for myself and future.
# ['Ahries Julian                                           Physics 102 reflection 1     Why am I here?', 'I am here attending SFSU to achieve higher education but also to hopefully find   a career.', 'One reason that I am taking physics is because I need to for my major courses to   graduate and achieve my bachelor of science degree in exercise science and movement   science.', 'After getting my bachelor of science degree in kinesiology, I plan to hopefully apply for   physical therapy school or occupational therapy school.', 'My mind has not been made up yet if I   wanted to go to medical school etc.', 'Since I am a personal trainer and have been coaching   clients in different populations for about 4 ½ years, I feel this is my passion and my calling.', '  Anything can happen though till I graduate so I do have time to reflect and process everything in   my mind to make the best decision for myself and future.']
# Why am I here ?     I am here in this class at least to gain more knowledge on a science subject that I am very  limited in. I want to learn more about how the world moves and the forces in it. Being a  kinesiology major we study the bodies and how they move. When a body is in motion many  forces are acting upon them. This class hopefully will help me understand those forces and  allow me to better help a patient. I really am I here because it is a requirement for my major  otherwise, I would have avoided this if I am being complet ely honest. So far I like the lecture  class because it has some real world applications. The lab I enjoy as well because we have the  breakout groups and they let me work with other students, makes me almost feel like I am in  class again.
# ['Why am I here ?', '    I am here in this class at least to gain more knowledge on a science subject that I am very  limited in.', 'I want to learn more about how the world moves and the forces in it.', 'Being a  kinesiology major we study the bodies and how they move.', 'When a body is in motion many  forces are acting upon them.', 'This class hopefully will help me understand those forces and  allow me to better help a patient.', 'I really am I here because it is a requirement for my major  otherwise, I would have avoided this if I am being complet ely honest.', 'So far I like the lecture  class because it has some real world applications.', 'The lab I enjoy as well because we have the  breakout groups and they let me work with other students, makes me almost feel like I am in  class again.']
# I had initially gone into STEM because I am good at it and thought that it would be a waste not to, but as I progressed into my major, it has become more clear that I am actually interested in the subject matter and I enjoy doing well in it. I grew up obsessed with comic book movies, and seeing real world applications of the technology in these films is also very rewarding and interesting to know that the concepts and studying in my classes can be combined and reworked into something that can truly benefit society. I am still dreading the difficulty of my upcoming classes, but I am ready for the challenge and hope to come out on the other side much smarter and ready to apply this knowledge for good.
# ['I had initially gone into STEM because I am good at it and thought that it would be a waste not to, but as I progressed into my major, it has become more clear that I am actually interested in the subject matter and I enjoy doing well in it.', 'I grew up obsessed with comic book movies, and seeing real world applications of the technology in these films is also very rewarding and interesting to know that the concepts and studying in my classes can be combined and reworked into something that can truly benefit society.', 'I am still dreading the difficulty of my upcoming classes, but I am ready for the challenge and hope to come out on the other side much smarter and ready to apply this knowledge for good.', '']
# I’m in this field first of all because I fell in love with astronomy. I loved learning about the stars, planets, Earth’s atmosphere, dark matter, the search for intelligent life...all of the subjects in ASTR 115 I just completely fell in love with and I thought, I could study this for the rest of my life. So that’s the first reason I decided to major in astrophysics. In addition, in general there’s something I’ve always respected about the STEM fields, and that’s the search for knowledge with pure motivations, for knowledge’s sake alone and not for other greedier motives. Obviously capitalist greed infiltrates scientific inquiries the same way it appears in any other field, and I’m not trying to put the scientists of the world on some noble pedestal. But most scientists are in their fields not for money or selfish reasons, but because they have a pure interest in their subjects and they want to learn as much as they can, and share that knowledge with others. Not to be cliche, but I think learning is one of the things that makes us human, and I respect and want to be in the STEM fields because of that.
# ['I’m in this field first of all because I fell in love with astronomy.', 'I loved learning about the stars, planets, Earth’s atmosphere, dark matter, the search for intelligent life...all of the subjects in ASTR 115 I just completely fell in love with and I thought, I could study this for the rest of my life.', 'So that’s the first reason I decided to major in astrophysics.', 'In addition, in general there’s something I’ve always respected about the STEM fields, and that’s the search for knowledge with pure motivations, for knowledge’s sake alone and not for other greedier motives.', 'Obviously capitalist greed infiltrates scientific inquiries the same way it appears in any other field, and I’m not trying to put the scientists of the world on some noble pedestal.', 'But most scientists are in their fields not for money or selfish reasons, but because they have a pure interest in their subjects and they want to learn as much as they can, and share that knowledge with others.', 'Not to be cliche, but I think learning is one of the things that makes us human, and I respect and want to be in the STEM fields because of that.']
# I wanted to go into the STEM field because I just happened to be a bit more proficient at the course material than other subjects. I was able to handle the course work during middle and high school, and the subject matter made was more practical and made more sense to me than other subjects. I knew that I wanted to go into engineering but I didn't know which specific field until I entered college where I just chose Mechanical engineering. Even if I switched to another field, I would still need most of the earlier courses anyways, so I was confident in my choice. I am hoping that I will be able to full grasp the material so that I won't have to look back on my college days and wished that I had put in more effort or tried harder. I am also hoping that I can understand the world around me a bit better and that I enjoy working in the STEM field so that the work I put in towards my major wouldn't be a waste.
# ...
# Honestly I am here just for the credits i need to get into my major. I am pre-kin and need to take physics in order to finish off my pre-requisites and make sure I do get accepted by the Kinesiology Association. But if I could think of another reason as to why I am here in a Kinesiology Lab taking the lecture as well, spending 4 days a week learning physics, it would be to understand how things in this world work and they interact with each other. Give reasons as to why this works and this doesn't, what is possible in our universe. Physics happens to us all the time and to know how it works would be beneficial in solving a problem when Im older or now. But regardless, I need the credits to pass and continue my path in college and in life while also gaining new knowledge that would otherwise help in everyday.
# ['Honestly I am here just for the credits i need to get into my major.', 'I am pre-kin and need to take physics in order to finish off my pre-requisites and make sure I do get accepted by the Kinesiology Association.', 'But if I could think of another reason as to why I am here in a Kinesiology Lab taking the lecture as well, spending 4 days a week learning physics, it would be to understand how things in this world work and they interact with each other.', "Give reasons as to why this works and this doesn't, what is possible in our universe.", 'Physics happens to us all the time and to know how it works would be beneficial in solving a problem when Im older or now.', 'But regardless, I need the credits to pass and continue my path in college and in life while also gaining new knowledge that would otherwise help in everyday.']
# I am here in this physics lab class because it is part of my prerequisites for my major, biology with a focus on physiology. Physics can provide me with a basic understanding in how things work and move. What I'm planning to learn in this class is how things move and to be able to apply it to the real world, a.k.a., driving a car or a plane flying. Also after this class, I will be to read and understand the graph of motion, velocity, and acceleration and now what they mean. As well as, vectors and their importance to the world of physics. I feel like knowing all this information can be beneficial to the real world and my future career in medicine. It can give me a wider understanding of atoms in a molecular level once we get to it and how I can alter them for the benefit of others.
# ['I am here in this physics lab class because it is part of my prerequisites for my major, biology with a focus on physiology.', 'Physics can provide me with a basic understanding in how things work and move.', "What I'm planning to learn in this class is how things move and to be able to apply it to the real world, a.k.a., driving a car or a plane flying.", 'Also after this class, I will be to read and understand the graph of motion, velocity, and acceleration and now what they mean.', 'As well as, vectors and their importance to the world of physics.', 'I feel like knowing all this information can be beneficial to the real world and my future career in medicine.', 'It can give me a wider understanding of atoms in a molecular level once we get to it and how I can alter them for the benefit of others.', '']
# I am here because I need to take physics as a GE class and potentially use the skills I learn in this class for future classes. So far I am enjoying this lab and learning new things about physics that I never knew before. It’s interesting that there are so many things I do in everyday life that relates to physics and I never realized these little things until now. Physics in general is a fascinating topic and answers many questions about us and our planet and I feel like most of our questions can be answered because of physics. I am looking forward to see what else I can learn from this class from here on out.
# ['I am here because I need to take physics as a GE class and potentially use the skills I learn in this class for future classes.', 'So far I am enjoying this lab and learning new things about physics that I never knew before.', 'It’s interesting that there are so many things I do in everyday life that relates to physics and I never realized these little things until now.', 'Physics in general is a fascinating topic and answers many questions about us and our planet and I feel like most of our questions can be answered because of physics.', 'I am looking forward to see what else I can learn from this class from here on out.']
# I know my purpose for being here, and hopefully I fulfill it while I am. I am a student in university for a reason, that reason being to be able to succeed in my future career and lifestyle. I will definitely fulfill my schooling requirements so hopefully I can be the best I can be in my career. I want to be in the medical field for animal care, and that is also for a good reason. I want to make a positive difference in my community and help many families. I am here in this class to travel my path to that point in my life. I know I am in this class for a couple of reasons, one being that it is a requirement for me to move on with my major and overall my field of study, so I can be who I was meant to be. I will try my hardest to be the best I can be while I’m here.
# ['I know my purpose for being here, and hopefully I fulfill it while I am.', 'I am a student in university for a reason, that reason being to be able to succeed in my future career and lifestyle.', 'I will definitely fulfill my schooling requirements so hopefully I can be the best I can be in my career.', 'I want to be in the medical field for animal care, and that is also for a good reason.', 'I want to make a positive difference in my community and help many families.', 'I am here in this class to travel my path to that point in my life.', 'I know I am in this class for a couple of reasons, one being that it is a requirement for me to move on with my major and overall my field of study, so I can be who I was meant to be.', 'I will try my hardest to be the best I can be while I’m here.', '']
# Why am I here? I am here because I am a general biology major at San Francisco State and this is one of my requirements for my major. I am a General Biology major because I want to go to dental school and become an orthodontist. I used to struggle with Physics in high school and understanding it. It is important for me to understand the concepts of Physics, which will help in other parts of life as well. It is good for me to know about physics and other sciences to help me in my path to my future career. Becoming an orthodontist is a very major part in my future and understanding sciences will help me lead to that path.
# ['Why am I here?', 'I am here because I am a general biology major at San Francisco State and this is one of my requirements for my major.', 'I am a General Biology major because I want to go to dental school and become an orthodontist.', 'I used to struggle with Physics in high school and understanding it.', 'It is important for me to understand the concepts of Physics, which will help in other parts of life as well.', 'It is good for me to know about physics and other sciences to help me in my path to my future career.', 'Becoming an orthodontist is a very major part in my future and understanding sciences will help me lead to that path.', '']
# I am here so that I can learn about physics. My primary goal is to understand how the universe works and function. I also taking this class because I want to go into graduate school which is a requirement for this class. Physics is an interesting concept that I often overlook due to the equations and complex idea behind it. I want to learn more about the everyday and basic things we do that has to do with physics. Examples such as how far, long and etc something is. The reason for me being in the class is to understand the different mechanics of the world and learn from it. The reason being of physics is know how the world functions and works. In conclusion, I am here to learn more about physics , how to apply it in my everyday life and understand why the world works the way it is.
# ['I am here so that I can learn about physics.', 'My primary goal is to understand how the universe works and function.', 'I also taking this class because I want to go into graduate school which is a requirement for this class.', 'Physics is an interesting concept that I often overlook due to the equations and complex idea behind it.', 'I want to learn more about the everyday and basic things we do that has to do with physics.', 'Examples such as how far, long and etc something is.', 'The reason for me being in the class is to understand the different mechanics of the world and learn from it.', 'The reason being of physics is know how the world functions and works.', 'In conclusion, I am here to learn more about physics , how to apply it in my everyday life and understand why the world works the way it is.']
# I am here because I’m trying to graduate with a degree in Kinesiology. I’m taking this class because it is one of my pre-requisites. I also chose this physics class over the other ones because I heard this would look better when I apply for graduate school. I want to go to physical therapy school. Also I need these units so that I’m on pace to graduate in four years. I’m at San Francisco State because it is close to home and I heard they work closely with UCSF for graduate school and I thought that would be good if I wanted to get into UCSF after graduating. Also I knew a couple people who were attending this school already and that swayed me to come here. I also just wanted to attend a 4 year college right away and San Francisco State was one of my options higher on my list
# ['I am here because I’m trying to graduate with a degree in Kinesiology.', 'I’m taking this class because it is one of my pre-requisites.', 'I also chose this physics class over the other ones because I heard this would look better when I apply for graduate school.', 'I want to go to physical therapy school.', 'Also I need these units so that I’m on pace to graduate in four years.', 'I’m at San Francisco State because it is close to home and I heard they work closely with UCSF for graduate school and I thought that would be good if I wanted to get into UCSF after graduating.', 'Also I knew a couple people who were attending this school already and that swayed me to come here.', 'I also just wanted to attend a 4 year college right away and San Francisco State was one of my options higher on my list']
# I am here to learn how physics works, how motion and forces correlate to our daily lives. This is my first time ever taking physics, which is pretty scary to me but very interesting at the same time. In high school, we were not offered a physics class. I come from a low income neighborhood that does not offer the best education. Taking classes that I have never taken before in highschool frightens me. I'm Taking this class for my biology major, so I can move on to my next classes and graduate SFSU. I am here to learn physics, to understand the concept of physics and to eventually teach others who do not understand physics. My main goal out of this class is to understand the material well and succeed in this class. I am aiming to earn an A in this class and move on to the next classes knowing physics.
# ['I am here to learn how physics works, how motion and forces correlate to our daily lives.', 'This is my first time ever taking physics, which is pretty scary to me but very interesting at the same time.', 'In high school, we were not offered a physics class.', 'I come from a low income neighborhood that does not offer the best education.', 'Taking classes that I have never taken before in highschool frightens me.', "I'm Taking this class for my biology major, so I can move on to my next classes and graduate SFSU. I am here to learn physics, to understand the concept of physics and to eventually teach others who do not understand physics.", 'My main goal out of this class is to understand the material well and succeed in this class.', 'I am aiming to earn an A in this class and move on to the next classes knowing physics.']
# I am here because there are so many things to accomplish, yet there is so little time. I am here to be the best or at least a better version of me. My purpose is to get the most out of life. I truly believe that I am meant to be a successful individual. The good thing is that everyone has their own definition of success, but mine will be reliant upon whether or not I can go above and beyond the goals that I have set for myself. I go to school because I only see one career path for myself. My purpose is to be a doctor and help change lives, whether I am getting the recognition for it or not. I am in this class because it is a requirement for my major. Obviously it can help me further my education in the field of science and help prepare me for future courses. Even though I don't understand some of the concepts, I do like physics. I just need a physics book for dummies.
# ['I am here because there are so many things to accomplish, yet there is so little time.', 'I am here to be the best or at least a better version of me.', 'My purpose is to get the most out of life.', 'I truly believe that I am meant to be a successful individual.', 'The good thing is that everyone has their own definition of success, but mine will be reliant upon whether or not I can go above and beyond the goals that I have set for myself.', 'I go to school because I only see one career path for myself.', 'My purpose is to be a doctor and help change lives, whether I am getting the recognition for it or not.', 'I am in this class because it is a requirement for my major.', 'Obviously it can help me further my education in the field of science and help prepare me for future courses.', "Even though I don't understand some of the concepts, I do like physics.", 'I just need a physics book for dummies.']
# I am currently taking Physics 112 for many reasons. My main reason for taking this class is to prepare myself for my future studies and eventually my future career goals. After receiving my bachelor’s degree I hope to continue on to medical school, where I will eventually become a doctor. Physics will be very helpful in real-life situations that I may come across in the medical field. The physics lab specifically is showing me isolated scenarios and allowing me to analyze them so that I can fully understand them when I come across them in real life. An example of me using this once I become a doctor is if my patient was in a car accident. If I understand the mechanics of the physics behind a car accident, I will be able to better assist my patients and help them to the best of my ability. I am excited to continue with this lab and continue to notice these physics concepts throughout my day to day life.
# ['I am currently taking Physics 112 for many reasons.', 'My main reason for taking this class is to prepare myself for my future studies and eventually my future career goals.', 'After receiving my bachelor’s degree I hope to continue on to medical school, where I will eventually become a doctor.', 'Physics will be very helpful in real-life situations that I may come across in the medical field.', 'The physics lab specifically is showing me isolated scenarios and allowing me to analyze them so that I can fully understand them when I come across them in real life.', 'An example of me using this once I become a doctor is if my patient was in a car accident.', 'If I understand the mechanics of the physics behind a car accident, I will be able to better assist my patients and help them to the best of my ability.', 'I am excited to continue with this lab and continue to notice these physics concepts throughout my day to day life.']

# %%
sentence_level_theme_datasets["Navigational Plus"]

for index, val in sentence_level_theme_datasets["Familial Plus"].iterrows():
   
    text = val['Essay: Why I am here?'].rstrip('\n\r')
    print(text)
    # Split the paragraphs into sentences using sent_tokenize from nltk
    temp_text = custom_sent_tokenizer(text)

    print(temp_text)
    break
# Out:
# Holly Enrile PHYSICS LAB Reﬂection#1 Sept. 10, 2020 I am here because it is a requirement for my major and I think Physics is a really cool subject to learn. To have knowledge about the way things work and relate to each other is a powerful skill.  In general, I’m in school because I want to make my parents proud and break the generational cycle. I will be ﬁrst generation university graduate. I am also a mother of 2 who I want to set a good example for and that hard work does and will pay oﬀ. There will be many obstacles, especially during this time with all the stuﬀ going in the world today but with grit and growth mindsets, we all can persevere and get through it.
# ['Holly Enrile PHYSICS LAB Reﬂection#1 Sept.', '10, 2020 I am here because it is a requirement for my major and I think Physics is a really cool subject to learn.', 'To have knowledge about the way things work and relate to each other is a powerful skill.', ' In general, I’m in school because I want to make my parents proud and break the generational cycle.', 'I will be ﬁrst generation university graduate.', 'I am also a mother of 2 who I want to set a good example for and that hard work does and will pay oﬀ.', 'There will be many obstacles, especially during this time with all the stuﬀ going in the world today but with grit and growth mindsets, we all can persevere and get through it.']

# %%
processed_theme_datasets = {}

for i in theme_names: #skipping Attainment because we already did it
    print("Working on " + i)
    processed_name = f"{i}_processed_sentence_df"
    processed_theme_datasets[i] = process_sentences_for_theme(sentence_level_theme_datasets[i], i)
# Out:
# Working on Aspirational Plus
# Working on Familial Plus
# Working on Navigational Plus
# Working on Social Plus
# Working on Resistance Plus

# %%
sentence_level_theme_datasets["Navigational"]["Essay: Why I am here?"][565]
# Out:
# "I am here to learn the basics of physics through experiments, also to graduate as the first one in my family from a college university. This should help me in the future because it is for my major requirement for kinesiology. I am also enrolled in the physics lecture. Physics is in everyday life so this class will come in handy. Currently I'm learning conversions which I am bad at. I wish to improve my math skills and conversion skills. This class will prepare me for upper division classes, even though its my last physics class, it should come in handy in everyday problem solving. For example if I ever need to calculate how much gas I need to pump in my car. I can calculate it with money, gallons, and miles. So this class will enhance my problem solving skills right now in life, and later in life. I am here to learn.†"

# %%
from utils.text_cleaner import clean_text

# %%
for k,v in processed_theme_datasets.items():
    print(k, len(v))
# Out:
# Aspirational Plus 5137
# Familial Plus 1205
# Navigational Plus 5006
# Social Plus 1724
# Resistance Plus 994

# %%
processed_theme_datasets["Familial Plus"]
# Out:
#                                                sentence label  \
# 0              holly enrile physics lab reection1 sept.     0
# 1     10, 2020 i am here because it is a requirement...     0
# 2     to have knowledge about the way things work an...     0
# 3     in general, im in school because i want to mak...     0
# 4         i will be rst generation university graduate.     0
# ...                                                 ...   ...
# 1200  i am here to enjoy life as well and learn as m...     0
# 1201  i am here to learn from my peers and teachers ...     0
# 1202  i feel like i am also here to teach others my ...     0
# 1203  i believe that everyone in the world can learn...     0
# 1204  finally, i am here to love, laugh, and share l...     0
#
#                                                  phrase
# 0     [In general, Im in school because I want to ma...
# 1     [In general, Im in school because I want to ma...
# 2     [In general, Im in school because I want to ma...
# 3     [In general, Im in school because I want to ma...
# 4     [In general, Im in school because I want to ma...
# ...                                                 ...
# 1200  [I am here to excel in school and make my pare...
# 1201  [I am here to excel in school and make my pare...
# 1202  [I am here to excel in school and make my pare...
# 1203  [I am here to excel in school and make my pare...
# 1204  [I am here to excel in school and make my pare...
#
# [1205 rows x 3 columns]

# %%
aspirational_processed_sentence_df = processed_theme_datasets["Aspirational"]
aspirational_processed_sentence_df.to_csv("")
# Out:
#                                                sentence label  \
# 0                                        why am i here?     0
# 1       well why does anyone pursue a higher education?     0
# 2     to better one self and be able to succeed late...     1
# 3     ever since i was little i wanted to be a docto...     0
# 4     i always wanted to be able to help people and ...     1
# ...                                                 ...   ...
# 3031  i want to better myself, improve myself in eve...     1
# 3032  i have no problems applying myself when it com...     0
# 3033  grow mentally so that i can apply more physica...     0
# 3034  use what i learn and apply it in whatever care...     0
# 3035  the more i learn the more opportunities are av...     0
#
#                                                  phrase
# 0     [to better one self and be able to succeed lat...
# 1     [to better one self and be able to succeed lat...
# 2     [to better one self and be able to succeed lat...
# 3     [to better one self and be able to succeed lat...
# 4     [to better one self and be able to succeed lat...
# ...                                                 ...
# 3031  [I want to be able to apply my knowledge to my...
# 3032  [I want to be able to apply my knowledge to my...
# 3033  [I want to be able to apply my knowledge to my...
# 3034  [I want to be able to apply my knowledge to my...
# 3035  [I want to be able to apply my knowledge to my...
#
# [3036 rows x 3 columns]

# %%
for k,v in processed_essay_theme_datasets.items():
    print(k, len(v))
    v.to_csv(f"/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/single_theme_essay_level/{k}_essay_level_batch_1_jaccard.csv", index=False)
# Out:
# Navigational 589
# Perseverance 589
# Resistance 589

# %%
for k,v in processed_theme_datasets.items():
    print(k, len(v))
    v.to_csv(f"/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/single_theme_using_jaccard_method/{k}_sentence_level_batch_2_jaccard.csv", index=False)
# Out:
# Aspirational Plus 5137
# Familial Plus 1205
# Navigational Plus 5006
# Social Plus 1724
# Resistance Plus 994

# %%
merged_resistance_essay_df = pd.concat([processed_essay_theme_datasets["Perseverance"], processed_essay_theme_datasets["Resistance"]])
merged_resistance_essay_df.to_csv("/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/essay_level/merged_themes_essay_level/merged_Resistance_essay_level_batch_1.csv", index=False)

# %%
pd.read_csv("/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/essay_level/merged_themes_essay_level/merged_Resistance_essay_level_batch_1.csv")
# Out:
#                                                   essay  label  \
# 0     Why am I here? Well why does anyone pursue a h...      0
# 1     I'm here because my parents came here during t...      0
# 2     I am here because I want to better myself my f...      0
# 3     I am here at SFSU because I am a first generat...      1
# 4     I am here to help myself grow. Learn and apply...      0
# ...                                                 ...    ...
# 1173  My family has valued hard work. Growing up I w...      0
# 1174  I have lived in the Bay Area my whole life and...      0
# 1175  The values of my community have made a deep an...      0
# 1176  Well one thing my mom has taught me is to not ...      0
# 1177  Since I am the first one go to college in my f...      0
#
#                                                  phrase
# 0                                                 ['0']
# 1                                                 ['0']
# 2                                                 ['0']
# 3     ['School has always helped me escape the hard ...
# 4                                                 ['0']
# ...                                                 ...
# 1173                                              ['0']
# 1174                                              ['0']
# 1175                                              ['0']
# 1176                                              ['0']
# 1177                                              ['0']
#
# [1178 rows x 3 columns]

# %% [markdown]
# ## 3. Merging similar themes

# %% [markdown]
# 1. Attainment and aspirational
# 2. Familial, filial piety, and first-generation
# 3. Perserverance and resistance (essay level)
# 4. Community consciousness, spiritual, and social
# 5. Navigational (essay level)

# %%
processed_theme_datasets["Navigational"]
# Out:
#                                                sentence label  \
# 0     i am here because i want to better myself my f...     0
# 1     being in this instituion will pave a way for m...     1
# 2     i know that as a child i never thought of educ...     0
# 3     i hope to reach a position in which i can insp...     0
# 4     also, statistics have shown that people with h...     0
# ...                                                 ...   ...
# 3191  i want to better myself, improve myself in eve...     0
# 3192  i have no problems applying myself when it com...     0
# 3193  grow mentally so that i can apply more physica...     0
# 3194  use what i learn and apply it in whatever care...     0
# 3195  the more i learn the more opportunities are av...     0
#
#                                                  phrase
# 0     [Being in this instituion will pave a way for ...
# 1     [Being in this instituion will pave a way for ...
# 2     [Being in this instituion will pave a way for ...
# 3     [Being in this instituion will pave a way for ...
# 4     [Being in this instituion will pave a way for ...
# ...                                                 ...
# 3191  [I am here to fulfill my mechanical engineerin...
# 3192  [I am here to fulfill my mechanical engineerin...
# 3193  [I am here to fulfill my mechanical engineerin...
# 3194  [I am here to fulfill my mechanical engineerin...
# 3195  [I am here to fulfill my mechanical engineerin...
#
# [3196 rows x 3 columns]

# %%
[processed_theme_datasets[i] for i in merged_themes["Aspirational"]]
# Out:
#                                                sentence label  \
# 0                                        why am i here?     0
# 1       well why does anyone pursue a higher education?     0
# 2     to better one self and be able to succeed late...     1
# 3     ever since i was little i wanted to be a docto...     0
# 4     i always wanted to be able to help people and ...     0
# ...                                                 ...   ...
# 3031  i want to better myself, improve myself in eve...     0
# 3032  i have no problems applying myself when it com...     0
# 3033  grow mentally so that i can apply more physica...     0
# 3034  use what i learn and apply it in whatever care...     0
# 3035  the more i learn the more opportunities are av...     0
#
#                                                  phrase
# 0     [to better one self and be able to succeed lat...
# 1     [to better one self and be able to succeed lat...
# 2     [to better one self and be able to succeed lat...
# 3     [to better one self and be able to succeed lat...
# 4     [to better one self and be able to succeed lat...
# ...                                                 ...
# 3031  [I want to be able to apply my knowledge to my...
# 3032  [I want to be able to apply my knowledge to my...
# 3033  [I want to be able to apply my knowledge to my...
# 3034  [I want to be able to apply my knowledge to my...
# 3035  [I want to be able to apply my knowledge to my...
#
# [3036 rows x 3 columns]

# %%
merged_resistance_essay_df
# Out:
#                                                  essay  label  \
# 0    Why am I here? Well why does anyone pursue a h...      0
# 1    I'm here because my parents came here during t...      0
# 2    I am here because I want to better myself my f...      0
# 3    I am here at SFSU because I am a first generat...      1
# 4    I am here to help myself grow. Learn and apply...      0
# ..                                                 ...    ...
# 584  My family has valued hard work. Growing up I w...      0
# 585  I have lived in the Bay Area my whole life and...      0
# 586  The values of my community have made a deep an...      0
# 587  Well one thing my mom has taught me is to not ...      0
# 588  Since I am the first one go to college in my f...      0
#
#                                                 phrase
# 0                                                  [0]
# 1                                                  [0]
# 2                                                  [0]
# 3    [School has always helped me escape the hard t...
# 4                                                  [0]
# ..                                                 ...
# 584                                                [0]
# 585                                                [0]
# 586                                                [0]
# 587                                                [0]
# 588                                                [0]
#
# [1178 rows x 3 columns]

# %%
# merged_themes = {"Aspirational": ["Attainment", "Aspirational"],
#                  "Familial": ["Familial", "Filial Piety", "First Gen"],
#                  "Social": ["Community Consciousness", "Spiritual", "Social"]}


# merged_aspirational_df = pd.concat([processed_theme_datasets[i] for i in merged_themes["Aspirational"]])
# merged_familial_df = pd.concat([processed_theme_datasets[i] for i in merged_themes["Familial"]])
# merged_social_df = pd.concat([processed_theme_datasets[i] for i in merged_themes["Social"]])

merged_themes = {"Resistance": ["Resistance", "Perseverance"]}
merged_resistance_df = pd.concat([processed_theme_datasets[i] for i in merged_themes["Resistance"]])

# %%
len(attainment_processed_sentence_df[attainment_processed_sentence_df["label"] == 1])
# Out:
# 304

# %%
processed_essay_theme_datasets["Navigational"]
# Out:
#                                                  essay  label  \
# 0    Why am I here? Well why does anyone pursue a h...      0
# 1    I'm here because my parents came here during t...      0
# 2    I am here because I want to better myself my f...      1
# 3    I am here at SFSU because I am a first generat...      0
# 4    I am here to help myself grow. Learn and apply...      1
# ..                                                 ...    ...
# 584  My family has valued hard work. Growing up I w...      0
# 585  I have lived in the Bay Area my whole life and...      0
# 586  The values of my community have made a deep an...      0
# 587  Well one thing my mom has taught me is to not ...      0
# 588  Since I am the first one go to college in my f...      0
#
#                                                 phrase
# 0                                                  [0]
# 1                                                  [0]
# 2    [Being in this instituion will pave a way for ...
# 3                                                  [0]
# 4    [Learn and apply my skills to progress towards...
# ..                                                 ...
# 584                                                [0]
# 585                                                [0]
# 586                                                [0]
# 587                                                [0]
# 588                                                [0]
#
# [589 rows x 3 columns]

# %%
merged_essay_level_datasets = {"Resistance": merged_resistance_essay_df,
"Navigational": processed_essay_theme_datasets["Navigational"]
                                  }

for k, v in merged_essay_level_datasets.items():
    print(k, v["label"].value_counts(), f"percentage of themed essays: {round(len(v[v['label'] == 1]) / len(v) * 100, 2)}%")
# Out:
# Resistance label
# 0    1031
# 1     147
# Name: count, dtype: int64 percentage of themed essays: 12.48%
# Navigational label
# 1    401
# 0    188
# Name: count, dtype: int64 percentage of themed essays: 68.08%

# %%
merged_sentence_level_datasets = {"Resistance": merged_resistance_df,
"Navigational": processed_theme_datasets["Navigational"]
                                  }

for k, v in merged_sentence_level_datasets.items():
    print(k, v["label"].value_counts(), f"percentage of themed essays: {round(len(v[v['label'] == 1]) / len(v) * 100, 2)}%")
# Out:
# Resistance label
# 0    1117
# 1      87
# Name: count, dtype: int64 percentage of themed essays: 7.23%
# Navigational label
# 0    2912
# 1     284
# Name: count, dtype: int64 percentage of themed essays: 8.89%

# %%
for k,v in merged_sentence_level_datasets.items():
    v.to_csv(f"/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/merged_themes_using_jaccard_method/merged_{k}_sentence_level_batch_1_jaccard.csv", index=False)

# %%
processed_theme_datasets.keys()
# Out:
# dict_keys(['Aspirational_processed_sentence_df', 'Familial_processed_sentence_df', 'Filial Piety_processed_sentence_df', 'First Gen_processed_sentence_df', 'Community Consciousness_processed_sentence_df', 'Spiritual_processed_sentence_df', 'Social_processed_sentence_df'])

# %%
atn_asp_df = pd.concat([attainment_processed_sentence_df, aspirational_processed_sentence_df])
atn_asp_df
# Out:
#                                                sentence label  \
# 0                                         why am i here     0
# 1        well why does anyone pursue a higher education     0
# 2     to better one self and be able to succeed late...     0
# 3     ever since i was little i wanted to be a docto...     1
# 4     i always wanted to be able to help people and ...     0
# ...                                                 ...   ...
# 3151  i want to better myself, improve myself in eve...     1
# 3152  i have no problems applying myself when it com...     0
# 3153  grow mentally so that i can apply more physica...     0
# 3154  use what i learn and apply it in whatever care...     0
# 3155  the more i learn the more opportunities are av...     0
#
#                                                  phrase
# 0     [Ever since I was little I wanted to be a doct...
# 1     [Ever since I was little I wanted to be a doct...
# 2     [Ever since I was little I wanted to be a doct...
# 3     [Ever since I was little I wanted to be a doct...
# 4     [Ever since I was little I wanted to be a doct...
# ...                                                 ...
# 3151  [I want to be able to apply my knowledge to my...
# 3152  [I want to be able to apply my knowledge to my...
# 3153  [I want to be able to apply my knowledge to my...
# 3154  [I want to be able to apply my knowledge to my...
# 3155  [I want to be able to apply my knowledge to my...
#
# [4897 rows x 3 columns]

# %%
# Out:
# /Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti

# %%
atn_asp_df.to_csv("/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/atn_asp_sentence_level_batch_1.csv", index=False)

# %%
attainment_sentence_df = sentence_level_theme_datasets["Attainment"]
attainment_sentence_df
# Out:
#               Alma ID                              Essay: Why I am here?  \
# 0    S18.W2.111.01.01  Why am I here? Well why does anyone pursue a h...
# 6    S18.W2.111.01.07  I am here to better myself and hopefully give ...
# 8    S18.W2.111.01.09  I am here in this class because I want a littl...
# 11   S18.W2.111.01.12  I am here at SFSU for a better future. A futur...
# 16   S18.W2.111.01.17  I'm here because I want to improve my understa...
# ..                ...                                                ...
# 68  F19.PHYS102.02.08  Why am I here? If you're asking me why am I on...
# 72  F19.PHYS242.05.01  I am here at SFSU for a multitude of reasons. ...
# 73  F19.PHYS242.05.02  I am here because I want to make my mom proud....
# 75  F19.PHYS242.05.04  Why am I here? †I am at San Francisco State Un...
# 77  F19.PHYS242.05.06  One of the main reasons why I came to Californ...
#
#                                            Attainment
# 0   Ever since I was little I wanted to be a docto...
# 6   I am in this class because I want to pass phys...
# 8   I am majoring in bio to get to my career goal ...
# 11  I aspire to become a doctor /%/ To achieve goa...
# 16  In the end, the goal is to achieve an A for my...
# ..                                                ...
# 68  I would tell you that I am chasing a degree. I...
# 72  My second is to receive a degree in Engineerin...
# 73                                 I want to graduate
# 75  I am at San Francisco State University to get ...
# 77  One of the main reasons why I came to Californ...
#
# [220 rows x 3 columns]

# %%
attainment_processed_sentence_df = process_sentences_for_theme(attainment_sentence_df, "Attainment")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 attainment_processed_sentence_df = process_sentences_for_theme(attainment_sentence_df, "Attainment")
#       2 attainment_processed_sentence_df[1:]
#
# Cell In[65], line 34, in process_sentences_for_theme(theme_df, theme_column)
#      32 for annotation_phrase in annotation_strip:
#      33     if len(annotation_phrase.split()) > 2:
# ---> 34         label = get_sentence_label(sentence, annotation_phrase)
#      35         if label == 1:
#      36             break
#
# Cell In[63], line 9, in get_sentence_label(essay_sentence, phrase)
#       6     return 1
#       7 else:
#       8     # 2. check for NER in phrase (title /profession/ scientific fields) check if those exist in sentence
# ----> 9     ner_list = get_ner(phrase)
#      10     ner_found_flag = None
#      11     if len(ner_list) == 0:
#
# Cell In[60], line 3, in get_ner(text)
#       2 def get_ner(text):
# ----> 3     doc = nlp(text)
#       4     ner_list = [ent.text for sent in doc.sentences for ent in sent.ents]
#       5     return ner_list
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/pipeline/core.py:480, in Pipeline.__call__(self, doc, processors)
#     479 def __call__(self, doc, processors=None):
# --> 480     return self.process(doc, processors)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/pipeline/core.py:431, in Pipeline.process(self, doc, processors)
#     429     if self.processors.get(processor_name):
#     430         process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 431         doc = process(doc)
#     432 return doc
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/pipeline/sentiment_processor.py:66, in SentimentProcessor.process(self, document)
#      64 sentences = self._model.extract_sentences(document)
#      65 with torch.no_grad():
# ---> 66     labels = self._model.label_sentences(sentences, batch_size=self._batch_size)
#      67 # TODO: allow a classifier processor for any attribute, not just sentiment
#      68 document.set(SENTIMENT, labels, to_sentence=True)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/models/classifiers/base_classifier.py:53, in BaseClassifier.label_sentences(self, sentences, batch_size)
#      50 if interval[1] - interval[0] == 0:
#      51     # this can happen for empty text
#      52     continue
# ---> 53 output = self(sentences[interval[0]:interval[1]])
#      54 predicted = torch.argmax(output, dim=1)
#      55 labels.extend(predicted.tolist())
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/models/classifiers/cnn_classifier.py:461, in CNNClassifier.forward(self, inputs)
#     458     all_inputs.append(char_reps_forward)
#     460 if self.backward_charlm is not None:
# --> 461     char_reps_backward = self.build_char_reps(inputs, max_phrase_len, self.backward_charlm, self.charmodel_backward_projection, begin_paddings, device)
#     462     all_inputs.append(char_reps_backward)
#     464 if self.config.use_elmo:
#     465     # this will be N arrays of 3xMx1024 where M is the number of words
#     466     # and N is the number of sentences (and 1024 is actually the number of weights)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/models/classifiers/cnn_classifier.py:313, in CNNClassifier.build_char_reps(self, inputs, max_phrase_len, charlm, projection, begin_paddings, device)
#     312 def build_char_reps(self, inputs, max_phrase_len, charlm, projection, begin_paddings, device):
# --> 313     char_reps = charlm.build_char_representation(inputs)
#     314     if projection is not None:
#     315         char_reps = [projection(x) for x in char_reps]
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/models/common/char_model.py:222, in CharacterLanguageModel.build_char_representation(self, sentences)
#     219 chars = get_long_tensor(chars, len(all_data), pad_id=vocab.unit2id(CHARLM_END)).to(device=device)
#     221 with torch.no_grad():
# --> 222     output, _, _ = self.forward(chars, char_lens)
#     223     res = [output[i, offsets] for i, offsets in enumerate(char_offsets)]
#     224     res = unsort(res, orig_idx)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/models/common/char_model.py:153, in CharacterLanguageModel.forward(self, chars, charlens, hidden)
#     150 if hidden is None:
#     151     hidden = (self.charlstm_h_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous(),
#     152               self.charlstm_c_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous())
# --> 153 output, hidden = self.charlstm(embs, charlens, hx=hidden)
#     154 output = self.dropout(pad_packed_sequence(output, batch_first=True)[0])
#     155 decoded = self.decoder(output)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/stanza/models/common/packed_lstm.py:22, in PackedLSTM.forward(self, input, lengths, hx)
#      19 if not isinstance(input, PackedSequence):
#      20     input = pack_padded_sequence(input, lengths, batch_first=self.batch_first)
# ---> 22 res = self.lstm(input, hx)
#      23 if self.pad:
#      24     res = (pad_packed_sequence(res[0], batch_first=self.batch_first)[0], res[1])
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniforge3/envs/ml_env/lib/python3.8/site-packages/torch/nn/modules/rnn.py:882, in LSTM.forward(self, input, hx)
#     879     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     880                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     881 else:
# --> 882     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     883                       self.num_layers, self.dropout, self.training, self.bidirectional)
#     884 output = result[0]
#     885 hidden = result[1:]
#
# KeyboardInterrupt:

# %%
attainment_processed_sentence_df[14:]
# Out:
#                                                sentence label  \
# 14    i knew this step was going to be an important ...     0
# 15                i am here at sfsu for a better future     0
# 16    a future where i don't have to struggle at the...     0
# 17    to achieve goals such as open up a homeless sh...     1
# 18    i aspire to become a doctor because i know tha...     1
# ...                                                 ...   ...
# 1736  †by the time i got here at sfsu i decided to j...     0
# 1737  †right now i am slightly considering switching...     0
# 1738  one of the main reasons why i came to californ...     1
# 1739  i move to san francisco because i got accepted...     0
# 1740  one of my goals will be to live in san francis...     0
#
#                                                  phrase
# 14    [I am majoring in bio to get to my career goal...
# 15    [I aspire to become a doctor , To achieve goal...
# 16    [I aspire to become a doctor , To achieve goal...
# 17    [I aspire to become a doctor , To achieve goal...
# 18    [I aspire to become a doctor , To achieve goal...
# ...                                                 ...
# 1736  [I am at San Francisco State University to get...
# 1737  [I am at San Francisco State University to get...
# 1738  [One of the main reasons why I came to Califor...
# 1739  [One of the main reasons why I came to Califor...
# 1740  [One of the main reasons why I came to Califor...
#
# [1727 rows x 3 columns]

# %%
attainment_processed_sentence_df["sentence"][18]
# Out:
# 'i aspire to become a doctor because i know that not only can i change my life, families, but also the people around me'

# %% [markdown]
# **Generate csv file for Attainment**

# %%
attainment_df = theme_datasets["Attainment"]

# %%
attainment_sentence_df = pd.DataFrame(columns=['sentence', 'label', 'phrase'])
with open('/Users/gbaldonado/Developer/ml-alma-taccti/ml-alma-taccti/data/processed_for_model/using_original_method/attainment_sentence_level_dataset.csv','w',newline='', encoding = 'UTF-8') as f:
    writer = csv.writer(f)
    writer.writerow(['sentence','phrases','label'])
    for index,val in attainment_df.iterrows():
        text = val['Essay: Why I am here?'].rstrip('\n\r')
        # using sent_tokenize from nltk to split the paragraphs into sentences.
        temp_text = re.split('\.|\?|\!',text) # text.split('.')
        # annotation
        annotation = val['Attainment']
        if '/%/' in annotation:
            annotation = re.sub('/%/', '. ', annotation)
        # annotation list
        annotation_list = re.split('\.|\?|\!',annotation) #annotation.split('.')
        annotation_strip = [y.rstrip('\r\n') for y in annotation_list if y != '']
        essay_strip = [x for x in temp_text if x !='']
        
        # remove the extra spaces before the sentences.
        annotation_strip = [y.lstrip(" ") for y in annotation_strip]
        essay_strip = [x.lstrip(" ") for x in essay_strip]
        
        # annotate the essay on sentence level.
        for sentence in essay_strip:
            if not (re.search('\w',sentence)):
                continue
            if (len(sentence.split(' ')) < 3):
                continue
            for annotation_phrase in annotation_strip:
                if len(annotation_phrase.split()) > 2:
                    label = get_sentence_label(sentence,annotation_phrase)
                    if label == 1:
                        break
            writer.writerow([sentence.lower(), annotation_strip, label])
            # Create a new DataFrame with the row you want to add
            new_row = pd.DataFrame([{'sentence': sentence.lower(), 'label': label, 'phrase': annotation_strip}])

            # Concatenate the new row to the existing DataFrame
            attainment_sentence_df = pd.concat([attainment_sentence_df, new_row], ignore_index=True)
            # attainment_sentence_df = attainment_sentence_df.append({'sentence' : sentence.lower() , 'label': label , 'phrase':annotation_strip}, ignore_index=True)
            #attainment_sentence_df = attainment_sentence_df.append({'sentence' : sentence , 'label': label , 'phrase':annotation_strip}, ignore_index=True)

# %%
attainment_df
# Out:
#                ID CODE                              Essay : Why am I here  \
# 0       pilot_study_01  I am here to get my BS in Physiology, so I can...
# 8       pilot_study_09  I’m here to learn and to be on the path toward...
# 9       pilot_study_10  I am in SFSU because I want to go to medical s...
# 11      pilot_study_12  I am here in SFSU because I am the first gener...
# 13      pilot_study_14  I am here because of my goal in trying to get ...
# ..                 ...                                                ...
# 551  F19.PHYS232.07.23  I'm here because of prerequisite for my comput...
# 559  F19.PHYS232.09.08  The reason I am here is to do experiments and ...
# 561  F19.PHYS232.09.10  I am in college to further my education. There...
# 562  F19.PHYS242.05.01  I am here at SFSU for a multitude of reasons. ...
# 565  F19.PHYS242.05.04  Why am I here? †I am at San Francisco State Un...
#
#                                     Attainment - FINAL
# 0    I am here to get my BS in physiology so I can ...
# 8    I’m here to learn and to be on the path toward...
# 9    I am in SFSU because I want to go to medical s...
# 11     My goal is to graduate with a degree B.A./B.S.
# 13   I am here because of my goal in trying to get ...
# ..                                                 ...
# 551     And my dream job is to be a software engineer.
# 559   I am an aspiring Engineer and I love doing ex...
# 561    I am studying to become an electrical engineer.
# 562  My second is to receive a degree in Engineerin...
# 565  I am at San Francisco State University to get ...
#
# [185 rows x 3 columns]

# %%
attainment_sentence_df
# Out:
# Empty DataFrame
# Columns: [sentence, label, phrase]
# Index: []

# %%
pos_labels = len([n for n in attainment_sentence_df['label'] if n==1])
print("Positive labels present in the dataset : {}  out of {} or {}%".format(pos_labels, len(attainment_sentence_df['label']), (pos_labels/len(attainment_sentence_df['label']))*100))
# Out:
# Positive labels present in the dataset : 253  out of 1413 or 17.905166312809627%

# %%
train, test = train_test_split(attainment_sentence_df, test_size=0.1, random_state=18, stratify=attainment_sentence_df['label'])

# %%
train.to_csv("data/csv/attainment_sentence_level_training_data.csv", encoding='UTF-8', index=False)

# %%
test.to_csv("data/csv/attainment_sentence_level_test_data.csv",  encoding='UTF-8', index=False)

# %%
print('Class distibution of Training data: {:0.2f}% positive class'.format(len([m for m in train['label'] if m==1])/len(train['label']) *100))
print('positive labels : {} out of total {} datapoints'.format(len([m for m in train['label'] if m==1]), len(train['label'])))
# Out:
# Class distibution of Training data: 17.94% positive class
# positive labels : 228 out of total 1271 datapoints

# %%
print('Class distibution of Test data: {:0.2f}% positive class'.format(len([m for m in test['label'] if m==1])/len(test['label']) *100))
print('positive labels : {} out of total {} datapoints'.format(len([m for m in test['label'] if m==1]), len(test['label'])))
# Out:
# Class distibution of Test data: 17.61% positive class
# positive labels : 25 out of total 142 datapoints

# %% [markdown]
# **Generate csv file for First Generation**

# %%
first_generation_sentence_df = pd.DataFrame(columns=['sentence', 'label', 'phrase'])
with open('data/csv/first_generation_sentence_level_dataset.csv','w',newline='', encoding = 'UTF-8') as f:
    writer = csv.writer(f)
    writer.writerow(['sentence','phrases','label'])
    for index,val in first_generation_df.iterrows():
        text = val['Essay : Why am I here'].rstrip('\n\r')
        # using sent_tokenize from nltk to split the paragraphs into sentences.
        temp_text = re.split('\.|\?|\!',text) # text.split('.')
        # annotation
        annotation = val['First Gen - FINAL']
        if '/%/' in annotation:
            annotation = re.sub('/%/', '. ', annotation)
        # annotation list
        annotation_list = re.split('\.|\?|\!',annotation) #annotation.split('.')
        annotation_strip = [y.rstrip('\r\n') for y in annotation_list if y != '']
        essay_strip = [x for x in temp_text if x !='']
        
        # remove the extra spaces before the sentences.
        annotation_strip = [y.lstrip(" ") for y in annotation_strip]
        essay_strip = [x.lstrip(" ") for x in essay_strip]
        
        # annotate the essay on sentence level.
        for sentence in essay_strip:
            if not (re.search('\w',sentence)):
                continue
            if (len(sentence.split(' ')) < 3):
                continue
            for annotation_phrase in annotation_strip:
                if len(annotation_phrase.split()) > 2:
                    label = get_sentence_label(sentence,annotation_phrase)
                    if label == 1:
                        break
            writer.writerow([sentence.lower(), annotation_strip, label])
            first_generation_sentence_df = first_generation_sentence_df.append({'sentence' : sentence.lower() , 'label': label , 'phrase':annotation_strip}, ignore_index=True)
            #first_generation_sentence_df = first_generation_sentence_df.append({'sentence' : sentence , 'label': label , 'phrase':annotation_strip}, ignore_index=True)

# %%
first_generation_sentence_df.shape
# Out:
# (128, 3)

# %%
pos_labels = len([n for n in first_generation_sentence_df['label'] if n==1])
print("Positive labels present in the dataset : {}  out of {} or {}%".format(pos_labels, len(first_generation_sentence_df['label']), (pos_labels/len(first_generation_sentence_df['label']))*100))
# Out:
# Positive labels present in the dataset : 19  out of 128 or 14.84375%

# %%
train, test = train_test_split(first_generation_sentence_df, test_size=0.2, random_state=18, stratify=first_generation_sentence_df['label'])

# %%
train.to_csv("data/csv/first_generation_sentence_level_training_data.csv", encoding='UTF-8', index=False)

# %%
test.to_csv("data/csv/first_generation_sentence_level_test_data.csv",  encoding='UTF-8', index=False)

# %%
print('Class distibution of Training data: {:0.2f}% positive class'.format(len([m for m in train['label'] if m==1])/len(train['label']) *100))
print('positive labels : {} out of total {} datapoints'.format(len([m for m in train['label'] if m==1]), len(train['label'])))
# Out:
# Class distibution of Training data: 14.71% positive class
# positive labels : 15 out of total 102 datapoints

# %%
print('Class distibution of Test data: {:0.2f}% positive class'.format(len([m for m in test['label'] if m==1])/len(test['label']) *100))
print('positive labels : {} out of total {} datapoints'.format(len([m for m in test['label'] if m==1]), len(test['label'])))
# Out:
# Class distibution of Test data: 15.38% positive class
# positive labels : 4 out of total 26 datapoints
