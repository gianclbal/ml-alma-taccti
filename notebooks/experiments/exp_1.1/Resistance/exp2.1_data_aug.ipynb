# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
seed = 18

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc

from nlpaug.util import Action

# %%
text = "The quick brown fox jumps over the lazy dog."

# %%
aug = naw.SynonymAug(aug_src='wordnet')
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog.
# Augmented Text:
# ['The quick robert brown fox jumps over the work shy domestic dog.']

# %% [markdown]
# ## Working with the resistance dataset.

# %%
merged_resistance_df = pd.read_csv("../../../../data/processed_for_model/merged_themes_using_jaccard_method/merged_Resistance_sentence_level_batch_1_jaccard.csv", encoding='utf-8')

# Shuffle the merged dataset
merged_resistance_df = shuffle(merged_resistance_df, random_state=seed)

# Train-test split 
training_df, test_df = train_test_split(merged_resistance_df, test_size=0.2, random_state=18, stratify=merged_resistance_df['label'])

training_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 1. Synonym-based

# %%
training_pos_data_list = training_df[training_df['label'] == 1].sentence.to_list()
test_pos_data_list = test_df[test_df['label'] == 1].sentence.to_list()

# %%
training_ = []
for i in resistance_pos_data_list:
    new_data = aug.augment(i)
    aug_data_pos_list.append(new_data)

# %%
resistance_pos_data_list
# Out:
# ['this is my first time taking physics in college and it been a rough start but i am hoping i can understand and learn from it.',
#  'in my junior year with HS school my thats been excited wanna take physics, but we had a teacher that didnt teach and just asked us to cheat all the tests so that it didnt look like a classroom teacher, so im excited everyone get a real deal on physics.',
#  'moving from los angeles to san francisco, i came with the hope to learn how to become independent and vouch for my needs and wants in a society where minorities like myself are constantly under attack and come from communities lacking in resources.',
#  'as a first generation student, i feel like it is my duty to break the generation of poverty and low education and instead be the first to pioneer a hopeful path of higher education and not be constrained to work.',
#  'i. also make notes We learn about the material because physics is a complex subject.',
#  'engineering is hard enough i will achieve i best in order I pass.',
#  'i have struggled with understanding physics since high school, yet i enter every class with the mindset that maybe today it will click.',
#  'i hope this semester will not only challenge me but also encourage me to not give up on struggling situations and be able to preserve until the end.',
#  'even though this as a course i took for myself, i only registered via satisfy school application, im putting forth my effort d learn more about physics and attempting to apply mathematical information in the world compared to something major.',
#  'i am here to change the number of women in stem, to change the number of latina women in stem. i am also here to make my parents proud.',
#  'however, sf is really different from la so there have been many times where i have contemplated going back to la and transferring to a community college but i look back and think that im already here.',
#  'i think physics will be hard but i believe that there needs to be a lot of time and dedication to succeed in this lab and during lecture and i will do my best to succeed.',
#  'physics 1 and physics 2 are requirements to get into ucsfs physical therapy program so im not going to let my fear of math stand in the way of my goals.',
#  'i also have had some struggles with college level math classes in the past because of the homework so i thought it would be a good idea to take a supplementary class because of the extensive math involved in understanding physics concepts.',
#  'i used to always fight a liberal, and as much months after graduate school they decided that i was not smart enough to understand science Now i have learned that dedication, willpower, and hard work are key.',
#  'this is a new adventure for me where i will make mistakes and learn from them.',
#  'i believe i will succeed at making my dreams by racing professional runner because it havent had anything stop me in from past.',
#  'i am here because we want too learn, ive taken 1 online course in high school - barely.',
#  'i am in this somewhat supplemental field so i know that i always winds up concerned with difficult topics in teaching.',
#  'i was a tad lost walking into biol 230, i made sure what i knew looking into college seemed pretty intense, also competitive in the teaching aspect, so when hearing about sci e knew i needed to sign up.',
#  'this is a challenging class that test my cooperation and communication ability.',
#  'while several months having been challenging, i appreciate the process of learning new methods and addressing these obstacles.',
#  'i know the journey will not be linear, i know that i can overcome these harsh barriers that will try to consume me.',
#  'to show them that it is possible for us, the minority, to become leaders, role models and influencers.',
#  "i dont want to be an immigration lawyer, especially while in the fair to old east asians here love getting together against gangs. i'm here in this class because i truly hate Trump and at least this is kind of interesting.",
#  'i just think that physics can be hard at times, so i know that ill have to put in time and effort to fully understand the material.',
#  'i love coding, and even though Im hard and theres u lot big struggles, im shaped by neuroscience.',
#  'i want to be able to get a grasp on concepts that i dont understand instead of just struggling through them and never fully understanding those specific topics.',
#  'i am here because of our different to struggle but i want to help build my character.',
#  'a place to learn, to make mistakes, overcome challeneges, and that is safe for them to be themselves and to meet others.',
#  'physics for me is not easy and it takes a lot of studying and hard work to achieve my understanding of the material.',
#  'i am here making me know that physics is hard and i knew it taking a sci course might benefit students to take that major.',
#  'i figure its hard that i kinda pushing myself anyway.',
#  'physics 2 is difficult but instead of giving up like before, my attitude includes ambition and determination.',
#  'since the journal requirement is minimum one hundred and fifty words i shall continue rambling on. i am a disabled veteran and am coming back to school to learn skills more properly suited for civilian interaction, basically here to learn something thats not related to killing and dealing with guns since all those skills do is help me stay in the cycle of protection lines of work (cop, security, etc...).',
#  'i am here to provide myself with opportunities and get well something besides stereotypes Also provide my resources to this younger generations from them to help them fully come to personal goals and achieve themselves more than they can comprehend.',
#  'i will always try my hardest in this class because i feel that this is where i can learn the best. i am also here because i want to graduate on time and not fail any of my classes.',
#  'i know its hard but i keep pushing myself forward.',
#  'i want to represent myself, my gender, my sexuality, and my latina heritage and prove the world wrong that we do have the potential to flourish.',
#  'life does seem to continue to throw obstacles my way, but i believe anything is possible when i try.',
#  'i chose t be in this school because you matter how smart u are, you idea how much you know in the course you think both are or so best at, there is simply room for improvement.',
#  'i slipped up a bit during this recent trip here, but i continue to make excuses for it using hard work on getting results.',
#  'i am here too prove that i can kill anything you set my heart to, not lying to you, and to ourselves equally well.',
#  'i screwed up a bit during my first year here, but i intend to make up for it with hard work and getting results.',
#  'even though this isnt a course i took for myself, i only registered to satisfy school requirements, im putting all my effort to learn more about physics and how to apply this information to the world and to my major.',
#  'moving down des angeles to san francisco, it came from special hope to discover how to become visible and voice for my needs and wants in in society where minorities like myself are constantly under attack and come into communities lacking in resources.',
#  'physics requires a ton of work effort and hard work, and you need to get help when ya need it from it it may handle all important material, so so you will not fall behind.',
#  'math still manages to give me a little too more work, but i get a ton of it for pushing myself to do I best i do.',
#  'i typically struggle with science courses, especially physical science courses with alot of conceptual material so the benefit of asking questions that i have for physics in a small group environment gives me more confidence in general.',
#  'im sorry for all we beautiful colored girls who did not got just politicians to look up to in their communities.',
#  'i hope this semester doesnt not only inspire me but also encourage u dont finally give up on our cause and be able to preserve until its light.',
#  'i have found physics to be very difficult and i am hoping this class will help me pass physics.',
#  'another reason i stayed here is just be by myself myself meditation can do it, if nothing else it can definitely DO that i promise!',
#  'school has always helped just escape the hard things you get by daily.',
#  'i am here because i want to learn, ive taken ap physics before in high school but struggle.',
#  'i am here in the science community because i feel that my people (of color and being a female) are under represented.',
#  'i am in this sci11502 supplemental course because i know that i will end up struggling with future topics in chem115.',
#  'i understand it takes time and patience to be to where i want to be, so i know u can if once i am i head clear enough do enough.',
#  'physics 1 at work 10 had requirements to apply into ucsfs physical therapy department so im being going to let my fear of math happen like the rest of my goals.',
#  'i try to put my mistakes behind me, and look forwards the future, and whatever happens, good or bad, ive gotten through it and i know i can do it again.',
#  'i believe i will succeed in making my goal of becoming a doctor because i havent had anything stop me in the past.',
#  'i am here to actually be and provide aid to hospitals where needed it, and to counter to stigma of healthcare being this certain job.',
#  "i don't really like physic but it is a part at my study but i aim to learn fast but hope more people love something because it would be easier.",
#  'i came bored today i think im important to show up to classes no matter looks tired and bored many are.',
#  'this is a challenging campaign & requires my cooperation and communication skill.',
#  'i got bad grade on my first test wanted wanna give out but i shouldnt and well know will still do the test hw and practice so i might predict better grades next time',
#  'physics its good reason really daunting and kind of boring too, and now that i am doing the class i feel excited to challenge and challenge yourself with what this class has within store.',
#  "i'm here i push through obstacles, deal with adversity, ultimately change people into who i hope to see.",
#  'this job has it extremely long and challenging like far, and l am just anxious to find more life back.',
#  'this year has been extremely long and challenging so far, and i am just trying to find my way back.',
#  'engineering is hard but i will do my best in order to succeed.',
#  'i know it takes time and patience to get to where i want to be, but i know i can achieve once i get my head straight and focus enough.',
#  'i was a bit lost going into biol 230, i wasnt sure what i was getting into and seemed pretty intense, and inyourface in the teaching aspect, so when hearing about sci i knew i needed to sign up.',
#  'i will succeed the class and get through all of the challenges that it throws at me.',
#  'im here of all the mistakes that i have taken and i learned from.',
#  'another reason i am here is to prove to myself that i can do it, if nothing else i can definitely say that i tried!',
#  'i want to be able to say i went back and finished school, but not only finished, but completed a major that most never thought i would be able to do.',
#  'i am here because i know that physics is hard and i knew that taking a sci course would benefit me to pass the class.',
#  'the work ethics that my dad has passed onto me has allowed me to overcome the tough times that both work and school throw at me.',
#  'im here because i told myself y decided to stay here but feel u have to prove it.',
#  "i really want to be an immigration lawyer, especially here in the bay since south east asians here are getting targeted by ice. i'm here in this class because i truly hate science and at least this is kind of interesting.",
#  'i am here to better be and provide resources to hospitals that need me, and to break the stigma of healthcare being a certain way.',
#  'i am not her first student of the university, while often, i find many ways difficult and are harder to to learn by others, but im am here to take aside such challenges, and expand certain limitations that are in my mindset.',
#  'im here for all the little colored girls who do not have positive figures to look up to in their communities.',
#  'physics is a class that often can have a negative stigma surrounding it, especially given how abstract the concepts can get, but i am nonetheless interested in the content and try to keep an open mind as i study it.as for college in general, i am here because i wish to gather the knowledge and experience to become a math teacher, in addition to forming valuable connections with the people i meet along the way.',
#  'i want my represent myself, I experience, my education, and my latina heritage - proving the feminists wrong that I do have some potential to exist.',
#  'i am attracted in the science community because they feel most black people (= learning and being mostly female) are strongly represented.',
#  'i am here to provide myself with opportunities and accomplish to something besides stereotypes and provide my resources to other younger generations with them to help them also accomplish to these goals and achieve to more than they can imagine.',
#  'to make my family proud and prove myself that i can do it, even though there are lots of challenges.',
#  "i came into this knowing the class would be challenging and i'm grateful for that as it continues to keep my attention.",
#  'i typically struggle more science courses, especially social science studies with alot less conceptual material so the benefit if asking questions that i have in physics to a small group environment gives i real confidence in writing.',
#  'ive had some complications that naturally come with moving off from family so theyve definitely proven your very hard it is to be an adult and that your all going to get worse.',
#  'i will succeed the class and get through life and the punishments this ultimately came at me.',
#  'not only am i making an impact on the medical field and women who are pregnant, but i am also changing the stem norms.',
#  'along with that, having a bachelors degree proves that i can be consistent and finish what i have started.',
#  'this is brand new adventure by me with he will see mistakes yet learn from them.',
#  "i'm here to push through obstacles, deal with adversity, and mold myself into what i want to be.",
#  'i am here because i think its important to show up to classes no matter how tired or bored you are.',
#  'math always seems to give me a little bit of trouble, but i get a hang of it after pushing myself to do the best i can.',
#  'also, i still an inexperienced medical doctor, and there is not a great influence in the stem fields, but i came to help in a direction.',
#  'i know that as a child i never thought of education and a career for someone who is undocumented.',
#  'i want on be more better maintain a grasp on concepts that i should understand d o just struggling through articles after never fully understanding those specific topics.',
#  'i hope to reach a position in which i can inspire and prove to all of the "immigrants" in the usa that achieving and surpassing struggle is possible.',
#  'must people try to get money, fame, or more stable life, and to be mean too you, I is not more about me that a dream we need to achieve to make a pokemon happy, myself.',
#  'initially, my motivation was very revolved around myself and proving others wrong, but eventually that motivation bloomed into proving to myself that i can and will continue to improve myself not only through school, but through life as well.',
#  'in my junior year of high school i had been excited to take physics, but we had a teacher that didnt teach and just asked us to cheat on the tests so that he didnt look like a bad teacher, so im excited to get a real education on physics.',
#  'must people study to get money, fame, or a stable life, and to be real with you, studying is nothing more to me that a goal i need to achieve to make a person happy, myself.',
#  'i am here to prove that i can do anything i set my mind to, not only to others, but to myself as well.',
#  'not only am i making an impact on a medical field while every working are doctors, but i am also changing American body culture.',
#  'i also had had some struggles with college level science classes in the past because of the homework so had thought that would be a good idea to pick a computer class if its the extensive math involved inside understanding basic concepts.',
#  'physics to me is not straightforward so it takes a fairly long studying with hard work to develop my understanding of astronomical material.',
#  'since the journal requirement is minimum one hundred and fifty words i shall continue rambling on. i im a combat veteran and am coming back to school to learn roles more properly suited for civilian interaction, basically here to learn something thats mainly related towards killing and dealing with guns but all those skills do is help soldiers stay in the cycle of protection culture of battle (cop, law, etc...).',
#  'i chose to be in this class because no matter how smart you are, no matter how much you know in the course you think you are doing the best at, there is always room for improvement.',
#  'i will just try other studies within this class because this feel that this is where i can learn to most. i love going here because i want to graduate on time and not fail any on my classes.',
#  'i will also make sure i understand all the material because physics is a tough subject.',
#  'i am here to finish what i started and make all the money i invested in worth going to school.',
#  "going private school full time and working over 30 hours a week and getting near anyone in my program has proven difficult but i've been determined to transfer what they have taught me onto excel on what ever i put my teeth behind.",
#  "luckily, the lab professor i train currently is very interesting, so don't stop staying back than get help and learning things from experience.",
#  'i hopes to reach a position in which it can inspire and prove to all of us "immigrants" on our world that achieving results defending these remain possible.',
#  'i believe physics might become interesting but really believe that there needs to only a lot of time and dedication to come to this lab like during lecture and i can do my best to succeed.',
#  'the work ethics that her brother has passed onto I have allowed me to meet the tough times on both work the youth throw for me.',
#  'i want ta be able the claim i gained back amd finished school, I not quite finished, but completed a major that we never thought i would was able t do.',
#  'initially, their motivation was very focused around self - proving others wrong, and then that motivation bloomed into proving to myself that i is & will work to improve myself not only through school, but through everything as well.',
#  'to learn as i have to, but to personally learn and one wish to learn and move forward with newly added knowledge.',
#  'i know the road will not be dull, i know that i can jump every physical barriers that would try or derail me.',
#  'i stay here a actually do something i am being taught in lecture, and just get lost or bored.',
#  'life does seem too struggle to throw projects your way, but i reach what is achievable when i try.',
#  "luckily, the lab professor i have currently is very helpful and i don't mind staying later to get help and understand things from her.",
#  'to learn because i have to, but also to learn because i want to survive and move forward with newly acquired knowledge.',
#  'i am not that strong in math but i am trying.',
#  'i am not the smartest student in the university, and often, i find many topics difficult and are harder to to learn than others, but i am here to take on these challenges, and expand the limitations that are in my mindset.',
#  'i also found chemistry to get too difficult and m am confident this class will help me pass physics.',
#  'i used to always be a quitter, and very early on in high school i decided that i was not smart enough to understand science but i have learned that dedication, passion, and hard work are key.',
#  'i try to put my friends around me, and look forwards for positives, and whatever happens, healthy or indifferent, ive struggled through it so i know i could do this again.',
#  'although honestly it can be very difficult i know what me being bitter can pay off one day and i can look away and draw encouraged from my strength and everything i did to get to that point.',
#  'a place where learn, and make mistakes, have difficulties, somewhere that is important for them to have friends and to meet everyone.',
#  'however, sf is really different compared la so there have been numerous times where i have contemplated changing big if la and transferring to another separate college but i look back i think eh im already ready.',
#  'ive had some struggles that naturally come with moving away from family but theyve really showed me how hard it is to be an adult and that its not going to get easier.',
#  'im here because i told myself i deserve to be here and now i have to prove it.']

# %%
aug_data_pos_list
# Out:
# [['this is my first years taking physics in english so it been another rough course so i am hoping we still understand and learn using it.'],
#  ['in my sophomore year yr HS teacher i thats been excited wanna take physics, but he had a friend She didnt teach and just asked us to cheat all the tests and that she didnt look like a classroom teacher, so im instead everyone get a real deal on physics.'],
#  ['moving from San angeles to san Fernando, we came with the hope to learn how to become responsible & act for my safety and wants in a society where minorities like myself lay continually under attack and come from those lacking in resources.'],
#  ['as a first generation student, i am like t is my duty to break each generation of poverty and poor education and hopefully lead the first to see a hopeful path for higher development thus not be constrained to work.'],
#  ['i. also make notes or knew about complex material because there was another complex subject.'],
#  ['engineering is strong enough you will achieve success just in order ro pass.'],
#  ['i have struggled with modern physics since high school, however often enter every class with the certainty that day more revolution will begin.'],
#  ['i hope this semester with not only test me but also encourage me where I given up on struggling physically and am able not preserve until the finish.'],
#  ['even though physics became a quest i took for myself, i only registered as satisfy school application, but putting down my effort d learn more about physics cause attempting to apply mathematical information across the world seemed like something major.'],
#  ['i am here te change the number of women in Nigeria, to change a number of adult females reaching stem. i think u here ti make my country proud.'],
#  ['however, bio is really close from la so my have been many times when i had contemplated going back to la farther then to one community college but instead stand back and think that im already here.'],
#  ['i think physics will be hard still i trust that there needs to be really lot of time and can I try in small lab and prove it and i will do my utmost to succeed.'],
#  ['physics 1, science 2 are requirements to get though any physical therapy program so im not one to let my fear of math stand in class draft like an entry.'],
#  ['i also have experience some struggles with AP level math classes in the past because of the homework which i thought t would seem a terrible idea first take a AP class because of the extensive math involved like understanding the concepts.'],
#  ['i used to always fight a liberal, at as much were after graduate as they said that i had not qualified as to understand science as i has seen that dedication, willpower, and hard work are key.'],
#  ['this is My game system for my where i will catch mistakes and learn though them.'],
#  ['i believe u will attempt at making my dreams by racing with games because games havent helped anything stop us in I past.'],
#  ['i am here cos we want more badly, ive taken good work position after high school - barely.'],
#  ['i am not yet somewhat supplemental field but i know that i always find up poking around related topics in teaching.'],
#  ['i though a tad lost walking into sem 230, i made sure what ke knew looking into everything seemed pretty intense, also lacking in the teaching aspect, so when hearing about classes ac knew i needed too listen up.'],
#  ['this is a proper competition - test my cooperation and concentration ability.'],
#  ['while several months ahead been challenging, developers embrace the process while learning new lessons while addressing these obstacles.'],
#  ['i knew me journey will not be linear, i know that i must face every harsh times which will try and consume me.'],
#  ['to represent Asians that it is possible for minorities, the minority, too make performers, role models and consumers.'],
#  ["i dont want to be an activist lawyer, even back in my fair to old hours asians here love getting together against racism. i'm here in this mood although i still hate Trump i at least this is kind of interesting."],
#  ['i just wish playing physics can be hard enough times, as i feel that guys have definitely put some time and effort to fully understand the model.'],
#  ['i love coding, and even though Im hard work theres hundreds of big ideas, i motivated via neuroscience.'],
#  ['i supposed to be easier to get the grasp on things an everyone can understand instead of just struggling through them and actually consistently understanding those specific topics.'],
#  ['i were here because of our different to us but i want more help lay a future.'],
#  ['a place to grow, to make mistakes, overcome things, and think are safe for people to be themselves or willingly face challenge.'],
#  ['physics, me is not intuitive and it means the lot of practice, hard research to achieve my understanding of a material.'],
#  ['i friend here lets me know that writing is fun and she knew it having a sci class might benefit students to take that seriously.'],
#  ['i figure got above that and was pushing myself anyway.'],
#  ['physics 2 seems difficult but instead of giving further than Socrates, the attitude includes ambition in determination.'],
#  ['since the journal requirement is minimum one hundred and fifty words i shall continue rambling on. i being a disabled veteran, so switching back to school to learn skills more properly suited for civilian use, basically here to learn something thats not related by killing and dealing with guns since having other skills do is result me else in the cycle of protection lines of work (cop, security, etc...).'],
#  ['i am doing too empower myself with help and get well something besides stereotypes i provide my resources to this new guy from them to help them fully come into our goals and achieve alot more than they can comprehend.'],
#  ['i will always try my hardest in EVERY area because i feel that this is where they can focus there best. my am also upset because i had to graduate on time to not owe any of my classes.'],
#  ['i realize how hard but actually enjoy pushing myself forward.'],
#  ['i want to celebrate myself, same gender, Latino ethnicity, and mt latina heritage and prove entire world wrong that you always have the ability to be.'],
#  ['life does seem to continue pushing throw punches our way, I truly believe anything is achieved when i fight.'],
#  ['i chose t tu in grad school because you matter how smart u look, either idea who much you eat and any course you think both better or so best at, there is simply room for you.'],
#  ['i slipped into behind marker during this recent project and, therefore i continue to make excuses for it using hard work during getting right.'],
#  ['i am here too believing that i can believe anything m set my mind to, not lying for myself, pretending to ourselves not to.'],
#  ['i screwed over a bit during this first demo here, but i intend ta fix up for it by good work and getting better.'],
#  ['even though this isnt a course yo do for myself, i only registered to take school requirements, im putting all my effort to know everything about physics and how to apply this all in this world and hopefully be major.'],
#  ['moving down des la es que francisco, it came from special interests she contemplate how to become all collective voice for those concerns and wants in in society where minorities like myself are constantly under attack and come into communities lacking in resources.'],
#  ['physics requires a lot on collaborative effort and precision work, and you ought to get help when ya need someone from beyond it may handle all important material, so so we will never fall overboard.'],
#  ['math still need to give me a little touch more slack, as i get a ton + praise for pushing on to achieve the best i do.'],
#  ['i did struggle with science courses, mainly physical science, with alot of conceptual frameworks so the importance of asking questions that would have for others in a small research environment helps me more confidence in research.'],
#  ['im sorry for all we beautiful colored girls who to once have Nigerian politicians to look back to for those communities.'],
#  ['i hope this semester doesnt u only support yr but also encourage u dont finally wake up and our cause and yr inspired to remain until thy light.'],
#  ['i never discovered physics to be very difficult and i was hoping your class will serve me with physics.'],
#  ['another sign im stayed alive cant just be by myself so meditation can do everything, if nothing bigger it can definitely DO everything i have!'],
#  ['school spirit always helped her escape the hard things we get lost doing.'],
#  ['i live here because i want fast sleep, ive taken ap physics test at middle school all struggle.'],
#  ['i prefer participating in natural science community because l feel that my species (of nature and being remotely black) are under represented.'],
#  ['i am call this sci11502 s intro final but know that i will finish up here with future topics in life.'],
#  ['i guess it takes time and patience like jump right where i needs to be, now i know u can if now you am i head up enough hard enough.'],
#  ['physics professor at work 10 had come to admit into ucsfs physical therapy department 18 im being challenged 2 keep my acceptance of it suffer like the rest of my goals.'],
#  ['i try to put my mistakes behind them, always look forwards till present, and whatever circumstance, good or not, ive gotten through it and always think m can do well again.'],
#  ['i however however will succeed in making my attempt on becoming to doctor as im havent had anything challenge me in the past.'],
#  ['i came here p both be and give assistance to those badly needed it, but to counter to stigma of healthcare being this crappy job.'],
#  ["i don't really like it but it took a part at a study but still hope to learn fast but hope that people love something now it should read better."],
#  ['i came down today. think im important to show up to classes no students looks boring and useless for exams.'],
#  ['this is his continuous campaign & challenges my cooperation and communication style.'],
#  ['i get bad scores on this first test id wanna give out but hed shouldnt either well know can still do the work hw and practice so it might predict better grades next week'],
#  ['physics its good though really pointless and kind of boring teaching, and partly because ill am doing the homework i just safe to challenge and challenge yourself with what this class throws within store.'],
#  ["i'm here i push on challenges, deal me frustrations, ultimately change people to who i desire to be."],
#  ['this guy made it so long and challenging like far, t l am slowly starting to take more life back.'],
#  ['this year only proved extremely uneven and tedious so far, and i am slowly learning to build my way back.'],
#  ['engineering is life but i wanna do m best in and so succeed.'],
#  ['i suppose it take time of patience to get to where my need to be, only to know i can succeed once i get my head cleared and focus inward.'],
#  ['i was a bit wary going into biol 230, when wasn sure whats i meant meant towards and seemed pretty intense, almost inyourface in the teaching aspect, so when researching about sci the knew i needed to sign up.'],
#  ['i will succeed the challenge and get through all of my hurdles how it places in me.'],
#  ['im here among all the mistakes ever to have taken and why learned nothing.'],
#  ['another reason i hate dying is te prove to myself maybe i can conquer it, if nothing else you do definitely believe that i CAN!'],
#  ['i wanted to er quick to say i went ahead and finished school, actually i only finished, but completed one major that most never thought i d be able lol complete.'],
#  ['i met here because i know high school is hard and i knew that doing some Physics education would benefit me to pass ur class.'],
#  ['the work methods that my dad eventually passed onto me have allowed my to survive the tough times which both drugs and education throw at life.'],
#  ['im good because i told u y decided to come here but away u went too prove it.'],
#  ['i ultimately want to be s immigration lawyer, especially here at the bay aka south east asians here keeps getting targeted by ice. Also here in this class because i truly hate science let me guess this was kind of interesting.'],
#  ['i am working to better or able provide resources to hospitals that need me, specifically to challenge societal stigma surrounding healthcare being of certain privilege.'],
#  ['i Im clearly her favoured student of the university, while often, friends find many ways difficult and are harder then be learn by others, but im am here to shove aside such challenges, and for certain those who are in my mindset.'],
#  ['im here says all the affected minority girls in do not achieve positive figures to look up or during their communities.'],
#  ['physics is the class that often can have a negative stigma to teachers, especially given how abstract these concepts can get, though i is nonetheless interested in the content and try to keep an analytical mind as i study it.as throughout college in general, i am here because i wish to gather the knowledge and experience to aid a math teacher, in fact to forming valuable connections with the people i meet along the way.'],
#  ['i want my represent career, I career, my education, myself my historical heritage - reinforcing the previous point that I do require some potential free leave.'],
#  ['i am included in this science community because they feel some notable people (- living and being naturally female) are strongly interested.'],
#  ['i actually seeking to provide myself unique opportunities to accomplish to something besides stereotypes and invest my resources towards other new generations with which to help them also accomplish all these goals and achieve to more than i can imagine.'],
#  ['to make HIS family great and prove myself that HE WILL make it, esp though there will lots of challenges.'],
#  ['i came into this knowing that founder would be unhappy and genuinely grateful of that cause he continues t keep my attention.'],
#  ['i typically struggle more studies groups, typically social behaviour studies with way less conceptual material so the benefit if asking questions that i answered in general to any small group environment gives one real confidence in everything.'],
#  ['ive has some complications that has come along moving off of home so theyve definitely proven your How hard it is to leave an adult except that your never going to go worse.'],
#  ['i will succeed the king and survive through life of the house this monster came at anyway.'],
#  ['not the am i having an imprint on a medical field treating women who are pregnant, but i am fundamentally changing gender gender norms.'],
#  ['along like that, completing a University degree proves that i should get persistent and finish what i have set.'],
#  ['this was the younger student to me with he will see mistakes yet learn with them.'],
#  ["i'm unstoppable -- push up obstacles, cope with adversity, and mold myself to what i poss t be."],
#  ['i commented here because i think its important people show up early games no matter how tired & early you re.'],
#  ['math always seem to give everyone a good bit of trouble, but i get on hang of it after long and too do as best my can.'],
#  ['also, u m an inexperienced medical doctor, and i is not a great influence from the public fields, So people came seeking help in a way.'],
#  ['i know her as a child she never thought of education as potential future for someone tha is undocumented.'],
#  ['i want on others no better put a position on concepts than they should as d o me struggling between articles after never fully understanding those specific topics.'],
#  ['i hope to reach another position in which i could write and introduce to others us we "immigrants" in the usa how only in surpassing struggle is possible.'],
#  ['must people try to get money, fame, life more stable life, seem to also mean too you, I is doing more about me that a lot one need to follow to achieve it pokemon more, myself.'],
#  ['initially, my motivation was based more around i finally proving everyone wrong, but eventually said motivation morphed into proving to myself that i can and will continue to improve myself system only through performance, but through life going well.'],
#  ['in my junior week of high school im had been approved to take physics, but we had a teacher that ill teach and just asked us to cheat on the tests enough that students wont look for a bad teacher, and im excited to get my real education on physics.'],
#  ['must people wants to get attention, status, or a stable life, and to deal real with that, studying become worth less to me that another goal i need to achieve to make a person happy, well.'],
#  ['i is here for prove that she must try anything in set my mind to, of just to others, and to myself as well.'],
#  ['not everyone will that casting an impact from a medical field of mostly working out doctors, but i am also changing American body culture.'],
#  ['i also had had some struggles training upper level science classes of the past because of the books and had thought that would be a wise idea to start a computer lab if its the extensive work involved inside understanding basic circuits.'],
#  ['physics around me seems less straightforward because it takes a fairly long studying upon intuitive observation to complete my understanding of astronomical material.'],
#  ['since the intro requirement is minimum one hundred on fifty words i will continue rambling on. i im a combat student and am coming back to school to learn roles more properly suited for daily operations, basically here to learn something thats mainly related with killing and dealing with guns all part those skills do is help soldiers interact in the cycle of protection culture of battle (cop, law, etc...).'],
#  ['i have to be in this class because no matter how accomplished you are, never matter how much you know in which business you see you are doing the best at, there is just uncertainty within controversy.'],
#  ['i will just try other websites to you class and this feel that this is where i can get to most. i i going here because i hopes you graduate on time or not fail any on my test.'],
#  ['i will then make sure you pursue all electronic techniques because physics is a fundamental subject.'],
#  ['i am here until finish what u did and make from the money u invested in to go to school.'],
#  ["going private equity full time whilst working over 400 hours a week or staying near anyone in either program has proven difficult but i've been determined to imprint what they have offered me onto paper on whatever ever i put my teeth behind."],
#  ["luckily, the second officer i see currently is really interesting, so don't fear staying other than to help and get things from her."],
#  ['i we could secure a position in which we might inspire and explain to all for us investing" on this street that achieving results defending these remain possible.'],
#  ['i believe this does become interesting but always believe that there needs to only a minimum of time and dedication to working with this lab like during classes and i can give my best that shine.'],
#  ['the work ethics that her upbringing has passed onto to think allowed me daily meet the change times and both worlds what sun throw for me.'],
#  ['i wont ti be able s claim i gained back amd finished school, I not been finished, the its so major that we never thought i would be able as graduate.'],
#  ['initially, first motivation was very focused around self - proving somebody wrong, so then that motivation bloomed into commitment to myself that actually do & will work to be myself not only in school, and through everything is well.'],
#  ['to grow as i wish to, but to quickly adapt and one day and continue and move forward with newly acquired knowledge.'],
#  ['i hope the road should not be dull, i know how i could jump beyond physical barriers that has attempted ot derail me.'],
#  ['i stay here a actually late as i want being taught and lecture, and then am mad or bored.'],
#  ['life doesnt seem too struggle to throw projects a window, as i reach know it achievable when i ask.'],
#  ["luckily, the art professor you have currently is really helpful however i don't remember staying back to get updates and understand further through her."],
#  ['to learn if i had to, as also to survive because i want to survive yet continue forward with the made knowledge.'],
#  ['i m not that experienced in math but must start trying.'],
#  ['i am also the beginner student in the university, that often, i try many topics hard and are used to to learn to others, but i am here to take on new challenges, and expand the limitations that are in school knowledge.'],
#  ['i also found chemistry to get too difficult therefore m not confident that class should help me along too.'],
#  ['i used a still be some quitter, and very early on at med school i decided that i im not smart enough to understand things but will have learned that dedication, passion, and hard work were necessary.'],
#  ['i need ti put some friends around em, and look forwards in positives, and whatever happens, superior or indifferent, ive worked with it so i know i will do better again.'],
#  ['although yes it can be very difficult i know what me being bitter can bring down many day therefore i w walking away hopefully draw encouraged for my strength and everything i did to get to that end.'],
#  ['a journey where learn, and make mistakes, have courage, somewhere that is important to you to rebuild confidence enough to meet problems.'],
#  ['however, college is really easy compared elsewhere cause there have been numerous moments where i have contemplated changing big if la and transferring to completely separate college but on look back i thought eh we all ready.'],
#  ['ive have the struggles moments naturally come upon moving away with family but its really reminded me how good business is to be an adult and that its really going to get easier.'],
#  ['im here bc i told myself people deserve to see here and today i get too prove it.']]

# %%
aug_data_pos_flat_list = [item for sublist in aug_data_pos_list for item in sublist]

aug_data_pos_flat_list
# Out:
# ['this is my first years taking physics in english so it been another rough course so i am hoping we still understand and learn using it.',
#  'in my sophomore year yr HS teacher i thats been excited wanna take physics, but he had a friend She didnt teach and just asked us to cheat all the tests and that she didnt look like a classroom teacher, so im instead everyone get a real deal on physics.',
#  'moving from San angeles to san Fernando, we came with the hope to learn how to become responsible & act for my safety and wants in a society where minorities like myself lay continually under attack and come from those lacking in resources.',
#  'as a first generation student, i am like t is my duty to break each generation of poverty and poor education and hopefully lead the first to see a hopeful path for higher development thus not be constrained to work.',
#  'i. also make notes or knew about complex material because there was another complex subject.',
#  'engineering is strong enough you will achieve success just in order ro pass.',
#  'i have struggled with modern physics since high school, however often enter every class with the certainty that day more revolution will begin.',
#  'i hope this semester with not only test me but also encourage me where I given up on struggling physically and am able not preserve until the finish.',
#  'even though physics became a quest i took for myself, i only registered as satisfy school application, but putting down my effort d learn more about physics cause attempting to apply mathematical information across the world seemed like something major.',
#  'i am here te change the number of women in Nigeria, to change a number of adult females reaching stem. i think u here ti make my country proud.',
#  'however, bio is really close from la so my have been many times when i had contemplated going back to la farther then to one community college but instead stand back and think that im already here.',
#  'i think physics will be hard still i trust that there needs to be really lot of time and can I try in small lab and prove it and i will do my utmost to succeed.',
#  'physics 1, science 2 are requirements to get though any physical therapy program so im not one to let my fear of math stand in class draft like an entry.',
#  'i also have experience some struggles with AP level math classes in the past because of the homework which i thought t would seem a terrible idea first take a AP class because of the extensive math involved like understanding the concepts.',
#  'i used to always fight a liberal, at as much were after graduate as they said that i had not qualified as to understand science as i has seen that dedication, willpower, and hard work are key.',
#  'this is My game system for my where i will catch mistakes and learn though them.',
#  'i believe u will attempt at making my dreams by racing with games because games havent helped anything stop us in I past.',
#  'i am here cos we want more badly, ive taken good work position after high school - barely.',
#  'i am not yet somewhat supplemental field but i know that i always find up poking around related topics in teaching.',
#  'i though a tad lost walking into sem 230, i made sure what ke knew looking into everything seemed pretty intense, also lacking in the teaching aspect, so when hearing about classes ac knew i needed too listen up.',
#  'this is a proper competition - test my cooperation and concentration ability.',
#  'while several months ahead been challenging, developers embrace the process while learning new lessons while addressing these obstacles.',
#  'i knew me journey will not be linear, i know that i must face every harsh times which will try and consume me.',
#  'to represent Asians that it is possible for minorities, the minority, too make performers, role models and consumers.',
#  "i dont want to be an activist lawyer, even back in my fair to old hours asians here love getting together against racism. i'm here in this mood although i still hate Trump i at least this is kind of interesting.",
#  'i just wish playing physics can be hard enough times, as i feel that guys have definitely put some time and effort to fully understand the model.',
#  'i love coding, and even though Im hard work theres hundreds of big ideas, i motivated via neuroscience.',
#  'i supposed to be easier to get the grasp on things an everyone can understand instead of just struggling through them and actually consistently understanding those specific topics.',
#  'i were here because of our different to us but i want more help lay a future.',
#  'a place to grow, to make mistakes, overcome things, and think are safe for people to be themselves or willingly face challenge.',
#  'physics, me is not intuitive and it means the lot of practice, hard research to achieve my understanding of a material.',
#  'i friend here lets me know that writing is fun and she knew it having a sci class might benefit students to take that seriously.',
#  'i figure got above that and was pushing myself anyway.',
#  'physics 2 seems difficult but instead of giving further than Socrates, the attitude includes ambition in determination.',
#  'since the journal requirement is minimum one hundred and fifty words i shall continue rambling on. i being a disabled veteran, so switching back to school to learn skills more properly suited for civilian use, basically here to learn something thats not related by killing and dealing with guns since having other skills do is result me else in the cycle of protection lines of work (cop, security, etc...).',
#  'i am doing too empower myself with help and get well something besides stereotypes i provide my resources to this new guy from them to help them fully come into our goals and achieve alot more than they can comprehend.',
#  'i will always try my hardest in EVERY area because i feel that this is where they can focus there best. my am also upset because i had to graduate on time to not owe any of my classes.',
#  'i realize how hard but actually enjoy pushing myself forward.',
#  'i want to celebrate myself, same gender, Latino ethnicity, and mt latina heritage and prove entire world wrong that you always have the ability to be.',
#  'life does seem to continue pushing throw punches our way, I truly believe anything is achieved when i fight.',
#  'i chose t tu in grad school because you matter how smart u look, either idea who much you eat and any course you think both better or so best at, there is simply room for you.',
#  'i slipped into behind marker during this recent project and, therefore i continue to make excuses for it using hard work during getting right.',
#  'i am here too believing that i can believe anything m set my mind to, not lying for myself, pretending to ourselves not to.',
#  'i screwed over a bit during this first demo here, but i intend ta fix up for it by good work and getting better.',
#  'even though this isnt a course yo do for myself, i only registered to take school requirements, im putting all my effort to know everything about physics and how to apply this all in this world and hopefully be major.',
#  'moving down des la es que francisco, it came from special interests she contemplate how to become all collective voice for those concerns and wants in in society where minorities like myself are constantly under attack and come into communities lacking in resources.',
#  'physics requires a lot on collaborative effort and precision work, and you ought to get help when ya need someone from beyond it may handle all important material, so so we will never fall overboard.',
#  'math still need to give me a little touch more slack, as i get a ton + praise for pushing on to achieve the best i do.',
#  'i did struggle with science courses, mainly physical science, with alot of conceptual frameworks so the importance of asking questions that would have for others in a small research environment helps me more confidence in research.',
#  'im sorry for all we beautiful colored girls who to once have Nigerian politicians to look back to for those communities.',
#  'i hope this semester doesnt u only support yr but also encourage u dont finally wake up and our cause and yr inspired to remain until thy light.',
#  'i never discovered physics to be very difficult and i was hoping your class will serve me with physics.',
#  'another sign im stayed alive cant just be by myself so meditation can do everything, if nothing bigger it can definitely DO everything i have!',
#  'school spirit always helped her escape the hard things we get lost doing.',
#  'i live here because i want fast sleep, ive taken ap physics test at middle school all struggle.',
#  'i prefer participating in natural science community because l feel that my species (of nature and being remotely black) are under represented.',
#  'i am call this sci11502 s intro final but know that i will finish up here with future topics in life.',
#  'i guess it takes time and patience like jump right where i needs to be, now i know u can if now you am i head up enough hard enough.',
#  'physics professor at work 10 had come to admit into ucsfs physical therapy department 18 im being challenged 2 keep my acceptance of it suffer like the rest of my goals.',
#  'i try to put my mistakes behind them, always look forwards till present, and whatever circumstance, good or not, ive gotten through it and always think m can do well again.',
#  'i however however will succeed in making my attempt on becoming to doctor as im havent had anything challenge me in the past.',
#  'i came here p both be and give assistance to those badly needed it, but to counter to stigma of healthcare being this crappy job.',
#  "i don't really like it but it took a part at a study but still hope to learn fast but hope that people love something now it should read better.",
#  'i came down today. think im important to show up to classes no students looks boring and useless for exams.',
#  'this is his continuous campaign & challenges my cooperation and communication style.',
#  'i get bad scores on this first test id wanna give out but hed shouldnt either well know can still do the work hw and practice so it might predict better grades next week',
#  'physics its good though really pointless and kind of boring teaching, and partly because ill am doing the homework i just safe to challenge and challenge yourself with what this class throws within store.',
#  "i'm here i push on challenges, deal me frustrations, ultimately change people to who i desire to be.",
#  'this guy made it so long and challenging like far, t l am slowly starting to take more life back.',
#  'this year only proved extremely uneven and tedious so far, and i am slowly learning to build my way back.',
#  'engineering is life but i wanna do m best in and so succeed.',
#  'i suppose it take time of patience to get to where my need to be, only to know i can succeed once i get my head cleared and focus inward.',
#  'i was a bit wary going into biol 230, when wasn sure whats i meant meant towards and seemed pretty intense, almost inyourface in the teaching aspect, so when researching about sci the knew i needed to sign up.',
#  'i will succeed the challenge and get through all of my hurdles how it places in me.',
#  'im here among all the mistakes ever to have taken and why learned nothing.',
#  'another reason i hate dying is te prove to myself maybe i can conquer it, if nothing else you do definitely believe that i CAN!',
#  'i wanted to er quick to say i went ahead and finished school, actually i only finished, but completed one major that most never thought i d be able lol complete.',
#  'i met here because i know high school is hard and i knew that doing some Physics education would benefit me to pass ur class.',
#  'the work methods that my dad eventually passed onto me have allowed my to survive the tough times which both drugs and education throw at life.',
#  'im good because i told u y decided to come here but away u went too prove it.',
#  'i ultimately want to be s immigration lawyer, especially here at the bay aka south east asians here keeps getting targeted by ice. Also here in this class because i truly hate science let me guess this was kind of interesting.',
#  'i am working to better or able provide resources to hospitals that need me, specifically to challenge societal stigma surrounding healthcare being of certain privilege.',
#  'i Im clearly her favoured student of the university, while often, friends find many ways difficult and are harder then be learn by others, but im am here to shove aside such challenges, and for certain those who are in my mindset.',
#  'im here says all the affected minority girls in do not achieve positive figures to look up or during their communities.',
#  'physics is the class that often can have a negative stigma to teachers, especially given how abstract these concepts can get, though i is nonetheless interested in the content and try to keep an analytical mind as i study it.as throughout college in general, i am here because i wish to gather the knowledge and experience to aid a math teacher, in fact to forming valuable connections with the people i meet along the way.',
#  'i want my represent career, I career, my education, myself my historical heritage - reinforcing the previous point that I do require some potential free leave.',
#  'i am included in this science community because they feel some notable people (- living and being naturally female) are strongly interested.',
#  'i actually seeking to provide myself unique opportunities to accomplish to something besides stereotypes and invest my resources towards other new generations with which to help them also accomplish all these goals and achieve to more than i can imagine.',
#  'to make HIS family great and prove myself that HE WILL make it, esp though there will lots of challenges.',
#  'i came into this knowing that founder would be unhappy and genuinely grateful of that cause he continues t keep my attention.',
#  'i typically struggle more studies groups, typically social behaviour studies with way less conceptual material so the benefit if asking questions that i answered in general to any small group environment gives one real confidence in everything.',
#  'ive has some complications that has come along moving off of home so theyve definitely proven your How hard it is to leave an adult except that your never going to go worse.',
#  'i will succeed the king and survive through life of the house this monster came at anyway.',
#  'not the am i having an imprint on a medical field treating women who are pregnant, but i am fundamentally changing gender gender norms.',
#  'along like that, completing a University degree proves that i should get persistent and finish what i have set.',
#  'this was the younger student to me with he will see mistakes yet learn with them.',
#  "i'm unstoppable -- push up obstacles, cope with adversity, and mold myself to what i poss t be.",
#  'i commented here because i think its important people show up early games no matter how tired & early you re.',
#  'math always seem to give everyone a good bit of trouble, but i get on hang of it after long and too do as best my can.',
#  'also, u m an inexperienced medical doctor, and i is not a great influence from the public fields, So people came seeking help in a way.',
#  'i know her as a child she never thought of education as potential future for someone tha is undocumented.',
#  'i want on others no better put a position on concepts than they should as d o me struggling between articles after never fully understanding those specific topics.',
#  'i hope to reach another position in which i could write and introduce to others us we "immigrants" in the usa how only in surpassing struggle is possible.',
#  'must people try to get money, fame, life more stable life, seem to also mean too you, I is doing more about me that a lot one need to follow to achieve it pokemon more, myself.',
#  'initially, my motivation was based more around i finally proving everyone wrong, but eventually said motivation morphed into proving to myself that i can and will continue to improve myself system only through performance, but through life going well.',
#  'in my junior week of high school im had been approved to take physics, but we had a teacher that ill teach and just asked us to cheat on the tests enough that students wont look for a bad teacher, and im excited to get my real education on physics.',
#  'must people wants to get attention, status, or a stable life, and to deal real with that, studying become worth less to me that another goal i need to achieve to make a person happy, well.',
#  'i is here for prove that she must try anything in set my mind to, of just to others, and to myself as well.',
#  'not everyone will that casting an impact from a medical field of mostly working out doctors, but i am also changing American body culture.',
#  'i also had had some struggles training upper level science classes of the past because of the books and had thought that would be a wise idea to start a computer lab if its the extensive work involved inside understanding basic circuits.',
#  'physics around me seems less straightforward because it takes a fairly long studying upon intuitive observation to complete my understanding of astronomical material.',
#  'since the intro requirement is minimum one hundred on fifty words i will continue rambling on. i im a combat student and am coming back to school to learn roles more properly suited for daily operations, basically here to learn something thats mainly related with killing and dealing with guns all part those skills do is help soldiers interact in the cycle of protection culture of battle (cop, law, etc...).',
#  'i have to be in this class because no matter how accomplished you are, never matter how much you know in which business you see you are doing the best at, there is just uncertainty within controversy.',
#  'i will just try other websites to you class and this feel that this is where i can get to most. i i going here because i hopes you graduate on time or not fail any on my test.',
#  'i will then make sure you pursue all electronic techniques because physics is a fundamental subject.',
#  'i am here until finish what u did and make from the money u invested in to go to school.',
#  "going private equity full time whilst working over 400 hours a week or staying near anyone in either program has proven difficult but i've been determined to imprint what they have offered me onto paper on whatever ever i put my teeth behind.",
#  "luckily, the second officer i see currently is really interesting, so don't fear staying other than to help and get things from her.",
#  'i we could secure a position in which we might inspire and explain to all for us investing" on this street that achieving results defending these remain possible.',
#  'i believe this does become interesting but always believe that there needs to only a minimum of time and dedication to working with this lab like during classes and i can give my best that shine.',
#  'the work ethics that her upbringing has passed onto to think allowed me daily meet the change times and both worlds what sun throw for me.',
#  'i wont ti be able s claim i gained back amd finished school, I not been finished, the its so major that we never thought i would be able as graduate.',
#  'initially, first motivation was very focused around self - proving somebody wrong, so then that motivation bloomed into commitment to myself that actually do & will work to be myself not only in school, and through everything is well.',
#  'to grow as i wish to, but to quickly adapt and one day and continue and move forward with newly acquired knowledge.',
#  'i hope the road should not be dull, i know how i could jump beyond physical barriers that has attempted ot derail me.',
#  'i stay here a actually late as i want being taught and lecture, and then am mad or bored.',
#  'life doesnt seem too struggle to throw projects a window, as i reach know it achievable when i ask.',
#  "luckily, the art professor you have currently is really helpful however i don't remember staying back to get updates and understand further through her.",
#  'to learn if i had to, as also to survive because i want to survive yet continue forward with the made knowledge.',
#  'i m not that experienced in math but must start trying.',
#  'i am also the beginner student in the university, that often, i try many topics hard and are used to to learn to others, but i am here to take on new challenges, and expand the limitations that are in school knowledge.',
#  'i also found chemistry to get too difficult therefore m not confident that class should help me along too.',
#  'i used a still be some quitter, and very early on at med school i decided that i im not smart enough to understand things but will have learned that dedication, passion, and hard work were necessary.',
#  'i need ti put some friends around em, and look forwards in positives, and whatever happens, superior or indifferent, ive worked with it so i know i will do better again.',
#  'although yes it can be very difficult i know what me being bitter can bring down many day therefore i w walking away hopefully draw encouraged for my strength and everything i did to get to that end.',
#  'a journey where learn, and make mistakes, have courage, somewhere that is important to you to rebuild confidence enough to meet problems.',
#  'however, college is really easy compared elsewhere cause there have been numerous moments where i have contemplated changing big if la and transferring to completely separate college but on look back i thought eh we all ready.',
#  'ive have the struggles moments naturally come upon moving away with family but its really reminded me how good business is to be an adult and that its really going to get easier.',
#  'im here bc i told myself people deserve to see here and today i get too prove it.']

# %%
syn_aug = naw.SynonymAug(aug_src='wordnet')
type(syn_aug)
# Out:
# nlpaug.augmenter.word.synonym.SynonymAug

# %%
syn_aug = naw.SynonymAug(aug_src='wordnet')

def dataset_augmentor(df, augmentor=syn_aug):

    list_to_augment = df[df['label'] == 1].sentence.to_list()

    aug_list = []

    for i in list_to_augment:
        new_data = augmentor.augment(i)
        aug_list.append(new_data[0])

    aug_df = pd.DataFrame()

    aug_df['sentence'] = aug_list
    aug_df['label'] = [1 for i in range(len(aug_list))]
    aug_df['phrase'] = [pd.NA for i in range(len(aug_list))]

    concat_df = pd.concat([df, aug_df])

    concat_df = shuffle(concat_df, random_state=seed)

    pos_labels = len([n for n in concat_df['label'] if n==1])
    print("Positive labels present in the dataset : {}  out of {} or {}%".format(pos_labels, len(concat_df['label']), (pos_labels/len(concat_df['label']))*100))

    return concat_df

# %%
training_aug_syn_df = dataset_augmentor(training_df, syn_aug)
training_aug_syn_df
# Out:
# Positive labels present in the dataset : 278  out of 1171 or 23.740392826643895%
#                                               sentence  label  \
# 630  going into this course i feel uncertain about ...      0
# 41   i slip up a bit during this late slip hither, ...      1
# 450  i have goals that benefit not just myself but ...      0
# 233  right now, i am really stuck on vectors and ca...      0
# 299  the bigger reason for why i am here as sf stat...      0
# ..                                                 ...    ...
# 578  of course, because of my proficiency of theore...      0
# 242  turns out i'm not as interested and my last la...      0
# 837                 honestly speaking, i have no idea.      0
# 112  i chose to live in this class because no matte...      1
# 275          "why am i here" is a very broad question.      0
#
#                                                 phrase
# 630  ['Im putting all my effort to learn more about...
# 41                                                 NaN
# 450  ['I know the journey will not be linear, I kno...
# 233  ['I am taking the physics SCI class because I ...
# 299  ["After working minimum wage part time jobs wh...
# ..                                                 ...
# 578  ['This is a challenging class that test my coo...
# 242  ["Luckily, the lab professor I have currently ...
# 837  ['First of all, it is mandatory and I do not w...
# 112                                                NaN
# 275  ['First of all, it is mandatory and I do not w...
#
# [1171 rows x 3 columns]

# %%
test_aug_syn_df = dataset_augmentor(test_df, syn_aug)
test_aug_syn_df
# Out:
# Positive labels present in the dataset : 70  out of 294 or 23.809523809523807%
#                                               sentence  label  \
# 29   im hoping by the end of this course i can take...      0
# 24   i be hither to actually understand what unity ...      1
# 41   physics 2 is difficult yet instead of giving u...      1
# 2    while it am not personally best when informati...      1
# 109  i usually am only interested in the courses th...      0
# ..                                                 ...    ...
# 242  i am here to make my familys sacrifices worth it.      0
# 174  to show them that it lies still in us, a tribe...      1
# 190  i am also here in this lab to get a better und...      0
# 120  hopefully, this class can help me overcome my ...      0
# 16   my client ha been the typical little beauty sa...      1
#
#                                                 phrase
# 29   ['Im here to be more involved and focused on c...
# 24                                                 NaN
# 41                                                 NaN
# 2                                                  NaN
# 109  ['Even though some classes can be very difficu...
# ..                                                 ...
# 242  ['Firstly, I am here to challenge myself and m...
# 174                                                NaN
# 190  ['Physics for me is not easy and it takes a lo...
# 120  ['Physics is difficult for me and I need all t...
# 16                                                 NaN
#
# [294 rows x 3 columns]

# %%
MAXLEN = 150

# %%
X = training_aug_syn_df['sentence']
y = training_aug_syn_df['label']

# %%
import ktrain
from ktrain import text
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 18, stratify=y)

model_name = 'bert-base-cased'

bert_transformer = text.Transformer(model_name, maxlen=MAXLEN, class_names=[0,1])
training_set = bert_transformer.preprocess_train(X_train.tolist(), y_train.tolist())
validation_set = bert_transformer.preprocess_test(X_test.tolist(), y_test.tolist())
bert_base_model = bert_transformer.get_classifier()
# Out:
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 23
# 	95percentile : 42
# 	99percentile : 55
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 23
# 	95percentile : 43
# 	99percentile : 58
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Define classes and class labels
classes = np.array([0, 1])
class_labels = list(training_aug_syn_df.label)

# Compute class weights
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=class_labels)

# Print class weights
print(class_weights)

class_weights = {0:0.6556551,1:2.10611511}
# Out:
# [0.6556551  2.10611511]

# %%
import tensorflow as tf
import numpy as np
import os
import random
def reset_random_seeds(seed=2):
    os.environ['PYTHONHASHSEED']=str(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

# %%
# Build BERT model
# model = text.text_classifier('distilbert', train_data=(X_train, y_train), preproc=distillbert_transformer)
learner = ktrain.get_learner(bert_base_model, train_data=training_set, val_data=validation_set, batch_size=6)
# learner.fit_onecycle(2e-5, 5)
# learner.autofit(2.27E-06, early_stopping=4)
learner.autofit(2e-5, early_stopping=3, class_weight=class_weights)
# distillbert_learner.set_weight_decay(0.001)
# distillbert_learner.autofit(2.27E-06, early_stopping=4, class_weight=class_weights)
# Out:
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 2e-05...
# Epoch 1/1024
# 137/137 [==============================] - 55s 399ms/step - loss: 0.0180 - accuracy: 0.9963 - val_loss: 0.4462 - val_accuracy: 0.9176
# Epoch 2/1024
# 137/137 [==============================] - 52s 373ms/step - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.4357 - val_accuracy: 0.9176
# Epoch 3/1024
# 137/137 [==============================] - 51s 369ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 0.4606 - val_accuracy: 0.9176
# Epoch 4/1024
# 137/137 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9951
# Epoch 00004: Reducing Max LR on Plateau: new max lr will be 1e-05 (if not early_stopping).
# 137/137 [==============================] - 49s 355ms/step - loss: 0.0218 - accuracy: 0.9951 - val_loss: 0.4965 - val_accuracy: 0.9148
# Epoch 5/1024
# 137/137 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9963Restoring model weights from the end of the best epoch: 2.
# 137/137 [==============================] - 51s 371ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.4584 - val_accuracy: 0.9205
# Epoch 5: early stopping
# Weights from best epoch have been loaded into model.

# %%
learner.validate(class_names=bert_transformer.get_classes())
# Out:
# 11/11 [==============================] - 5s 395ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       268
#            1       0.97      0.68      0.80        84
#
#     accuracy                           0.92       352
#    macro avg       0.94      0.84      0.87       352
# weighted avg       0.92      0.92      0.91       352
# array([[266,   2],
#        [ 27,  57]])

# %%
bert_predictor = ktrain.get_predictor(learner.model, preproc=bert_transformer)

bert_test_data = test_aug_syn_df['sentence'].tolist()
bert_test_label = test_aug_syn_df['label'].tolist()

y_pred_bert = bert_predictor.predict(bert_test_data)

y_pred_bert = [int(x) for x in y_pred_bert]

tn, fp, fn, tp = confusion_matrix(bert_test_label, y_pred_bert).ravel()
print('True Negative: {}, False Positive: {}, False Negative: {}, True Positive: {}'.format(tn, fp, fn, tp))

print('  Classification Report:\n',classification_report(bert_test_label,y_pred_bert),'\n')
# Out:
# True Negative: 219, False Positive: 5, False Negative: 27, True Positive: 43
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       224
#            1       0.90      0.61      0.73        70
#
#     accuracy                           0.89       294
#    macro avg       0.89      0.80      0.83       294
# weighted avg       0.89      0.89      0.88       294

# %%
bert_predictor = ktrain.get_predictor(learner.model, preproc=bert_transformer)

bert_test_data = test_df['sentence'].tolist()
bert_test_label = test_df['label'].tolist()

y_pred_bert = bert_predictor.predict(bert_test_data)

y_pred_bert = [int(x) for x in y_pred_bert]

tn, fp, fn, tp = confusion_matrix(bert_test_label, y_pred_bert).ravel()
print('True Negative: {}, False Positive: {}, False Negative: {}, True Positive: {}'.format(tn, fp, fn, tp))

print('  Classification Report:\n',classification_report(bert_test_label,y_pred_bert),'\n')
# Out:
# True Negative: 219, False Positive: 5, False Negative: 22, True Positive: 13
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       224
#            1       0.72      0.37      0.49        35
#
#     accuracy                           0.90       259
#    macro avg       0.82      0.67      0.72       259
# weighted avg       0.88      0.90      0.88       259

# %% [markdown]
# ### 2. Contextual based

# %%
text = "The quick brown fox jumped over the lazy dog"
contextual_aug = naw.ContextualWordEmbsAug(
    model_path='roberta-base', action="substitute")
augmented_text = contextual_aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumped over the lazy dog
# Augmented Text:
# ['The quick brown fox towers over the menacing canine']

# %%
training_aug_context_df = dataset_augmentor(training_df, contextual_aug)
training_aug_context_df
# Out:
# Positive labels present in the dataset : 278  out of 1171 or 23.740392826643895%
#                                               sentence  label  \
# 630  going into this course i feel uncertain about ...      0
# 41   i slipped off a bit from the recent trip there...      1
# 450  i have goals that benefit not just myself but ...      0
# 233  right now, i am really stuck on vectors and ca...      0
# 299  the bigger reason for why i am here as sf stat...      0
# ..                                                 ...    ...
# 578  of course, because of my proficiency of theore...      0
# 242  turns out i'm not as interested and my last la...      0
# 837                 honestly speaking, i have no idea.      0
# 112  i chose myself be in ballet class because no m...      1
# 275          "why am i here" is a very broad question.      0
#
#                                                 phrase
# 630  ['Im putting all my effort to learn more about...
# 41                                                 NaN
# 450  ['I know the journey will not be linear, I kno...
# 233  ['I am taking the physics SCI class because I ...
# 299  ["After working minimum wage part time jobs wh...
# ..                                                 ...
# 578  ['This is a challenging class that test my coo...
# 242  ["Luckily, the lab professor I have currently ...
# 837  ['First of all, it is mandatory and I do not w...
# 112                                                NaN
# 275  ['First of all, it is mandatory and I do not w...
#
# [1171 rows x 3 columns]

# %%
X = training_aug_context_df['sentence']
y = training_aug_context_df['label']

# %%
import ktrain
from ktrain import text
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 18, stratify=y)

model_name = 'bert-base-cased'

bert_transformer = text.Transformer(model_name, maxlen=MAXLEN, class_names=[0,1])
training_set = bert_transformer.preprocess_train(X_train.tolist(), y_train.tolist())
validation_set = bert_transformer.preprocess_test(X_test.tolist(), y_test.tolist())
bert_base_model = bert_transformer.get_classifier()
# Out:
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 23
# 	95percentile : 42
# 	99percentile : 55
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 23
# 	95percentile : 43
# 	99percentile : 60
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Define classes and class labels
classes = np.array([0, 1])
class_labels = list(training_aug_context_df.label)

# Compute class weights
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=class_labels)

# Print class weights
print(class_weights)

class_weights = {0:0.6556551,1:2.10611511}
# Out:
# [0.6556551  2.10611511]

# %%
# Build BERT model
# model = text.text_classifier('distilbert', train_data=(X_train, y_train), preproc=distillbert_transformer)
learner = ktrain.get_learner(bert_base_model, train_data=training_set, val_data=validation_set, batch_size=6)
# learner.fit_onecycle(2e-5, 5)
# learner.autofit(2.27E-06, early_stopping=4)
learner.autofit(2e-5, early_stopping=3, class_weight=class_weights)
# distillbert_learner.set_weight_decay(0.001)
# distillbert_learner.autofit(2.27E-06, early_stopping=4, class_weight=class_weights)
# Out:
# reduce_on_plateau automatically enabled at patience=2
#
#
# begin training using triangular learning rate policy with max lr of 2e-05...
# Epoch 1/1024
# 156/156 [==============================] - 144s 671ms/step - loss: 0.5714 - accuracy: 0.7233 - val_loss: 0.3387 - val_accuracy: 0.9021
# Epoch 2/1024
# 156/156 [==============================] - 64s 406ms/step - loss: 0.2257 - accuracy: 0.9199 - val_loss: 0.2363 - val_accuracy: 0.9277
# Epoch 3/1024
# 156/156 [==============================] - 62s 396ms/step - loss: 0.0618 - accuracy: 0.9850 - val_loss: 0.3909 - val_accuracy: 0.9064
# Epoch 4/1024
# 156/156 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9829
# Epoch 00004: Reducing Max LR on Plateau: new max lr will be 1e-05 (if not early_stopping).
# 156/156 [==============================] - 65s 412ms/step - loss: 0.0506 - accuracy: 0.9829 - val_loss: 0.4209 - val_accuracy: 0.9064
# Epoch 5/1024
# 156/156 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9882Restoring model weights from the end of the best epoch: 2.
# 156/156 [==============================] - 64s 404ms/step - loss: 0.0360 - accuracy: 0.9882 - val_loss: 0.4648 - val_accuracy: 0.8979
# Epoch 5: early stopping
# Weights from best epoch have been loaded into model.

# %%
learner.validate(class_names=bert_transformer.get_classes())
# Out:
# 8/8 [==============================] - 25s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       179
#            1       1.00      0.70      0.82        56
#
#     accuracy                           0.93       235
#    macro avg       0.96      0.85      0.89       235
# weighted avg       0.93      0.93      0.92       235
# array([[179,   0],
#        [ 17,  39]])

# %%
training_aug_context_df.sentence.to_list()
# Out:
# ['going into this course i feel uncertain about how well i will do, since the last time i took this class was in high school.',
#  'i slipped off a bit from the recent trip there, but still continue to make observations regarding it using just work on getting results.',
#  'i have goals that benefit not just myself but also my family as well.',
#  'right now, i am really stuck on vectors and calculating vectors.',
#  'the bigger reason for why i am here as sf state is to get my degree to get a hopefully get a decent to well paying job when i graduate.',
#  'i guess that the college experience, but i have made it this long, these past three years have been a quite a challenging journey, adjusting my school schedule with work is still a hassle.',
#  'i will always try my hardest in this class because i feel that this is where i can learn the best. i am also here because i want to graduate on time and not fail any of my classes.',
#  'i am here because i want to get a degree.',
#  'most importantly, i am here because of my fiancee, jordan.',
#  'i am in sci 111 so i can keep myself motivated to do better, improve, and gain a better understanding on what is going on in my physics class.',
#  'i have suspected physics could be very difficult -- w m hoping this survey will help me pass physics.',
#  'i feel like i am meant to be here.',
#  'i the always her first student of the university, while often, i find her ways difficult and much harder so quickly learn by others, but im am here to take from my challenges, maybe expand certain limitations that are just my mindset.',
#  'my parents were immigrants and teen parents so growing up i was at a disadvantage when it came to schools.',
#  'that was my favorite thing to do back home in the sunny weather because its too gloomy and cold up here.',
#  'i want to inspire others and help them have what i never had.',
#  'i understand it adds time and patience lets be to you i want to go, so i know u can reach once you get i head the me up enough.',
#  'now i want to have a try to touch with practice so in my mind there exists a motivation of taking part in the physics lab class.',
#  'why am i here?',
#  'i honestly didnt know anything about physics before taking the class, since i never took a class in high school.',
#  "i am here because i want to get a bachelor's degree on my major of kinesiology.",
#  'i want to make an impact in this world, even if it is a small dent.',
#  'the only way that im able to create a better future for my community is by getting a phd and create data dedicated in my community and create policy targeted towards my community.',
#  'my mom and dad cemented in me that the only way to avoid such a hectic beginning to life was to go to college right after high school, since that is what they wished they would have done.',
#  'i am excited to study what makes the physical world work and cant wait for this class to shed some insight into how the physical world around me.',
#  'taking physics now in college terrifies me knowing that i do not have any knowledge from it at all.',
#  "i'm also in this class to discover what i really want to do for the rest if my life.",
#  'i have heard nothing but good things about these classes, and so far what i have heard is true.',
#  'i intend to reach my goal no matter what, but first i need to finish all of my prerequisites in order to get to my cinema classes.',
#  'i want to be able to get a grasp on concepts that i dont understand instead of just struggling through them and never fully understanding those specific topics.',
#  'the field where women are appreciated less and less accounted for when compared to their male counterparts.',
#  'since computer engineering is also an engineering degree its requirements are very similar to electrical engineering which means all the same science class.',
#  'also, it is the last physics series i would need to complete and move on forward for additional classes until it is time to graduate from this university.',
#  'i used to always fight a liberal, and as much months after graduate school they decided that i was not smart enough to understand science Now i have learned that dedication, willpower, and hard work are key.',
#  'i think its vital to feel a class interesting.',
#  'since i will need to perhaps take another class of physics after this semester, i wanted to fully understand the material as opposed to just completing the material so i can just complete the class.',
#  'i want to be able to have options, and being educated in a useful skill like computer science makes that much easier to achieve.',
#  'meeting people along the way and getting to know them helps because i may be stuck or not able to progress without help, so knowing i can count on others lets me focus on what im working on and not how i will fail.',
#  'another reason why i am here is that i would be the first in my family to be able to go to college and pursue a degree in biology.',
#  'it here to learn new things, meet new people, and to be able to learn the culture and how is the america dream that a lot of people from the different country dream of.',
#  'during this class, i work with my partner.',
#  'i try to put my mistakes behind me, and look forwards the future, and whatever happens, good or bad, ive gotten through it and i know i can do it again.',
#  'the reason i am in this sci course is to support and solidify my knowledge in physics so that i can have a full understanding of the material going into a test.',
#  'how did i come to be here?',
#  'i am here to make my familys sacrifices worth it.',
#  'however, i am here because i have goals and i want to pursue a career in the medical field hopefully leading my way to becoming a neonatal doctor.',
#  'i cant take any other courses for my major until i take ochem so im in a weird state of relaxation.',
#  "but then there's physics.",
#  'when i chose this major out of interest i didnt look into how challenging it is.',
#  'going to class can be more clear than just reading from a book because you have explanations to help you.',
#  'sometimes i feel that i am too old to be in school especially this semester.',
#  'i just think that physics can be hard at times, so i know that ill have to put in time and effort to fully understand the material.',
#  'i believe i will succeed in making my goal of becoming a doctor because i havent had anything stop me in the past.',
#  'while several months having been challenging, i appreciate the process of learning new methods and addressing these obstacles.',
#  'i got bad grade on my first test wanted wanna give out but i shouldnt and well know will still do the test hw and practice so i might predict better grades next time',
#  'becoming a doctor has been a lifelong dream of mine and i plan on enjoying my journey with amazing opportunities here at sfsu.',
#  'i got bad grade on the first test i t give fault but im shouldnt and well im can still do the test hw and now so i wil predict better on next time',
#  'i am a fan of science and i am upset with all the antiscience bias that the world is seemingly going through right now and the best way to combat that is through education and enlightenment.',
#  'people around the clock trying to decide what aspects of their lives involve only needs or wants.',
#  'i chose this major because i enjoy science and as much as i wish i was good at it, i suck at math.',
#  "i really want to be an immigration lawyer, especially here in the bay since south east asians here are getting targeted by ice. i'm here in this class because i truly hate science and at least this is kind of interesting.",
#  'i am excited to enter into a new field of study that i have never actually learned before.',
#  'taking this class in particular was meant to assist me in fulfilling my general education and pushing me towards receiving my credits toward my intended areas of study.',
#  'it is also very difficult for me to understand since it does not spark my interests.',
#  'ive seen what good and bad doctors have done to people suffering from cancer and i would like to become someone that works in this field and treats their patients with care.',
#  "i thought it couldn't hurt anything and it would just be an extra study session that i would get college credit for.",
#  'i am here making me know that physics is hard and i knew it taking a sci course might benefit students to take that major.',
#  'i know here to actually kind of do aid for hospitals where needed again, and to not to stress around healthcare being this certain job.',
#  'i believe that sci 111 will help me get there.',
#  'to learn because i have to, but also to learn because i want to survive and move forward with newly acquired knowledge.',
#  'however, that is not the only medical research i would do, i would love to do more than that, thats why i am here.',
#  'i am currently in my 2nd year, and i plan to have my 120 credits achieved by the end of my 4th year, in 2022.',
#  'i wouldnt be here if it wasnt for my parents constant support financially, physically, and mentally.',
#  'i am here to be able to learn and capture as much knowledge as i can in my path to achieving one of the many goals i have set myself to accomplish.',
#  'i am here to expand my knowledge of the world around me and to converse with my peers to grow as a person.',
#  'i screwed about that bit during that freshman year here, but you intend to make up for things playing hard graft and getting results.',
#  'this is not meant to be a formal essay.',
#  'i think its hard when i kinda love myself lol.',
#  'ive had some struggles that naturally come with moving away from family but theyve really showed me how hard it is to be an adult and that its not going to get easier.',
#  'all of unit one and unit two are where i am struggling.',
#  'why am i here?',
#  'i do not know what it is though, but it is a nice thought.',
#  'my first step to getting there is obtaining my undergraduate degree, which requires for me to past this physics 122 course.',
#  'i am here to finish what i started and make all the money i invested in worth going to school.',
#  'lastly, i hope i am able to learned from the labs and have the professor help the entire class throughout the lab as a whole group.',
#  'despite the fact that i need this class for my major (biology), i am at college because i hope to learn both inside and outside of the classroom as well as ideally apply what i learn in school to the real world.',
#  'ive only been into one class of sci 111 so far and it is definitely helpful.',
#  'when this semester began, i quickly realized that it was quite the opposite.',
#  'i made the mistake of not taking a sci class when i was in calculus, and my grades suffered from it.',
#  'i am international student and i come from china.',
#  'this is why i am motivated to keep going to school and work hard because im the only whom has this opportunity thread a path of a better education, thus is one of my goals to inspire future family generations and help them out and continue the cycle and break it.',
#  'i am in this somewhat supplemental field so i know that i always winds up concerned with difficult topics in teaching.',
#  'the reason of this is because i began to slack off towards the end of the semester because i was barely coasting by the course with a decent grade and as the course became harder and the longer i did not reach out for help.',
#  'i love coding, and even though Im hard and theres u lot big struggles, im shaped by neuroscience.',
#  'i want to save lifes.',
#  'i want to make myself proud and my family.',
#  'jordan passed away unexpectedly this year, on march 2nd, 2019.',
#  'to appreciate all the unique backgrounds, cultures and experiences.',
#  'it all started ever since i got injured playing basketball.',
#  'being in this instituion will pave a way for me to become a professional.',
#  'i have attended the physics lab class this semester.',
#  'i am here because i want to make a positive difference in this world.',
#  'i decided to take this class because i knew that i was definitely going to struggle and i really do not want to fail my physics class.',
#  'i am here because i always wanted to be involved in the stem field ever since i have been a little kid.',
#  "i want to contribute my knowledge that i've gain since i've been at sf state to those around me and become a role model for my younger cousins back where i'm from.i am also here because i want to gain new perspective from my peers because",
#  'i felt comfortable with them and it gave me time to ask specific questions that i had and have something close to a one on one explanation.',
#  'science is my weakest subject.',
#  'im attending sfsu because i am trying to get a major in physiology.',
#  'besides that this week i have been trying to focus on finding my routine.',
#  'i hope that after taking this class i would be more confident in tackling physics problems and applying it further in my field especially since i am interested in biomechanics.',
#  'why i am here is because i want to fulfill my families dreams and my own dreams of becoming a successful obgyn one day.',
#  "i'm willing t root through obstacles, live with fears, and mold myself into what l want t be.",
#  'at the end of the day i just know to keep my eyes ok the prize and the rest will come along.',
#  'i believe i will succeed at making my dreams by racing professional runner because it havent had anything stop me in from past.',
#  'she did not know how to teach the students in a way that we would be able to learn the concept.',
#  'a place to learn, to make mistakes, overcome challeneges, and that is safe for them to be themselves and to meet others.',
#  'i do enjoy learning more about science in general.',
#  'my parents are my motivators, they work so hard to give me everything they can and i want all their efforts to be worth it.',
#  'with a community i would feel comfortable enough to ask questions without having to worry about sounding unintelligent.',
#  'having a degree will have more opportunity such as better job offers in order to support the family needs.',
#  'my overall goal as to why i am in college is to become a physical therapist.',
#  'the standard i set for myself is very low, but i hope to change that.',
#  "since i didn't get accepted into the architecture schools i applied for, i decided to move towards san francisco state in order to study computer science.",
#  'this can then give me an opportunity to take the next step and find my purpose and be successful in life.',
#  'for example, applying to it to bigger questions like how to the world works the way it does.',
#  'not only am i making an impact on a medical field while every working are doctors, but i am also changing American body culture.',
#  'physics to me has a lot of complicated parts and a lot of formulas.',
#  'im here because i want students to experience the opportunities and community that i have built when i took the sci 115 class myself.',
#  'this is why i decided to sign up for sci 111 and receive the extra help i knew was necessary in order for me to pass this class.',
#  'im here to learn and will try my utmost best to obtain a b grade ill take a c but want to aim for a b. the reason a is not mentioned is because i realize the challenge in front of me and with current course load i will be multifocusing so all my time and effort will not be in this class alone.',
#  'the homework seriously causes me so much stress and its only the fourth week of the semester.',
#  'im here because i want to be apart of a new community.',
#  'going private school every day after working over 30 hours an week and school near anyone to my program has so difficult me ill been determined to transfer what people have taught me onto excel on what ever i put my teeth behind.',
#  "everything else feels out of reach, so hopefully, i'll find a reason to stay in science while enjoying what i do",
#  'i no longer hate math or physics and i have learned to cope with them.',
#  'it was hard but my parents always prioritized school first for my sister and me.',
#  'i am studying physiology in hopes of going to medical school to become an oncologist.',
#  'i am here to do everything i started i make all this money its left in worth going home school.',
#  "on the other hand, i want to take full advantage of the new environment and lack of distractions to fully immerse myself in the college career i've chosen to undertake.",
#  "and even though it hasn't been easy, it definitely has been worth it.",
#  'i hope that through sci i will also be able to grow as an individual.',
#  'i am here at sfsu to grow my knowledge in all of these subjects, which will help me succeed in the future.',
#  'at the sci classes, we usually go over worksheets that answer my questions.',
#  'when i think about why am i here, many questions arise like why am i in this class?',
#  'it should be streamofconciousness writing from the heart.',
#  'in high school i opted out of physics and took courses like physiology and forensics science.',
#  'i want to learn not memorize, and understand and not _.',
#  'the class is much easier than i expected it to be, however its only the first month of the class, so its bound to get harder sometime soon.',
#  'since the journal requirement is minimum one hundred and fifty words i shall continue rambling on. i im a combat veteran and am coming back to school to learn roles more properly suited for civilian interaction, basically here to learn something thats mainly related towards killing and dealing with guns but all those skills do is help soldiers stay in the cycle of protection culture of battle (cop, law, etc...).',
#  'i feel like physics is a good combination of math and science versus other science classes ive taken before.',
#  'why am i here?',
#  'thus, i am here to learn physics and more to get better.',
#  'i am here because i am a first generation college student and i am interested in the medical field.',
#  'so far in my college career i have managed to get okay grades but still succeed when i am not doing so well in a class.',
#  'i am here because i want to learn, ive taken ap physics before in high school but struggle.',
#  'i was looking for something similar with phys 111, so thats why im here.',
#  "i'm taking astronomy because i realized animal diversity didn't have a lab.",
#  'i will succeed the class and get through life and the punishments this ultimately came at me.',
#  'i am here to build off of what we learn in class, ask questions about topics that i am not understanding, and to build study groupsrelationships with my fellow peers.',
#  'physics 1 + physics 2 are requirements to integrate onto ucsfs physical therapy program so first just going go let my dread of failure stand in le way of other goals.',
#  'i want to create change and its all about finding ways to make those changes.',
#  'i have already used the knowledge of my peers in this sci class to solve a problem i was not familiar with.',
#  'i am here solely to learn.',
#  'this semester i want to prove to myself that i am smart and capable of passing this class with an a. i want to actually learn the concepts and not come into class everyday confused and lost.',
#  'specifically speakers, im here today in this sci class because i need help with calculating valence electrons,atomic orbitals, and electron configuration.',
#  "i'm here because i have a dream and i will accomplish it.",
#  'in a year i lost everything but now that i have come back, it almost feels as if i was meant to be here at this exact time in my life.',
#  'although i it may be terribly discouraging i know what me being negative can pay off one day and i can come away and draw encouraged from my strength and everything i did i come to those time.',
#  'i understand it takes time and patience to be to where i want to be, so i know u can if once i am i head clear enough do enough.',
#  'i am here because i fell in love with thee whole concept of chemistry, i am deeply interested in science and i want to prove to myself that i can actually become a chemist or a dermatologist.',
#  'i. also make notes We learn about the material because physics is a complex subject.',
#  'if i had classmates that didnt really care about the assignment at hand and did something else the entire time, then it would be very difficult for me to work as hard as i do on the various experiments with other people.',
#  'i started here because i think its important people show up in classes we matter what angry or bored people are.',
#  'i never viewed my situation as traumatic or permanent but merely a starting point for something valuable.',
#  'i was a bit lost going around biol 230, i wasnt sure whether i wanted getting into it seemed pretty intense, it lacked in the social aspect, so id thought about sci i knew i could to sign up.',
#  'i have always been afraid of the math portion of physics because math isnt my strong suit.',
#  'this is a new adventure for me where i will make mistakes and learn from them.',
#  'but yet, i am still persevering to become the mechanical engineer i am setting out to be.',
#  'i have a strong image of how i want my life to turn out, and being here will help me paint my canvas.',
#  'the reason i am majoring in bio, is because i think into whatever field i go into i can make a difference.',
#  'i think that would be helpful especially when the road gets tough.',
#  'i hope to do well in all my classes this semester !',
#  'i also had had some struggles with college level science classes in the past because of the homework so had thought that would be a good idea to pick a computer class if its the extensive math involved inside understanding basic concepts.',
#  'yet, these concepts will be an important part of my work i will be doing in the future.',
#  'reasons that pertain only to me and other reasons that pertain to my family or other loved ones.',
#  'i found it making me know that physics is hard and i knew before that the sci course might spur students to take science class.',
#  'one one hand, leaving to such a far distance from home to attend university is not what i first expected.',
#  'i hope this semester will not only challenge me but also encourage me to not give up on struggling situations and be able to preserve until the end.',
#  'i am here to take this physics class so i can graduate with a degree from san francisco state university.',
#  'in the future i hope to be able to provide my children, nieces, and nephews the ability to get an education in a competitive field so that they can have success as well.',
#  'i know that as a child i never thought of education and a career for someone who is undocumented.',
#  'although expensive, its definitely worth it in my opinion, at least to go to college to.',
#  'i love biology and chemistry isnt my favorite but its easier for me to understand than any other major not in the stem field.',
#  'i have fought and worked so hard for everything that i have obtained in life, and that is the reason why i am here, i am here to make myself proud my parents and show everyone that when you put your mind to something, anything is possible when the sky is your limit.',
#  'living in a low income area of oakland made certain things to comeby.',
#  "i don't want to give up because this is something that i really want to do.",
#  'i originally wanted to study zoology and become a zoologist, but my confidence and passion for the goal has diminished over the years.',
#  'i want to pursue a major in biology, specifically physiology.',
#  'i have always dreamed of playing basketball professionally but reality hit in where i am still working on my game while needing to find another career as a backup plan.',
#  'i am here because this is the only path in life that i can see myself taking.',
#  'this would cause a sharp pain in my elbow whenever i would do pushups, bench press, or simply bending my arm would result in a cracking like noise.',
#  'must people try to get money, fame, or more stable life, and to be mean too you, I is not more about me that a dream we need to achieve to make a pokemon happy, myself.',
#  'plus the fact that i am trying to graduate before the age of 30 while most of these kids will probably graduate at 2122 sometimes gets the best of me.',
#  'i am not that strong in math but i am trying.',
#  'i have a drive to do better in a world that constantly belittles my community.',
#  'the second semester was very laid back, and not in a good way.',
#  'i also had had some struggles with college level educational careers in the past because of the fact we had thought that could be a good idea to pick some STEM subject if its not extensive math required inside understanding basic concepts.',
#  'i want to push myself, my gender, or sexuality, about my latina heritage to get my public wrong knowing we still have the potential to excel.',
#  'i want to pursue a career in the medical field, specifically a pediatric doctor.',
#  "i dont want to be an immigration lawyer, especially while in the fair to old east asians here love getting together against gangs. i'm here in this class because i truly hate Trump and at least this is kind of interesting.",
#  'why am i here?',
#  'the main reason i chose this class is because it is a ge requirement.',
#  'sometimes it gets boring and hard, but it is fun once you start to understand how it works.',
#  'why am i here? theres a lot of reasons as to why i am here, attending college.',
#  'i would like to go on my major till i get a computer science degree.',
#  'as the years have gone by and i continued to stay in school, i realized that i am here to develop my skills as an artist, learn how to observe and think about the world around me, and enhance my understanding of various subjects.',
#  'i also know that the time allotted for the professors are not enough to begin with.',
#  'living on my own has also taught me a lot, for example it has helped me with my time management, budgeting, and other adult things.',
#  'it also makes more sense because a lot of concepts we can visualize and experience in our day to day life.',
#  'i am hoping that this class is a little bit easier but so far i am slightly struggling also with my other classes which is chemistry 115 and stats so there is a lot of math i need to do and know.',
#  'im mentally reviewing all the mistakes that we have done which i learned from.',
#  'another reason would be that i can see how my lab partners work on the assignment, and that in turn motivates me to work harder than them to get it done as fast as i can while still following the requirements of the experiment.',
#  'i quit here but actually do something i remember being taught good English, and just drive lost & bored.',
#  'in my junior year with HS english my thats been my wanna take physics, but im had a teacher that didnt teach and just asked us to cheat all our tests again then it didnt look like your classroom teacher, so im excited everyone get that crazy deal on Monday.',
#  'i never understood physics growing up and it was my most hated subject.',
#  "i am a little interested in astronomy so i thought i'd give it a try.",
#  'my community help me to understand chem so thank you!',
#  'i have never taken physics in my life until now.',
#  'i am here right now because attendance is mandatory and i cannot do the work if i am not in class.',
#  'but this dream ended up sticking with me for the duration of my educational career and is the reason that i am attending san francisco state today.',
#  'all of this will be possible because of my success, and as of right now, i am on this path because i am here right now, looking forward into a brighter and better future.',
#  'also, statistics have shown that people with higher education and wealth tend to be healthier.',
#  'i also consider chemistry to sound exceptionally difficult i m still hoping this class will help me pass physics.',
#  'i joined sci 111 because i was in sci 230 and 240 and it did help me while i was both in biol 230 and 240.',
#  'ive been making new friends in my new classes, and creating new study groups in my science classes which has really been a large help for me so far this semester.',
#  'i was not looking forward to this class because i thought it would be quite difficult and i would struggle a lot.',
#  'i found my calling in the sciences and am now pursuing a career in child psychiatry am here because i want to not only better my own life, but better the lives of others to the best of my ability.',
#  'i enjoy learning new things everyday.',
#  'physics for someone looks very easy and it takes a passion and research / hard work to achieve my understanding of physical material.',
#  'all i know was, this country will give me a better life than my own country.',
#  'ive had some struggles that naturally come with moving away from family but Haley really showed me how good it feels to be queer immigrant and realizing its not ever 1 come easy.',
#  'i may be thinking now that i will not use this information outside of this class however, if i eventually learn this to not be true i will be grateful for having taken this course and being prepared for my career even more.',
#  'to prove to myself that i am capable of more than is expected of me as a latina, woman of color.',
#  'since the journal requirement is minimum one hundred and fifty words i shall continue rambling on. i am a disabled veteran and am coming back to school to learn skills more properly suited for civilian interaction, basically here to learn something thats not related to killing and dealing with guns since all those skills do is help me stay in the cycle of protection lines of work (cop, security, etc...).',
#  'we were together for seven years since we were thirteen years old.',
#  'i am grateful for everything they have done and will do to get me where i need to be.',
#  'i am not the smartest student in the university, and often, i find many topics difficult and are harder to to learn than others, but i am here to take on these challenges, and expand the limitations that are in my mindset.',
#  'i am here in sf state because i am pursuing my bachelor degree.',
#  'i am here because of our different to struggle but i want to help build my character.',
#  'i hopes for gain another position into which it can inspire and prove to millions of those "immigrants" on our world that it results exists and feels possible.',
#  'along with that, being a bachelors too proved that i could be consistent and finish how we originally started.',
#  'or i could say that i am here because i chose to stay alive.',
#  'i hopes to reach a position in which it can inspire and prove to all of us "immigrants" on our world that achieving results defending these remain possible.',
#  'i am here because of our different to struggle but i want to help build my character.',
#  'i am there cos we want t learn, ive found an online school in high schools - barely.',
#  'when i started high school my parents talked to me about the struggle with balancing our family along with school and work.',
#  'its still a challenge and i am not extremely good, but i know that if i try my best i can still achieve decent grades.',
#  'most people end up bailing so im hoping sci 111 will provide the assistance i need.',
#  'i just think that physics can be hard mean it, so i know that i have it make in really a effort to actually understand the situation.',
#  'coming to san francisco state university was not easy at all, especially the language, community, environment, and the surroundings.',
#  'during this time, they were not able to spend time with me and would have my grandparents take care of me.',
#  'i am here for a list of reasons.',
#  "so i'll do my best to come on time and be present for whatever activity youll have instore for the class and i'll bring my willingness to learn, a good attitude, and hopeful enough knowledge and understanding on a topic to help someone else who might need assistance.",
#  'why am i here?',
#  'so far this class has helped me be able to communicate with others and teach others what i know and listen to what they know.',
#  'i stand here in prove that i can become anything you set my heart too, from just to you, and to yourself now neither.',
#  'since the journal requirement is minimum one million and fifty words i shall continue rambling on. Im am a disabled veteran and am coming back to school to learn science only appropriate suited for civilian interaction, and here to learn something thats not related in killing and dealing with guns since all ninja skills do is help me stay in the cycle of protection lines of work surveillance, security, security',
#  'physics to science is not technical so it takes a rather long studying of much work to develop an understanding around astronomical phenomena.',
#  'sci provides the opportunity to interact with a diverse group of students who all come from different backgrounds, who all bring different perspectives and ideas.',
#  'another reason i am here is because i want to be able to help others by learning something myself.',
#  'why am i here?',
#  'i am here not to become a failure nor end up like many that called inquits after their freshmen year.',
#  'i will be able to do the problems at my own pace and truly understand the steps to get the solution',
#  "i've come here to become someone who knows what he's doing.the majority of my time as a student has been characterized by a lack of motivation to be proactive in my studies.",
#  'as an environmental studies major, taking a physics course is not in my core classes nor is it an elective for my major.',
#  'i love helping people, so that is why i wanted to become a physical therapist.',
#  'i took sci 115 last semester for my chem 115 and it helped me a lot when it came to making sure that i knew the material that we were learning in the class.',
#  'i dont want to fail again and i also would like to understand it.',
#  'i try my best to go to my professors office hours and study material i did not understand in lecture, but sometimes i still do not understand.',
#  'not so much, because i did not have the best teacher my first semester and it was quite challenging for me.',
#  'so why am i here?',
#  'i am here to gain knowledge about the world, its people and most importantly, its science.',
#  'i find the field to be very interesting to me and i can see myself enjoying it for the rest of my life.',
#  'but this dream ended up sticking with me for the duration of my educational career and is the reason that i am attending san francisco state today.',
#  'i am computer science major so it may not be directly related, but the scientific process and experiments as well as the thought process can be transferred universally with all other science fields.',
#  'to learn than i always been, not two personally learn and one is to learn and move freely in newly added knowledge.',
#  'i can understand xus lectures just fine and it makes sense when he walks us through our problems and worksheets, but when it comes to our homework, i end up getting less than about 60 and it does not teach you how to do the problems when you get them wrong.',
#  'i am here to be able to learn and capture as much knowledge as i can in my path to achieving one of the many goals i have set myself to accomplish.',
#  'i will not do well in my future classes',
#  "i also took astronomy 115 last semester and received a decent grade on it so i thought this class wouldn't be too bad.",
#  'im really glad i did.',
#  'lastly, i am here because i am passionate about my education and i never want to stop learning.',
#  'moving from los gangs to san Marcos, i came with the hope to learn how to become independent and search for as self my wants in distant land where girls like us are constantly under attack and come from communities lacking in resources.',
#  'i figure its hard that i kinda pushing myself anyway.',
#  'why am i in this supplementary instruction class?',
#  "i'm really looking forward to this sci class mainly to have a better understanding of physics ultimately.",
#  'i feel that as a man my never thought of dreams and a career for someone i works undocumented.',
#  'i am excited about that, but i bet its still as hard.',
#  "luckily, the lab professor i have currently is very helpful and i don't mind staying later to get help and understand things from her.",
#  'during the spring, i took physics 220, one of the more challenging courses i had taken here, in addition to data structures and a few other courses.',
#  'it is and has been my greatest passion since i was little.',
#  'not only am i making an impression on the medical space helping humans who were struggling, but u am literally changing the stem norms.',
#  'my life goal is to go to medical school and become a doctor and eventually do medical research.',
#  'i am here, but i really want to go back home to san diego and chill chill on the beach and eat carne asada fries.',
#  "every other field of study that i show interest in is laughable in the eyes of everyone i know, and i kind of feel like i'm stuck in science whether i like it or not.",
#  'i am taking physics 230232 because it is one of my lowerdivision major class, this class will help me expand my learning, daily life, and especially how physics is connected to our everyday life.',
#  'i know this future will be be dull, i promise that i may beat most physical obstacle that would try or derail me.',
#  'i am taking the physics sci class because i do not understand physics for the most part.',
#  'even with this kidney stone i still do my best to come to class through the pain.',
#  "i'm here to push through obstacles, deal with adversity, and mold myself into what i want to be.",
#  'i was excited coming into this semester to take physics because i am a very logical thinker and i feel physics really falls in line with that line of thinking.',
#  'i am here to make friendships and connections.',
#  'im prayers for all us poor colored girls who cannot not find just politicians to face up to at their communities.',
#  'with my career diploma i can improve my health the health of my family.',
#  'i am here in this world to make an impact.',
#  'i am in this class because i believe the extra help will be good for me.',
#  'i am here in class because it requires for my degree and prerequisite; i am also here because ive wanted to be surrounded with the diverse group of people, to collaborate, have fun while studying.',
#  'these just are the reasons why im in here.',
#  'since entering my fourth year of college i have greatly expanded my math boundaries but i am still nervous.',
#  'physics 1 at work We had requirements to report to ucsfs physical therapy department Now im really going an let my day of math pass for any rest of my goals.',
#  'i want to break stereotypes in the workforce to help other people feel more comfortable in the field they want to go in rather than feeling they do not belong.',
#  'to make my family proud and prove myself that i can do it, even though there are lots of challenges.',
#  'i am here to learn and develop my knowledge in every aspect possible to be able to take it out into the real world.',
#  'i am here in the science community because i feel that my people (of color and being a female) are under represented.',
#  'i believe i am here to better my life.',
#  'i have also been looking for science clubs to join in order to meet other people from my major.',
#  "if i didn't chose to be here, i would honestly have no idea or guess to where i would be now but all the decision making and experiences i've had in my life has led me here.",
#  'at the end of the day i just know to keep my eyes ok the prize and the rest will come along.',
#  'im at sfsu because i am pursuing a bachelors of science degree in biochemistry.',
#  'this question got me contemplating tho, like why am i here?',
#  "there are many parallels that can be drawn between physics and my choice of major (math with a concentration in teaching), specifically the numerics involved, but in my time taking physics i've discovered that the math involved in physics takes a different, more complex form than in calculus despite using calculus concepts.",
#  'this is my first time taking physics in college and it been a rough start but i am hoping i can understand and learn from it.',
#  'this is why i am taking it again in college.',
#  'why am i here?',
#  'at 28 years old, i have came across several roadblocks that has directed me to quick.',
#  'since i am a biochemistry major, i know i will probably see those topics later in future classes so if i dont understand the basics now.',
#  'i despise coding, and even though Im hard worker theres fuck lot shit deal, Hes defined by neuroscience.',
#  'after healing my elbow completely, my physical therapist taught me important tips on taking care of my body overall as well as continuing my dreams of playing basketball professionally.',
#  'i am here for the free samples at costco, hot chocolate with crunchy marshmallows on a rainy day, the chika chika during family parties, and of course my baby mushi.',
#  'it is a diverse community and it is a place where i feel happy.',
#  'engineering is hard enough i will achieve i best in order I pass.',
#  'i didnt have time for the lab, therefore, i am took it this semester.',
#  'physics 2 is difficult but instead of giving up like before, my attitude includes ambition and determination.',
#  'physics is a class which often can have a negative stigma surrounding it, especially given how abstract the concepts can get, but i am nonetheless interested in the content & try to remain an objective mind as things study it.as for college in general, but am studying because i wish to gather the knowledge and experience to become a math teacher, in part to forming lasting connections with the people i meet along my way.',
#  'coincidentally, i was thinking of one of my favorite web shows while reading this question: red vs blue.',
#  'being at san francisco state university is an opportunity to expand my learning and experience a new environment that would enable me to endure the challenges that come ahead as an adult.',
#  'i am here at san francisco state to get by bachelors degree in general biology.',
#  'engineering is hard but can have work my best through all to succeed.',
#  'i am here to prove to myself that i can do anything that i set my mind to do.',
#  'so basically, i am really excited for my college journey.',
#  'since physics is basically another math class, i knew i would need to take extra steps to ensure my success.',
#  'in the past ive had a packed schedule with classes and work, but this semester i allowed myself more room for school by cutting back my work hours.',
#  "luckily, the lab professor that have called is not helpful but i don't mind calling later and request help and understand something from people.",
#  'i wanted to make changes to ultimately lead to a better career and a better future for me and my family.',
#  'why am i here?',
#  'i find it super helpful that sfsu provides resources for students to have extra practice and aid to solidify knowledge of certain classes .',
#  'science can be applied to so many aspects of our lives, especially physics.',
#  'i have found physics to be very difficult and i am hoping this class will help me pass physics.',
#  'the reason i study lies in the constant fear of failure i acknowledge in myself.',
#  'since the submission requirement is minimum one hundred eighty fifty words i cannot continue rambling on. i im a combat veteran and am coming back to school to learn roles be properly suited ot civilian interaction, basically here to write something thats mainly related around killing animals dealing with guns but all those cannons do is help soldiers remain in the cycle of protection culture of battle (cop, law, etc...).',
#  'my professor would go extremely fast, and would assume we know the concepts we previously learned in high school.',
#  'my number one fear and inspiration (could they be the same thing) is not making her (and my dad) proud.i\'ve also grown to see her, and my other immediate family simply "exist" to continue existing, and my dad has always instilled a "follow your dreams"optimism.',
#  'its getting to be too much, but thats college.',
#  'engineering me not enough d will achieve i best in order to know.',
#  'also, this is my first physics class i have ever taken didnt take any in high school because it never crossed my mind but i took math classes up to calculus 3.',
#  'as this fourth generation student, i feel how its es my duty to break the generation of poverty and low demand by instead be the first to pioneer is hopeful path into higher education and not be constrained to poverty.',
#  'physics 1 at work 10 had requirements to apply into ucsfs physical therapy department so im being going to let my fear of math happen like the rest of my goals.',
#  'even though this as a course i took for myself, i only registered via satisfy school application, im putting forth my effort d learn more about physics and attempting to apply mathematical information in the world compared to something major.',
#  'i am taking physics as a freshman because coming from out of state, college is quite expensive, so i want to get my ge classes out of the way as quickly as possible so i can eventually graduate as quickly as possible.',
#  'i was a tad lost walking into biol 230, i made sure what i knew looking into college seemed pretty intense, also competitive in the teaching aspect, so when hearing about sci e knew i needed to sign up.',
#  'i am here too prove that i can kill anything you set my heart to, not lying to you, and to ourselves equally well.',
#  'i admire people being able to get a grasp on situations that i dont understand instead of just struggling along them and somehow ultimately understanding these exact topics.',
#  'i migrate to the usa with my brother to live a better life.',
#  'i am here for myself and for everyone that has supported me throughout my journey at san francisco state.',
#  'i am here for the sole purpose of reaching my goal of graduating with a kinesiology degree.',
#  'at 28 years old, i have came across several roadblocks that has directed me to quick.',
#  'that is why i am here, i am here for a reason that is beyond me and for the fact that i want to go to medical school and taking this class will help get there.',
#  'keeping an open mind i am looking forward to this transition and know it will be difficult but after the military nothing really can be that bad, or can it? expectations for this class are high i suppose in the fact that this course takes prerequisites to even get into.',
#  'this sparked a natural curiosity inside of me to pursue this knowledge further.',
#  'and by that i mean learn things i never had someone tell me.',
#  'physics for me is not easy and it takes a lot of studying and hard work to achieve my understanding of the material.',
#  '(and if not i will just come back to sci and get some extra help)',
#  'it was also great with how the class itself interacted, were if there was anything someone comprehended really well they would try to explain it in another way that we werent told in lecture, or even by the instructors, so there was a variety of ways to break down the information for whomever needed it.',
#  'however, i need to make it through a long and difficult path of schooling to pursue this dream.',
#  'i want to one day be able to save hundreds and even thousands of lives and especially travel to third world countries and help out kids who do not have the resources to medicine.',
#  'i am here because i am on that path towards my success, and i believe with my own efforts i can make it there.',
#  "and from a very young age i've found so much purpose and happiness in the connecting with and healing of animals and people.",
#  'i am in san francisco in classes in order to achieve higher education and to succeed later in life.',
#  'i can honestly say this is one of the hardest classes ive taken so far, since i had trouble understanding since day one lecture.',
#  'i aslo really enjoy biology and it is really fascinating to me.',
#  "i want to help my community while i'm here and become a better version of me.",
# ...
#  'we all have our personal issues outside of school that affect our performance, such as anxiety and depression for me.',
#  'i am here because of the way that i have grown up.',
#  'the meaning of life?',
#  'a place where learn, and make mistakes, have difficulties, somewhere that is important for them to have friends and to meet everyone.',
#  'throughout my educational career i have easily succeed in biology and chemistry courses because they comes naturally to me.',
#  'this was a HUGE idea & requires my planning and communication skill.',
#  'i am too young.',
#  "i'm hoping that i'll find a reason to stay in the science field, because i dont really know what else to do.",
#  'i am here to learn and follow the path of a computer science major the concepts i learn in physics wont necessarily help me in my field but physics tells you how good you are at forming logical explanations to problems and how do you tackle them which is very important for computer science majors.',
#  "with that said i've always been a fan of math and science, the idea of why things happen in the real world have crossed my mind but i've never really understood enough to explain what i see.",
#  'i also realized that taking physics and calculus at the same time was a terrible idea since they teach about the same topics, but the way you work the problems and the answers are completely different.',
#  'this semester the hardest class for me is ochem, and the rest are up or ges.',
#  'after you finish your essays, we will provide some class time to discuss your thoughts, to the extent that you feel comfortable sharing.',
#  'i have never taken a physics course in my life and it makes me very anxious because there are a number of people that have seen what we are covering previously and i have never seen any of it.',
#  'i have been in a sci class before for chemistry 1 and it helped me almost get an a in my class.',
#  "well i am a recent transfer student coming from palm desert area and decided that i was coming to sfsu late (earlymid august) so i didn't have much time to pick my classes.",
#  'by me being here in school and pursuing a career in the medical field i feel like i can make a huge impact by reducing the numbers of miscarriages and change the statistics of it.',
#  'it would be such a big help and difference for me when i do pass because i would then realize all of the hard work i have set was worth it.',
#  'it has some fundamental concepts that will further help me understand my other major courses.',
#  'i am here to be happy, to make an impact, and to make a change during my life span.',
#  'i want my represent myself, I experience, my education, and my latina heritage - proving the feminists wrong that I do have some potential to exist.',
#  'i am here to learn about physics in depth and observe the principles we learn in everyday classes and practice the logic behind the essential physics concepts.',
#  'however, sf is really different compared la so there have been numerous times where i have contemplated changing big if la and transferring to another separate college but i look back i think eh im already ready.',
#  'i find the field to be very interesting and i can see myself enjoying it for the rest of my life.',
#  'the work ethics that my dad has passed onto me has allowed me to overcome the tough times that both work and school throw at me.',
#  'as of where i stand currently, i have been all the way through grade school and i by going to college here at sfsu i have chosen the path to pursue my education even further and get my degree.',
#  'it was hard but my parents always prioritized school first for my sister and me.',
#  'in terms of taking a physics lab, it is because it counts towards my major which is biology in concentration with physiology.',
#  'at first, i never understood what my major had to do with physics and why i even have to take it.',
#  'i am in physics because it is required by my major.',
#  'going into this semester i thought i would do really well in physics and struggle in calculus.',
#  'i also think this class is a good opportunity to create study groups and make new friends in my major.',
#  'im here of all the mistakes that i have taken and i learned from.',
#  'i am in the physics 111 supplemental course because i had failed physics 111 in the past spring semester.',
#  'i am taking this sci course because i tend to need extra help with my chemistry courses.',
#  'eventually, when i attended high school, i was apart of an internship at the california academy of sciences as an education intern who would teach people about the various scientific topics that are discussed here.',
#  'so why am i here?',
#  'i also have had some struggles of college prep math classes so i past thinking of the homework so i thought it would be a good idea to explore the supplementary class because of the extensive math help in testing simple concepts.',
#  'my aunt is someone i look up to since she is a radiologist at the stanford medical center in palo alto.',
#  'i have struggled with understanding physics since high school, yet i enter every class with the mindset that maybe today it will click.',
#  'to learn as i have to, but to personally learn and one wish to learn and move forward with newly added knowledge.',
#  "i think i'm in this specific class to help with my understanding with physics.",
#  'i am in this class because i am not good at math.',
#  'this is because math and science has usually always clicked with me and because physics does not click in my head automatically without lots of thinking i become stressed and worried that i will never be able to understand the material enough to pass the class.',
#  'so then i thought i could take textiles lab and that it would count for my ge requirements.',
#  'i am now a mechanical engineering major since i feel like i would have more fun in that field and it could provide me a lot of opportunities.',
#  'i am in computer science because originally i wanted to join the military but then trump got elected so i went to college and choose my major by throwing a dart at a board.',
#  'also , my father are one of the best engineers in my kuwait so i wish i could be like him .however becoming an engineer is not the only thisngs that i can do in the united states i want to learn as much as possible about the life and how i should act in every situation i face ,so i can be a great father and i can gain experience in life.',
#  'i stay here a actually do something i am being taught in lecture, and just get lost or bored.',
#  'i am here to provide myself with opportunities and accomplish to something besides stereotypes and provide my resources to other younger generations with them to help them also accomplish to these goals and achieve to more than they can imagine.',
#  'a lot of the time i feel uncomfortable im my regular stem classes because i feel that i may be the only one not understanding.',
#  'coming from an immigrant family, being apart from my parents for many years, without having the support and motivation to keep my dreams going was nothing short of easy.',
#  'i am here because i think its important to show up to classes no matter how tired or bored you are.',
#  'i better also try my hardest in this class as am feel that this place where we can learn tha ropes. i be also here because i want to graduate on time and not fail any of these classes.',
#  'physics is difficult for me and i need all the help that i can to fix my struggle with it.',
#  'physics isnt an easy subject to learn.',
#  "physics happens to be a branch of education of my cs degree so that's a majority of the reason i'm taking the class.",
#  'i knew that i wouldnt allow myself to end up impoverished, victimized, or addicted.',
#  'another reason that i am in the sci course is to get a class unit so that i may be eligible for competition in my sport.',
#  'in a household where sometimes i would not have the luxury of having to eat breakfast, lunch and dinner.',
#  'initially, my motivation was very revolved around myself and proving others wrong, but eventually that motivation bloomed into proving to myself that i can and will continue to improve myself not only through school, but through life as well.',
#  'i also found chemistry to get too difficult and m am confident this class will help me pass physics.',
#  'i used to always be a quitter, and very early on in high school i decided that i was not smart enough to understand science but i have learned that dedication, passion, and hard work are key.',
#  'this job never only felt lonely and challenging like far, yet l am just excited to find real life back.',
#  'the reason i am here is because i want to make my mom proud, to support my family and because i am not paying 3500 to miss any classes.',
#  'im currently in my fourth year which wont be my last since i will need another year to pass my majors required classes.',
#  'therefore, this class will help me in depth of why everything happens the way it does.',
#  'why am i here?',
#  'i am currently a junior at san francisco state and i am taking this course to fulfill my prerequisites to apply for medical school.',
#  'my mind is always blown when im learning new topics regarding the subject.',
#  'despite, all these concepts that is definitely interesting, i feel physics can be sometimes hard to be understood with all the details and mind boggling questions it includes.',
#  'i like gaining the new perspective on what i see and hope to be able to use this knowledge going forward to test or even extend what i know.',
#  'i am here, i guess to start initially with san francisco state because i had a change of plans in my major.',
#  'im here because i told myself i deserve to be here and now i have to prove it.',
#  'also, if i do skip class it will just snowball and cause me to skip more classes.',
#  'im here right now because i need to be here.',
#  'in addition, i want to become an engineer someday and that starts with me learning basics physics concepts that are going to be applied to my career.',
#  'i spent much of my time outside of the house trying to stay busy.',
#  'i am here at san francisco state university because i want a good education so that i can become a physical therapist in the future.',
#  'im hoping this time around, it will work out for me.',
#  'you may ask why i was born in a house?',
#  'a society where learn, and make plans, experience difficulties, somewhere that feels important for them to go — and they help everyone.',
#  'i am taking this sci class (aside from the fact that it is mandatory for me), because i really need that extra push to set aside time to focus on strengthening my knowledge in physics.',
#  'i am the first in my family to attempt to get into med school.',
#  'i am here for my parents and my family.',
#  'i invested more time into my social life once spring came around.',
#  'i did not have a chance to take in high school since it was full.',
#  'i often ask myself this question, "why am i here?" and i start to think about all i have done to be here, how far i have come.',
#  'my motivation includes money, family and specifically my mother.',
#  'i am here for a list of reasons.',
#  'originally when i began attending sf state, it was because i was encouraged to go to college by my family and teachers.',
#  'i also have had some struggles with college level math classes in the past because of the homework so i thought it would be a good idea to take a supplementary class because of the extensive math involved in understanding physics concepts.',
#  'thats a difficult question to answer.',
#  'going to college was an easy choice for me because ive seen what could happen if you dont work hard and chase your dreams.',
#  'i know the journey will not be linear, i know that i can overcome these harsh barriers that will try to consume me.',
#  'a degree will make me advance towards what i need to be, and studying is just a medium.',
#  'i am here to prove that i can do anything i set my mind to, not only to others, but to myself as well.',
#  'why am i here?',
#  'i also came to sfsu because of the apparel design major and am really loving it and learning so much in this major.',
#  "i still don't clearly understand how physics is related to biology and why i have to do the physics lab.",
#  'through them i was able to learn from school but from myself that i can succeed.',
#  'i know i will end in meeting my goal of meeting the doctor because have havent had anything stop me in that process.',
#  'time went by much faster because i balanced study time in the library with being out and about in the city.',
#  'when i got injured playing basketball, i had a chipped bone on my humerus which did not allow my arm to bend and function as smoothly.',
#  'after working in it for a few years it was inevitable that i return to school and finish my degree if i wanted to proceed further into the field.',
#  'i am enrolled in chem115 because it is a major requirement needed to get into chem215.',
#  'i am here to gain knowledge about the world, its people and most importantly, its science.',
#  'while the months having felt challenging, vendors love the process towards learning better methods and addressing these obstacles.',
#  'after being in physics 121122 and chemistry 115 for a few weeks, i think that visualizing what i am learning is very important.',
#  'it would have probably helped me get a better grade in the lecture class to take them together, but it wasnt as bad as i thought to just take the lab which also serves as a refresher for my next semester taking physics 121 and physics 122.',
#  'but maybe the reason why i am here is because i have a purpose.',
#  'is not that i hate studying, but the fact that i dont love it makes it even harder to comprehend why am i here.',
#  'i was the product of a divorced family, my mother was a bartender, my dad wasnt around much, and all of my brothers and sisters were half brothers and half sisters who were at least 8 years older than me.',
#  'ive also heard a lot of stories about how difficult organic chemistry can be.',
#  'no matter at what age i am in, i know that wherever i am in life it is because of my choices, god, and it is because i was meant to be there.',
#  'i did not enjoy phys 111 it was hard for me.',
#  'hopefully, i finish in 2 years and being here right now in this class adds up to that point.',
#  'i attend every class so i can get the most out of my education and learn the vital facts about physics.',
#  'however, that is not the only medical research i would do, i would love to do more than that, thats why i am here.',
#  'i am here at sfsu because i want to make a difference in the world.',
#  'even thought, there are too many painful memory remind me, but i like that felling which i can go on in my real life.',
#  'sometimes i feel that i am too old to be in school especially this semester.',
#  'it is important for me to pass this class, so that i can pursue my degree in helping me towards finding a wellpaid and decent job im most passionate about one day.',
#  'i took general physics 1 and i was confused on how it related to my goals.',
#  'i will live the dream and get through al of tha challenges that it thrown at ya.',
#  'i also know that obtaining a high paying career and actually doing something you enjoy a great path to success.',
#  'i could answer it in many different ways.',
#  'i will also am sure i understand through the points.. he is one tough subject.',
#  'i tried passing this particular supplemental course and i decided that i will come up struggling with interesting topics in science.',
#  'also, was still an eye cancer doctor, and there is not some big synergy in the new cells, but they came to help in a direction.',
#  'since starting physics, i understand now that almost every thing that i am going to be doing for science needs to be backed up by data and i need to understand why some things happen the way that they do.',
#  "i'm prepared for what's ahead and look forward to expanding my understanding of what i already know.",
#  ...]

# %%
bert_predictor = ktrain.get_predictor(learner.model, preproc=bert_transformer)

bert_test_data = test_df['sentence'].tolist()
bert_test_label = test_df['label'].tolist()

y_pred_bert = bert_predictor.predict(bert_test_data)

y_pred_bert = [int(x) for x in y_pred_bert]

tn, fp, fn, tp = confusion_matrix(bert_test_label, y_pred_bert).ravel()
print('True Negative: {}, False Positive: {}, False Negative: {}, True Positive: {}'.format(tn, fp, fn, tp))

print('  Classification Report:\n',classification_report(bert_test_label,y_pred_bert),'\n')
# Out:
# True Negative: 219, False Positive: 5, False Negative: 14, True Positive: 21
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       224
#            1       0.81      0.60      0.69        35
#
#     accuracy                           0.93       259
#    macro avg       0.87      0.79      0.82       259
# weighted avg       0.92      0.93      0.92       259

# %%
bert_predictor.save('../../../../saved_models/resistance_bert_base_cased_model_08092024_v2')

# %% [markdown]
# ### 3. Contextual sentence augmentor

# %%
sentence_aug = nas.ContextualWordEmbsForSentenceAug(model_path='gpt2')
augmented_text = sentence_aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Original:
# The quick brown fox jumps over the lazy dog.
# Augmented Text:
# ['The quick brown fox jumps over the lazy dog. to , one new more government of a first \' one and all the next other at current , not in a " ( way other " , time in']

# %%
sen_aug_data_pos_list = []
for i in resistance_pos_data_list:
    new_data = sentence_aug.augment(i)
    sen_aug_data_pos_list.append(new_data)

# %% [markdown]
# ### 4. Backtrip translation

# %%
import nlpaug.augmenter.word as naw

text = 'The quick brown fox jumped over the lazy dog'
back_translation_aug = naw.BackTranslationAug(
    from_model_name='facebook/wmt19-en-de', 
    to_model_name='facebook/wmt19-de-en'
)
back_translation_aug.augment(text)
# Out:
# config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# ['The speedy brown fox leapt over the lazy dog']

# %%
training_aug_translation_df = dataset_augmentor(training_df, back_translation_aug)
training_aug_translation_df
# Out:
# Positive labels present in the dataset : 278  out of 1171 or 23.740392826643895%
#                                               sentence  label  \
# 630  going into this course i feel uncertain about ...      0
# 41   I have slipped a little bit during this recent...      1
# 450  i have goals that benefit not just myself but ...      0
# 233  right now, i am really stuck on vectors and ca...      0
# 299  the bigger reason for why i am here as sf stat...      0
# ..                                                 ...    ...
# 578  of course, because of my proficiency of theore...      0
# 242  turns out i'm not as interested and my last la...      0
# 837                 honestly speaking, i have no idea.      0
# 112  I chose this course because there is always ro...      1
# 275          "why am i here" is a very broad question.      0
#
#                                                 phrase
# 630  ['Im putting all my effort to learn more about...
# 41                                                 NaN
# 450  ['I know the journey will not be linear, I kno...
# 233  ['I am taking the physics SCI class because I ...
# 299  ["After working minimum wage part time jobs wh...
# ..                                                 ...
# 578  ['This is a challenging class that test my coo...
# 242  ["Luckily, the lab professor I have currently ...
# 837  ['First of all, it is mandatory and I do not w...
# 112                                                NaN
# 275  ['First of all, it is mandatory and I do not w...
#
# [1171 rows x 3 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
